# %%
# %matplotlib inline
# %run ../import_envs.py
from sim_banana import Sim_BANANA
# Out:
# probtorch: 0.0+5a2c637 torch: 1.3.0

# %%
N = 200
D = 2
alpha = 1.0
beta = 20
mu = 0.0
nu = 25.0
simulator = Sim_BANANA(N, D, alpha, beta, mu, nu)
simulator.viz_data(num_seqs=5)

# %%
PATH = DATA_DIR + 'banana/train/'
simulator.sim_save_data(num_seqs=1000, PATH=PATH)

# %%
import matplotlib.pyplot as plt
from torch.distributions.gamma import Gamma
precisions = Gamma(torch.ones(2) * alpha, torch.ones(2) * beta).sample((1000,))
sigma = 1. / (precisions).sqrt()
plt.scatter(sigma[:,0], sigma[:, 1])

# %%
sigma_mean = 1. / (nu * precisions).sqrt()
plt.scatter(sigma_mean[:,0], sigma_mean[:, 1])
