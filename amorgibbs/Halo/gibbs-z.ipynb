# %%
# %matplotlib inline
import sys
sys.path.append("../")
sys.path.append('/home/hao/Research/probtorch/')
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
from plots import *
from utils import *
from objectives import *
from torch.distributions.normal import Normal
from torch.distributions.one_hot_categorical import OneHotCategorical as cat
import time
import probtorch
print('probtorch:', probtorch.__version__, 
      'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# probtorch: 0.0+5a2c637 torch: 1.0.0 cuda: True

# %%
N = 300
K = 3
D = 2

## Model Parameters
SAMPLE_SIZE = 10
NUM_HIDDEN1 = 8
STAT_SIZE = 8
NUM_LATENTS =  D
## Training Parameters
BATCH_SIZE = 20
NUM_EPOCHS = 10000
LEARNING_RATE = 1e-3
CUDA = torch.cuda.is_available()
PATH = 'gibbs-z'

gpu = torch.device('cuda:0')

# %%
Xs = torch.from_numpy(np.load('rings_dataset/obs.npy')).float()
# STATES = torch.from_numpy(np.load('rings_dataset/states.npy')).float()
OBS_MU = torch.from_numpy(np.load('rings_dataset/obs_mu.npy')).float()
NUM_SEQS = Xs.shape[0]
NUM_BATCHES = int((Xs.shape[0] / BATCH_SIZE))

# %%
class Enc_z(nn.Module):
    def __init__(self, num_hidden=2*D,
                       sample_size=SAMPLE_SIZE,
                       batch_size=BATCH_SIZE):
        super(self.__class__, self).__init__()
        self.log_distance = nn.Sequential(
            nn.Linear(2*D, int(0.5*num_hidden)),
            nn.Tanh(),
            nn.Linear(int(0.5*num_hidden), int(0.5*num_hidden)),
            nn.Tanh(),
            nn.Linear(int(0.5*num_hidden), 1))
        
#         self.pi_prob = nn.Sequential(
#             nn.Linear(1+D, num_hidden),
#             nn.Tanh(),
#             nn.Linear(num_hidden, int(0.5*num_hidden)),
#             nn.Tanh(),
#             nn.Linear(int(0.5*num_hidden), 1))
        
        self.prior_pi = torch.ones(K) * (1./ K)
        self.radius = torch.ones((sample_size, batch_size, N, 1)) *  1.5
#         self.noise_sigma = torch.ones((sample_size, batch_size, N, D)) *  0.05
        if CUDA:
            self.prior_pi = self.prior_pi.cuda().to(gpu)
            self.radius = self.radius.cuda().to(gpu)
#             self.noise_sigma = self.noise_sigma.cuda().to(gpu)
  
    def forward(self, obs, obs_mu, sample_size, batch_size):
        q = probtorch.Trace()
        obs_mu_c1 = obs_mu[:, :, 0, :].unsqueeze(-2).repeat(1,1,N,1)
        obs_mu_c2 = obs_mu[:, :, 1, :].unsqueeze(-2).repeat(1,1,N,1)
        obs_mu_c3 = obs_mu[:, :, 2, :].unsqueeze(-2).repeat(1,1,N,1)
        
        data_c1 = torch.cat((obs, obs_mu_c1), -1) 
        data_c2 = torch.cat((obs, obs_mu_c2), -1) 
        data_c3 = torch.cat((obs, obs_mu_c3), -1) ## S * B * N * 2D
        
        dis_c1 = self.log_distance(data_c1).exp()
        dis_c2 = self.log_distance(data_c2).exp()
        dis_c3 = self.log_distance(data_c3).exp() ## S * B * N * 1
        
#         ## S * B * N * (1+D) --> S * B * N * 1
#         z_pi_c1 = self.pi_prob(torch.cat((self.radius - dis_c1, self.noise_sigma), -1) )
#         z_pi_c2 = self.pi_prob(torch.cat((self.radius - dis_c2, self.noise_sigma), -1) )
#         z_pi_c3 = self.pi_prob(torch.cat((self.radius - dis_c3, self.noise_sigma), -1) )
        distance = torch.cat((dis_c1, dis_c2, dis_c3), -1) # S * B * N * K
        obs_dist = Normal(torch.zeros(1).cuda().to(gpu) , torch.ones(1).cuda().to(gpu) * 0.05)
        log_distance = obs_dist.log_prob(distance - self.radius) # S * B * N * K   

        q_pi = F.softmax(log_distance, -1)
        
        q = probtorch.Trace()
        p = probtorch.Trace()
        
        z = cat(q_pi).sample()
        _ = q.variable(cat, probs=q_pi, value=z, name='zs')
        p = probtorch.Trace()
        _ = p.variable(cat, probs=self.prior_pi, value=z, name='zs')
        return q, p
    
def initialize():
    enc_z = Enc_z()
    if CUDA:
        enc_z.cuda().to(gpu)
    optimizer =  torch.optim.Adam(list(enc_z.parameters()),lr=LEARNING_RATE, betas=(0.9, 0.99))    
    return enc_z, optimizer

# %%
enc_z, optimizer = initialize()

# %%
def Eubo(enc_z, obs, obs_mu, N, K, D, sample_size, batch_size, gpu):
    q_z, p_z = enc_z(obs, obs_mu, sample_size, batch_size)
    log_p_z = p_z['zs'].log_prob
    log_q_z = q_z['zs'].log_prob ## S * B * N
    states = q_z['zs'].value
    log_obs_n = Log_likelihood(obs, states, obs_mu, K, D, radius=1.5, noise_sigma = 0.05, gpu=gpu, cluster_flag=False)
    log_weights_local = log_obs_n + log_p_z - log_q_z
    weights_local = F.softmax(log_weights_local, 0).detach()

    eubo =(weights_local * log_weights_local).sum(0).sum(-1).mean()
    elbo = log_weights_local.mean()
    ess = (1. / (weights_local**2).sum(0)).mean()
    return eubo, elbo, ess

# %%
EUBOs = []
ELBOs = []
ESSs = []

flog = open('results/log-' + PATH + '.txt', 'w+')
flog.write('EUBO\tELBO\tESS\n')
flog.close()
for epoch in range(NUM_EPOCHS):
    time_start = time.time()
    indices = torch.randperm(NUM_SEQS)
    EUBO = 0.0
    ELBO = 0.0
    ESS = 0.0
    for step in range(NUM_BATCHES):
        optimizer.zero_grad()
        batch_indices = indices[step*BATCH_SIZE : (step+1)*BATCH_SIZE]
        obs = Xs[batch_indices]
        obs_mu = OBS_MU[batch_indices].repeat(SAMPLE_SIZE, 1, 1, 1)
        obs = shuffler(obs).repeat(SAMPLE_SIZE, 1, 1, 1)
        if CUDA:
            obs = obs.cuda().to(gpu)
            obs_mu = obs_mu.cuda().to(gpu)
        eubo, elbo, ess = Eubo(enc_z, obs, obs_mu, N, K, D, SAMPLE_SIZE, BATCH_SIZE, gpu)
        ## gradient step
        eubo.backward()
        optimizer.step()
        EUBO += eubo.item()
        ELBO += elbo.item()
        ESS += ess.item()
    EUBOs.append(EUBO / NUM_BATCHES)
    ELBOs.append(ELBO / NUM_BATCHES)
    ESSs.append(ESS / NUM_BATCHES) 
    flog = open('results/log-' + PATH + '.txt', 'a+')
    print('%.3f\t%.3f\t%.3f'
            % (EUBO/NUM_BATCHES, ELBO/NUM_BATCHES, ESS/NUM_BATCHES), file=flog)
    flog.close()
    time_end = time.time()
    print('epoch=%d, EUBO=%.3f, ELBO=%.3f, ESS=%.3f (%ds)'
            % (epoch, EUBO/NUM_BATCHES, ELBO/NUM_BATCHES, ESS/NUM_BATCHES, 
               time_end - time_start))
# Out:
# epoch=0, EUBO=-3533.041, ELBO=-649.598, ESS=5.376 (0s)
# epoch=1, EUBO=-2641.174, ELBO=-494.121, ESS=5.917 (1s)
# epoch=2, EUBO=-2350.648, ELBO=-428.932, ESS=6.113 (0s)
# epoch=3, EUBO=-2087.169, ELBO=-405.203, ESS=6.210 (0s)
# epoch=4, EUBO=-1732.323, ELBO=-397.621, ESS=6.251 (1s)
# epoch=5, EUBO=-1589.717, ELBO=-381.762, ESS=6.313 (1s)
# epoch=6, EUBO=-1336.218, ELBO=-359.759, ESS=6.364 (0s)
# epoch=7, EUBO=-1191.643, ELBO=-341.762, ESS=6.400 (0s)
# epoch=8, EUBO=-1046.559, ELBO=-327.533, ESS=6.425 (0s)
# epoch=9, EUBO=-956.406, ELBO=-312.751, ESS=6.455 (0s)
# epoch=10, EUBO=-868.907, ELBO=-299.838, ESS=6.478 (1s)
# epoch=11, EUBO=-878.204, ELBO=-291.913, ESS=6.494 (0s)
# epoch=12, EUBO=-859.533, ELBO=-283.470, ESS=6.517 (0s)
# epoch=13, EUBO=-790.754, ELBO=-279.043, ESS=6.519 (1s)
# epoch=14, EUBO=-888.441, ELBO=-273.852, ESS=6.543 (1s)
# epoch=15, EUBO=-829.663, ELBO=-273.918, ESS=6.533 (1s)
# epoch=16, EUBO=-830.505, ELBO=-272.030, ESS=6.541 (0s)
# epoch=17, EUBO=-844.641, ELBO=-272.462, ESS=6.534 (1s)
# epoch=18, EUBO=-867.580, ELBO=-271.019, ESS=6.548 (1s)
# epoch=19, EUBO=-797.551, ELBO=-271.577, ESS=6.540 (1s)
# epoch=20, EUBO=-825.526, ELBO=-271.083, ESS=6.541 (0s)
# epoch=21, EUBO=-820.568, ELBO=-270.902, ESS=6.539 (1s)
# epoch=22, EUBO=-814.606, ELBO=-270.091, ESS=6.543 (0s)
# epoch=23, EUBO=-845.576, ELBO=-270.834, ESS=6.543 (0s)
# epoch=24, EUBO=-816.247, ELBO=-270.302, ESS=6.543 (1s)
# epoch=25, EUBO=-828.106, ELBO=-270.906, ESS=6.540 (0s)
# epoch=26, EUBO=-807.341, ELBO=-271.245, ESS=6.542 (1s)
# epoch=27, EUBO=-815.264, ELBO=-270.833, ESS=6.542 (0s)
# epoch=28, EUBO=-845.226, ELBO=-271.131, ESS=6.540 (1s)
# epoch=29, EUBO=-825.811, ELBO=-271.583, ESS=6.536 (0s)
# epoch=30, EUBO=-792.996, ELBO=-270.415, ESS=6.540 (1s)
# epoch=31, EUBO=-821.293, ELBO=-271.417, ESS=6.535 (1s)
# epoch=32, EUBO=-796.079, ELBO=-271.385, ESS=6.534 (1s)
# epoch=33, EUBO=-786.735, ELBO=-271.628, ESS=6.536 (0s)
# epoch=34, EUBO=-780.572, ELBO=-272.568, ESS=6.530 (0s)
# epoch=35, EUBO=-819.610, ELBO=-271.072, ESS=6.543 (0s)
# epoch=36, EUBO=-803.242, ELBO=-272.116, ESS=6.536 (1s)
# epoch=37, EUBO=-830.779, ELBO=-271.237, ESS=6.538 (1s)
# epoch=38, EUBO=-794.796, ELBO=-271.650, ESS=6.535 (0s)
# epoch=39, EUBO=-815.107, ELBO=-271.515, ESS=6.535 (1s)
# epoch=40, EUBO=-803.462, ELBO=-271.330, ESS=6.534 (0s)
# epoch=41, EUBO=-764.036, ELBO=-271.990, ESS=6.535 (0s)
# epoch=42, EUBO=-824.682, ELBO=-270.908, ESS=6.538 (0s)
# epoch=43, EUBO=-783.028, ELBO=-272.246, ESS=6.534 (1s)
# epoch=44, EUBO=-824.407, ELBO=-271.203, ESS=6.543 (0s)
# epoch=45, EUBO=-783.001, ELBO=-272.182, ESS=6.536 (1s)
# epoch=46, EUBO=-795.295, ELBO=-271.716, ESS=6.536 (1s)
# epoch=47, EUBO=-802.756, ELBO=-271.825, ESS=6.539 (0s)
# epoch=48, EUBO=-804.487, ELBO=-271.799, ESS=6.536 (1s)
# epoch=49, EUBO=-785.390, ELBO=-272.269, ESS=6.534 (1s)
# epoch=50, EUBO=-775.344, ELBO=-272.275, ESS=6.536 (1s)
# epoch=51, EUBO=-778.844, ELBO=-271.936, ESS=6.532 (0s)
# epoch=52, EUBO=-791.261, ELBO=-271.482, ESS=6.534 (1s)
# epoch=53, EUBO=-783.076, ELBO=-270.914, ESS=6.539 (1s)
# epoch=54, EUBO=-777.276, ELBO=-272.072, ESS=6.537 (0s)
# epoch=55, EUBO=-747.489, ELBO=-271.429, ESS=6.539 (0s)
# epoch=56, EUBO=-771.560, ELBO=-272.161, ESS=6.534 (1s)
# epoch=57, EUBO=-791.891, ELBO=-271.318, ESS=6.540 (0s)
# epoch=58, EUBO=-713.955, ELBO=-272.351, ESS=6.530 (0s)
# epoch=59, EUBO=-852.299, ELBO=-271.630, ESS=6.539 (0s)
# epoch=60, EUBO=-781.668, ELBO=-271.573, ESS=6.535 (0s)
# epoch=61, EUBO=-772.209, ELBO=-272.799, ESS=6.531 (0s)
# epoch=62, EUBO=-841.751, ELBO=-271.312, ESS=6.543 (0s)
# epoch=63, EUBO=-731.639, ELBO=-272.294, ESS=6.530 (0s)
# epoch=64, EUBO=-797.004, ELBO=-271.754, ESS=6.537 (0s)
# epoch=65, EUBO=-764.706, ELBO=-272.013, ESS=6.533 (0s)
# epoch=66, EUBO=-768.629, ELBO=-271.919, ESS=6.537 (0s)
# epoch=67, EUBO=-795.941, ELBO=-272.018, ESS=6.537 (0s)
# epoch=68, EUBO=-802.678, ELBO=-272.024, ESS=6.536 (0s)
# epoch=69, EUBO=-777.540, ELBO=-271.899, ESS=6.539 (1s)
# epoch=70, EUBO=-828.306, ELBO=-272.571, ESS=6.536 (1s)
# epoch=71, EUBO=-775.083, ELBO=-271.543, ESS=6.539 (1s)
# epoch=72, EUBO=-804.515, ELBO=-272.307, ESS=6.531 (0s)
# epoch=73, EUBO=-770.177, ELBO=-272.229, ESS=6.538 (0s)
# epoch=74, EUBO=-818.976, ELBO=-272.625, ESS=6.531 (0s)
# epoch=75, EUBO=-795.171, ELBO=-272.288, ESS=6.536 (0s)
# epoch=76, EUBO=-827.146, ELBO=-272.703, ESS=6.532 (1s)
# epoch=77, EUBO=-810.254, ELBO=-270.779, ESS=6.540 (0s)
# epoch=78, EUBO=-761.753, ELBO=-272.587, ESS=6.530 (0s)
# epoch=79, EUBO=-822.645, ELBO=-272.322, ESS=6.535 (0s)
# epoch=80, EUBO=-800.277, ELBO=-272.119, ESS=6.537 (0s)
# epoch=81, EUBO=-835.027, ELBO=-272.591, ESS=6.534 (0s)
# epoch=82, EUBO=-771.929, ELBO=-272.082, ESS=6.537 (1s)
# epoch=83, EUBO=-799.751, ELBO=-271.999, ESS=6.538 (1s)
# epoch=84, EUBO=-742.459, ELBO=-271.691, ESS=6.538 (0s)
# epoch=85, EUBO=-779.472, ELBO=-272.779, ESS=6.533 (1s)
# epoch=86, EUBO=-806.765, ELBO=-271.801, ESS=6.540 (1s)
# epoch=87, EUBO=-828.521, ELBO=-274.012, ESS=6.524 (0s)
# epoch=88, EUBO=-833.895, ELBO=-271.314, ESS=6.541 (0s)
# epoch=89, EUBO=-770.320, ELBO=-271.666, ESS=6.539 (0s)
# epoch=90, EUBO=-716.912, ELBO=-272.373, ESS=6.529 (1s)
# epoch=91, EUBO=-791.429, ELBO=-272.721, ESS=6.531 (1s)
# epoch=92, EUBO=-845.185, ELBO=-272.221, ESS=6.533 (1s)
# epoch=93, EUBO=-793.080, ELBO=-271.885, ESS=6.538 (0s)
# epoch=94, EUBO=-763.216, ELBO=-272.072, ESS=6.536 (0s)
# epoch=95, EUBO=-801.317, ELBO=-271.439, ESS=6.540 (1s)
# epoch=96, EUBO=-793.262, ELBO=-272.147, ESS=6.535 (1s)
# epoch=97, EUBO=-749.073, ELBO=-272.538, ESS=6.535 (1s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-03d370d0a1eb> in <module>()
#      21             obs = obs.cuda().to(gpu)
#      22             obs_mu = obs_mu.cuda().to(gpu)
# ---> 23         eubo, elbo, ess = Eubo(enc_z, obs, obs_mu, N, K, D, SAMPLE_SIZE, BATCH_SIZE, gpu)
#      24         ## gradient step
#      25         eubo.backward()
#
# <ipython-input-6-7b55c206b1e9> in Eubo(enc_z, obs, obs_mu, N, K, D, sample_size, batch_size, gpu)
#       1 def Eubo(enc_z, obs, obs_mu, N, K, D, sample_size, batch_size, gpu):
# ----> 2     q_z, p_z = enc_z(obs, obs_mu, sample_size, batch_size)
#       3     log_p_z = p_z['zs'].log_prob
#       4     log_q_z = q_z['zs'].log_prob ## S * B * N
#       5     states = q_z['zs'].value
#
# ~/anaconda3/envs/dev/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-4-b6d43cd220c8> in forward(self, obs, obs_mu, sample_size, batch_size)
#      36         data_c3 = torch.cat((obs, obs_mu_c3), -1) ## S * B * N * 2D
#      37
# ---> 38         dis_c1 = self.log_distance(data_c1).exp()
#      39         dis_c2 = self.log_distance(data_c2).exp()
#      40         dis_c3 = self.log_distance(data_c3).exp() ## S * B * N * 1
#
# ~/anaconda3/envs/dev/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     482
#     483     def __call__(self, *input, **kwargs):
# --> 484         for hook in self._forward_pre_hooks.values():
#     485             hook(self, input)
#     486         if torch._C._get_tracing_state():
#
# KeyboardInterrupt:

# %%
batch_indices = indices[step*BATCH_SIZE : (step+1)*BATCH_SIZE]
obs = Xs[batch_indices]
obs_mu = OBS_MU[batch_indices].repeat(SAMPLE_SIZE, 1, 1, 1)
obs = shuffler(obs).repeat(SAMPLE_SIZE, 1, 1, 1)
if CUDA:
    obs = obs.cuda().to(gpu)
    obs_mu = obs_mu.cuda().to(gpu)

# %%
obs_mu[0, 0]

# %%
q_z, p_z = enc_z(obs, obs_mu, SAMPLE_SIZE, BATCH_SIZE)
# log_p_z = p_z['zs'].log_prob
# log_q_z = q_z['zs'].log_prob ## S * B * N
# states = q_z['zs'].value

# %%
log_p_z = p_z['zs'].log_prob
log_q_z = q_z['zs'].log_prob ## S * B * N

# %%
q_z['zs'].dist.probs

# %%
BATCH_SIZE_TEST = 20

def sample_single_batch(num_seqs, Xs, OBS_MU, sample_size, batch_size, gpu):
    indices = torch.randperm(num_seqs)
    batch_indices = indices[0*batch_size : (0+1)*batch_size]
    obs = Xs[batch_indices]
    obs_mu = OBS_MU[batch_indices].repeat(sample_size, 1, 1, 1)
    obs = shuffler(obs).repeat(sample_size, 1, 1, 1)
    if CUDA:
        obs = obs.cuda().to(gpu)
        obs_mu = obs_mu.cuda().to(gpu)
    return obs, obs_mu

def test(enc_z, obs, obs_mu, sample_size, batch_size):
        ## update z -- cluster assignments
    q_z, p_z = enc_z(obs, obs_mu, sample_size, batch_size)
    return q_z

def plot_samples(obs, q_eta, q_z, K, batch_size, PATH):
    colors = ['r', 'b', 'g']
    fig = plt.figure(figsize=(25,50))
    xs = obs[0].cpu().data.numpy()
    mu = obs_mu[0].cpu().data.numpy()
    zs = q_z['zs'].dist.probs[0].cpu().data.numpy()
    for b in range(batch_size):
        ax = fig.add_subplot(int(batch_size / 5), 5, b+1)
        x = xs[b]
        z = zs[b]
        mu_b = mu[b]
        assignments = z.argmax(-1)
        for k in range(K):
            xk = x[np.where(assignments == k)]
            ax.scatter(xk[:, 0], xk[:, 1], c=colors[k], alpha=0.2)
            ax.scatter(mu_b[k, 0], mu_b[k, 1], c=colors[k])
        ax.set_ylim([-5, 5])
        ax.set_xlim([-5, 5])
    plt.savefig('results/modes-' + PATH + '.svg')
    
obs, obs_mu = sample_single_batch(NUM_SEQS, Xs, OBS_MU, SAMPLE_SIZE, BATCH_SIZE_TEST, gpu)
q_z = test(enc_z, obs, obs_mu, SAMPLE_SIZE, BATCH_SIZE_TEST)
# %time plot_samples(obs, obs_mu, q_z, K, BATCH_SIZE_TEST, PATH)
# Out:
# CPU times: user 1.87 s, sys: 27.2 ms, total: 1.89 s
# Wall time: 1.95 s
