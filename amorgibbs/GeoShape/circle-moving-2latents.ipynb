# %%
# %matplotlib inline
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from plots import *
from kls import *
from torch.distributions.normal import Normal
from torch.distributions.one_hot_categorical import OneHotCategorical as cat
from torch.distributions.beta import Beta
from torch.distributions.uniform import Uniform
from torch.distributions.relaxed_categorical import RelaxedOneHotCategorical as rcat
from torch import logsumexp
import sys
import time
import datetime
import math

# %%
Xs = torch.from_numpy(np.load('circles/obs.npy')).float()
Mus = torch.from_numpy(np.load('circles/mus.npy')).float()
Xs = Xs.transpose(1,2)

B, N, D = Xs.shape

## Model Parameters
NUM_SAMPLES = 10
NUM_HIDDEN = 32
NUM_LATENTS = 2
NUM_OBS = D
NUM_EPOCHS = 25000
LEARNING_RATE = 1e-4
CUDA = False
PATH = 'circles'

# %%
class Encoder(nn.Module):
    def __init__(self, num_obs= NUM_OBS,
                       num_hidden=NUM_HIDDEN,
                       num_latents=NUM_LATENTS):
        super(self.__class__, self).__init__()
        self.enc_h = nn.Sequential(
            nn.Linear(num_obs, num_hidden),
            nn.Tanh())
        self.enc_log_u_a = nn.Sequential(
            nn.Linear(num_hidden, int(0.5*num_hidden)),
            nn.Tanh(),
            nn.Linear(int(0.5*num_hidden), num_latents))
        self.enc_log_u_b = nn.Sequential(
            nn.Linear(num_hidden, int(0.5*num_hidden)),
            nn.Tanh(),
            nn.Linear(int(0.5*num_hidden), num_latents))

    def forward(self, obs, num_samples):
        h = self.enc_h(obs) # (B, H)
        a = torch.exp(self.enc_log_u_a(h)) # (B, 2)
        b = torch.exp(self.enc_log_u_b(h)) # (B, 2)
        q_u = Beta(a, b)
        u = q_u.sample((num_samples,)) # (S, B, 2)
        log_q_u = q_u.log_prob(u).sum(-1)
        return u, log_q_u
    
    
class Decoder(nn.Module):
    def __init__(self, num_obs=D,
                       num_hidden=NUM_HIDDEN,
                       num_latents=NUM_LATENTS):
        super(self.__class__, self).__init__()

        self.x_sigma = 0.01 * torch.ones((N, num_obs))
        self.dec_mu = nn.Sequential(
            nn.Linear(num_latents, num_hidden),
            nn.Tanh(),
            nn.Linear(num_hidden, num_obs))

    def forward(self, u, obs, num_samples):
        mu = self.dec_mu(u) # (S, B, K) -> (S, B, O)
        p_x = Normal(mu, self.x_sigma.repeat(num_samples, 1, 1)) # (S, B, O)
        log_p_x = p_x.log_prob(obs).sum(-1) # (S, B)
        return mu, log_p_x

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Linear') != -1:
        m.weight.data.normal_(0.0, 1e-2)     
        
def initialize():
    enc = Encoder()
    dec = Decoder()
#     enc.apply(weights_init)
    opt1 =  torch.optim.Adam(list(enc.parameters()),lr=LEARNING_RATE, betas=(0.9, 0.99)) 
    opt2 = torch.optim.Adam(list(dec.parameters()),lr=LEARNING_RATE, betas=(0.9, 0.99))
    return enc, dec, opt1, opt2
enc, dec, opt1, opt2 = initialize()

# %%
def oneshot(x, mean, N, D, num_samples):
    data = x - mean

    u, log_q = enc(data, num_samples)
    mu, log_p_x = dec(u, data, num_samples)
    pr_u = Uniform(torch.zeros(N, NUM_LATENTS), torch.ones(N, NUM_LATENTS))
    log_pr_u = pr_u.log_prob(u).sum(-1)
    log_weights = (log_pr_u + log_p_x - log_q)
    weights = torch.exp(log_weights - logsumexp(log_weights, 0)).detach()
    eubo = torch.mul(weights, log_weights).sum(0).mean()
    elbo = log_weights.mean(0).mean()

    return eubo, elbo, mu, u

# %%
ELBOs = []
EUBOs = []
time_start = time.time()

for epoch in range(NUM_EPOCHS):
    for b in range(B):
        X = Xs[b]
        mean = Mus[b]
        indices = torch.randperm(N)
        X_shuffle = X[indices]
        opt1.zero_grad()
        eubo, elbo, mu, u = oneshot(X_shuffle, mean, N, D, NUM_SAMPLES)
        eubo.backward()
        opt1.step()
        opt2.zero_grad()
        eubo, elbo, mu, u = oneshot(X_shuffle, mean, N, D, NUM_SAMPLES)
        (-elbo).backward()
        opt2.step()
    
        ELBOs.append(elbo.item())
        EUBOs.append(eubo.item())
    

    time_end = time.time()  
    print('epoch=%d, EUBO=%.3f, ELBO=%.3f (%ds)' % (epoch, eubo, elbo, time_end - time_start))
    time_start = time.time()
# Out:
# epoch=0, EUBO=-3885.971, ELBO=-4992.250 (1s)
# epoch=1, EUBO=-3645.053, ELBO=-4650.609 (1s)
# epoch=2, EUBO=-3162.197, ELBO=-4262.119 (1s)
# epoch=3, EUBO=-2660.216, ELBO=-3816.616 (1s)
# epoch=4, EUBO=-2188.037, ELBO=-3321.881 (1s)
# epoch=5, EUBO=-1823.715, ELBO=-2888.209 (1s)
# epoch=6, EUBO=-1481.981, ELBO=-2435.780 (1s)
# epoch=7, EUBO=-1180.779, ELBO=-2102.136 (1s)
# epoch=8, EUBO=-943.233, ELBO=-1795.091 (1s)
# epoch=9, EUBO=-727.630, ELBO=-1463.161 (1s)
# epoch=10, EUBO=-543.582, ELBO=-1159.913 (1s)
# epoch=11, EUBO=-413.598, ELBO=-972.828 (1s)
# epoch=12, EUBO=-312.466, ELBO=-866.138 (1s)
# epoch=13, EUBO=-238.926, ELBO=-716.899 (0s)
# epoch=14, EUBO=-188.392, ELBO=-639.786 (0s)
# epoch=15, EUBO=-142.875, ELBO=-576.557 (0s)
# epoch=16, EUBO=-122.317, ELBO=-486.011 (0s)
# epoch=17, EUBO=-107.185, ELBO=-466.349 (0s)
# epoch=18, EUBO=-86.590, ELBO=-378.207 (0s)
# epoch=19, EUBO=-76.600, ELBO=-333.947 (0s)
# epoch=20, EUBO=-67.908, ELBO=-297.793 (0s)
# epoch=21, EUBO=-58.715, ELBO=-270.757 (1s)
# epoch=22, EUBO=-51.276, ELBO=-244.030 (1s)
# epoch=23, EUBO=-47.163, ELBO=-207.675 (1s)
# epoch=24, EUBO=-39.184, ELBO=-189.183 (1s)
# epoch=25, EUBO=-36.816, ELBO=-169.451 (1s)
# epoch=26, EUBO=-32.051, ELBO=-155.233 (1s)
# epoch=27, EUBO=-26.549, ELBO=-136.723 (1s)
# epoch=28, EUBO=-25.070, ELBO=-126.037 (1s)
# epoch=29, EUBO=-21.247, ELBO=-109.894 (1s)
# epoch=30, EUBO=-20.430, ELBO=-106.128 (1s)
# epoch=31, EUBO=-19.219, ELBO=-99.285 (1s)
# epoch=32, EUBO=-15.149, ELBO=-84.193 (1s)
# epoch=33, EUBO=-14.688, ELBO=-78.068 (1s)
# epoch=34, EUBO=-13.659, ELBO=-71.027 (1s)
# epoch=35, EUBO=-11.869, ELBO=-66.081 (1s)
# epoch=36, EUBO=-10.081, ELBO=-61.924 (1s)
# epoch=37, EUBO=-9.630, ELBO=-57.971 (1s)
# epoch=38, EUBO=-8.874, ELBO=-52.211 (1s)
# epoch=39, EUBO=-8.683, ELBO=-49.590 (1s)
# epoch=40, EUBO=-7.437, ELBO=-45.864 (1s)
# epoch=41, EUBO=-6.971, ELBO=-42.820 (1s)
# epoch=42, EUBO=-6.267, ELBO=-40.065 (1s)
# epoch=43, EUBO=-5.494, ELBO=-37.473 (1s)
# epoch=44, EUBO=-4.534, ELBO=-34.694 (1s)
# epoch=45, EUBO=-4.446, ELBO=-32.957 (1s)
# epoch=46, EUBO=-3.899, ELBO=-29.761 (1s)
# epoch=47, EUBO=-3.785, ELBO=-29.733 (1s)
# epoch=48, EUBO=-3.241, ELBO=-27.136 (1s)
# epoch=49, EUBO=-2.569, ELBO=-24.693 (1s)
# epoch=50, EUBO=-2.575, ELBO=-23.911 (1s)
# epoch=51, EUBO=-2.310, ELBO=-23.221 (1s)
# epoch=52, EUBO=-2.596, ELBO=-21.421 (0s)
# epoch=53, EUBO=-2.096, ELBO=-20.793 (0s)
# epoch=54, EUBO=-1.858, ELBO=-19.451 (0s)
# epoch=55, EUBO=-1.797, ELBO=-18.370 (0s)
# epoch=56, EUBO=-1.499, ELBO=-16.898 (0s)
# epoch=57, EUBO=-1.598, ELBO=-17.089 (0s)
# epoch=58, EUBO=-1.495, ELBO=-16.206 (0s)
# epoch=59, EUBO=-1.294, ELBO=-15.206 (1s)
# epoch=60, EUBO=-1.490, ELBO=-15.337 (1s)
# epoch=61, EUBO=-1.300, ELBO=-13.273 (1s)
# epoch=62, EUBO=-1.227, ELBO=-13.554 (1s)
# epoch=63, EUBO=-1.138, ELBO=-12.135 (1s)
# epoch=64, EUBO=-1.142, ELBO=-11.586 (1s)
# epoch=65, EUBO=-1.208, ELBO=-11.656 (1s)
# epoch=66, EUBO=-1.029, ELBO=-11.487 (1s)
# epoch=67, EUBO=-1.095, ELBO=-11.288 (1s)
# epoch=68, EUBO=-1.215, ELBO=-9.643 (1s)
# epoch=69, EUBO=-1.166, ELBO=-9.982 (1s)
# epoch=70, EUBO=-1.016, ELBO=-9.544 (1s)
# epoch=71, EUBO=-1.131, ELBO=-9.240 (1s)
# epoch=72, EUBO=-0.950, ELBO=-9.432 (1s)
# epoch=73, EUBO=-1.033, ELBO=-8.692 (1s)
# epoch=74, EUBO=-1.010, ELBO=-8.485 (1s)
# epoch=75, EUBO=-1.070, ELBO=-8.238 (1s)
# epoch=76, EUBO=-0.910, ELBO=-7.522 (1s)
# epoch=77, EUBO=-0.987, ELBO=-7.509 (1s)
# epoch=78, EUBO=-0.984, ELBO=-7.602 (1s)
# epoch=79, EUBO=-0.926, ELBO=-6.755 (1s)
# epoch=80, EUBO=-1.170, ELBO=-6.906 (1s)
# epoch=81, EUBO=-1.045, ELBO=-6.686 (1s)
# epoch=82, EUBO=-1.024, ELBO=-6.442 (1s)
# epoch=83, EUBO=-0.971, ELBO=-6.619 (1s)
# epoch=84, EUBO=-1.091, ELBO=-6.120 (0s)
# epoch=85, EUBO=-1.062, ELBO=-6.168 (0s)
# epoch=86, EUBO=-0.974, ELBO=-5.905 (1s)
# epoch=87, EUBO=-0.983, ELBO=-5.888 (1s)
# epoch=88, EUBO=-0.954, ELBO=-5.513 (1s)
# epoch=89, EUBO=-1.033, ELBO=-5.572 (1s)
# epoch=90, EUBO=-0.975, ELBO=-5.511 (1s)
# epoch=91, EUBO=-1.029, ELBO=-5.204 (1s)
# epoch=92, EUBO=-1.004, ELBO=-5.599 (0s)
# epoch=93, EUBO=-1.017, ELBO=-5.061 (0s)
# epoch=94, EUBO=-1.065, ELBO=-4.921 (0s)
# epoch=95, EUBO=-1.193, ELBO=-5.203 (0s)
# epoch=96, EUBO=-1.119, ELBO=-5.104 (0s)
# epoch=97, EUBO=-1.035, ELBO=-4.875 (0s)
# epoch=98, EUBO=-1.052, ELBO=-4.667 (0s)
# epoch=99, EUBO=-1.136, ELBO=-4.283 (0s)
# epoch=100, EUBO=-1.416, ELBO=-5.155 (0s)
# epoch=101, EUBO=-0.946, ELBO=-4.908 (1s)
# epoch=102, EUBO=-1.200, ELBO=-4.776 (1s)
# epoch=103, EUBO=-1.136, ELBO=-4.545 (1s)
# epoch=104, EUBO=-1.022, ELBO=-4.464 (1s)
# epoch=105, EUBO=-1.224, ELBO=-4.631 (1s)
# epoch=106, EUBO=-1.363, ELBO=-4.844 (1s)
# epoch=107, EUBO=-1.051, ELBO=-4.849 (1s)
# epoch=108, EUBO=-1.151, ELBO=-4.447 (1s)
# epoch=109, EUBO=-1.097, ELBO=-3.893 (1s)
# epoch=110, EUBO=-1.259, ELBO=-4.036 (1s)
# epoch=111, EUBO=-1.180, ELBO=-3.758 (1s)
# epoch=112, EUBO=-1.234, ELBO=-3.971 (1s)
# epoch=113, EUBO=-1.192, ELBO=-4.294 (1s)
# epoch=114, EUBO=-1.293, ELBO=-4.064 (1s)
# epoch=115, EUBO=-1.257, ELBO=-4.000 (1s)
# epoch=116, EUBO=-1.115, ELBO=-4.068 (1s)
# epoch=117, EUBO=-1.200, ELBO=-3.915 (1s)
# epoch=118, EUBO=-1.232, ELBO=-3.813 (1s)
# epoch=119, EUBO=-1.328, ELBO=-3.903 (1s)
# epoch=120, EUBO=-1.378, ELBO=-3.850 (1s)
# epoch=121, EUBO=-1.117, ELBO=-3.883 (1s)
# epoch=122, EUBO=-1.173, ELBO=-3.661 (1s)
# epoch=123, EUBO=-1.452, ELBO=-4.020 (1s)
# epoch=124, EUBO=-1.233, ELBO=-4.033 (1s)
# epoch=125, EUBO=-1.200, ELBO=-3.386 (1s)
# epoch=126, EUBO=-1.197, ELBO=-3.749 (1s)
# epoch=127, EUBO=-1.279, ELBO=-3.545 (1s)
# epoch=128, EUBO=-1.452, ELBO=-3.741 (1s)
# epoch=129, EUBO=-1.208, ELBO=-4.289 (1s)
# epoch=130, EUBO=-1.191, ELBO=-3.905 (1s)
# epoch=131, EUBO=-1.244, ELBO=-3.690 (1s)
# epoch=132, EUBO=-1.358, ELBO=-3.417 (1s)
# epoch=133, EUBO=-1.369, ELBO=-3.521 (1s)
# epoch=134, EUBO=-1.430, ELBO=-4.133 (1s)
# epoch=135, EUBO=-1.210, ELBO=-4.072 (1s)
# epoch=136, EUBO=-1.207, ELBO=-3.740 (1s)
# epoch=137, EUBO=-1.264, ELBO=-3.462 (1s)
# epoch=138, EUBO=-1.300, ELBO=-3.713 (1s)
# epoch=139, EUBO=-1.254, ELBO=-3.341 (1s)
# epoch=140, EUBO=-1.412, ELBO=-3.290 (1s)
# epoch=141, EUBO=-1.277, ELBO=-3.256 (1s)
# epoch=142, EUBO=-1.438, ELBO=-3.088 (1s)
# epoch=143, EUBO=-1.407, ELBO=-3.449 (1s)
# epoch=144, EUBO=-1.320, ELBO=-3.743 (1s)
# epoch=145, EUBO=-1.097, ELBO=-3.950 (1s)
# epoch=146, EUBO=-1.321, ELBO=-3.239 (1s)
# epoch=147, EUBO=-1.448, ELBO=-3.121 (1s)
# epoch=148, EUBO=-1.328, ELBO=-3.570 (1s)
# epoch=149, EUBO=-1.351, ELBO=-3.976 (1s)
# epoch=150, EUBO=-1.297, ELBO=-3.209 (1s)
# epoch=151, EUBO=-1.353, ELBO=-2.869 (1s)
# epoch=152, EUBO=-1.461, ELBO=-2.943 (1s)
# epoch=153, EUBO=-1.357, ELBO=-3.222 (1s)
# epoch=154, EUBO=-1.398, ELBO=-3.483 (1s)
# epoch=155, EUBO=-1.229, ELBO=-3.835 (1s)
# epoch=156, EUBO=-1.265, ELBO=-3.518 (0s)
# epoch=157, EUBO=-1.252, ELBO=-3.166 (0s)
# epoch=158, EUBO=-1.321, ELBO=-2.945 (0s)
# epoch=159, EUBO=-1.419, ELBO=-2.838 (1s)
# epoch=160, EUBO=-1.369, ELBO=-2.995 (1s)
# epoch=161, EUBO=-1.539, ELBO=-3.112 (1s)
# epoch=162, EUBO=-1.361, ELBO=-3.343 (1s)
# epoch=163, EUBO=-1.337, ELBO=-3.665 (1s)
# epoch=164, EUBO=-1.255, ELBO=-3.189 (0s)
# epoch=165, EUBO=-1.532, ELBO=-2.888 (0s)
# epoch=166, EUBO=-1.416, ELBO=-3.181 (0s)
# epoch=167, EUBO=-1.326, ELBO=-3.702 (0s)
# epoch=168, EUBO=-1.266, ELBO=-3.201 (1s)
# epoch=169, EUBO=-1.330, ELBO=-2.961 (1s)
# epoch=170, EUBO=-1.345, ELBO=-2.721 (1s)
# epoch=171, EUBO=-1.542, ELBO=-3.016 (1s)
# epoch=172, EUBO=-1.412, ELBO=-3.343 (1s)
# epoch=173, EUBO=-1.348, ELBO=-3.779 (1s)
# epoch=174, EUBO=-1.336, ELBO=-3.602 (1s)
# epoch=175, EUBO=-1.287, ELBO=-3.573 (1s)
# epoch=176, EUBO=-1.418, ELBO=-2.825 (1s)
# epoch=177, EUBO=-1.446, ELBO=-2.657 (1s)
# epoch=178, EUBO=-1.535, ELBO=-2.744 (1s)
# epoch=179, EUBO=-1.479, ELBO=-2.874 (1s)
# epoch=180, EUBO=-1.403, ELBO=-3.649 (0s)
# epoch=181, EUBO=-1.341, ELBO=-3.594 (0s)
# epoch=182, EUBO=-1.423, ELBO=-2.749 (0s)
# epoch=183, EUBO=-1.497, ELBO=-2.804 (0s)
# epoch=184, EUBO=-1.524, ELBO=-2.670 (0s)
# epoch=185, EUBO=-1.521, ELBO=-2.865 (0s)
# epoch=186, EUBO=-1.322, ELBO=-3.147 (0s)
# epoch=187, EUBO=-1.360, ELBO=-3.326 (0s)
# epoch=188, EUBO=-1.348, ELBO=-2.994 (1s)
# epoch=189, EUBO=-1.517, ELBO=-2.591 (1s)
# epoch=190, EUBO=-1.510, ELBO=-2.674 (1s)
# epoch=191, EUBO=-1.468, ELBO=-2.806 (1s)
# epoch=192, EUBO=-1.413, ELBO=-3.303 (1s)
# epoch=193, EUBO=-1.387, ELBO=-3.429 (1s)
# epoch=194, EUBO=-1.331, ELBO=-3.021 (1s)
# epoch=195, EUBO=-1.458, ELBO=-2.687 (1s)
# epoch=196, EUBO=-1.418, ELBO=-2.572 (1s)
# epoch=197, EUBO=-1.500, ELBO=-2.595 (1s)
# epoch=198, EUBO=-1.509, ELBO=-2.627 (1s)
# epoch=199, EUBO=-1.545, ELBO=-2.651 (1s)
# epoch=200, EUBO=-1.413, ELBO=-3.579 (1s)
# epoch=201, EUBO=-1.469, ELBO=-3.045 (1s)
# epoch=202, EUBO=-1.440, ELBO=-2.951 (1s)
# epoch=203, EUBO=-1.397, ELBO=-2.525 (1s)
# epoch=204, EUBO=-1.476, ELBO=-2.719 (1s)
# epoch=205, EUBO=-1.527, ELBO=-2.884 (1s)
# epoch=206, EUBO=-1.376, ELBO=-3.150 (1s)
# epoch=207, EUBO=-1.376, ELBO=-3.657 (1s)
# epoch=208, EUBO=-1.270, ELBO=-3.458 (1s)
# epoch=209, EUBO=-1.312, ELBO=-3.324 (1s)
# epoch=210, EUBO=-1.361, ELBO=-2.978 (1s)
# epoch=211, EUBO=-1.394, ELBO=-3.091 (1s)
# epoch=212, EUBO=-1.388, ELBO=-2.497 (1s)
# epoch=213, EUBO=-1.540, ELBO=-2.594 (1s)
# epoch=214, EUBO=-1.536, ELBO=-2.429 (1s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-94295ed5a2db> in <module>
#      10         X_shuffle = X[indices]
#      11         opt1.zero_grad()
# ---> 12         eubo, elbo, mu, u = oneshot(X_shuffle, mean, N, D, NUM_SAMPLES)
#      13         eubo.backward()
#      14         opt1.step()
#
# <ipython-input-5-86f89c6bb968> in oneshot(x, mean, N, D, num_samples)
#       2     data = x - mean
#       3
# ----> 4     u, log_q = enc(data, num_samples)
#       5     mu, log_p_x = dec(u, data, num_samples)
#       6     pr_u = Uniform(torch.zeros(N, NUM_LATENTS), torch.ones(N, NUM_LATENTS))
#
# ~/.conda/envs/dev/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-3-4577e4f20f98> in forward(self, obs, num_samples)
#      21         b = torch.exp(self.enc_log_u_b(h)) # (B, 2)
#      22         q_u = Beta(a, b)
# ---> 23         u = q_u.sample((num_samples,)) # (S, B, 2)
#      24         log_q_u = q_u.log_prob(u).sum(-1)
#      25         return u, log_q_u
#
# ~/.conda/envs/dev/lib/python3.6/site-packages/torch/distributions/distribution.py in sample(self, sample_shape)
#     116         """
#     117         with torch.no_grad():
# --> 118             return self.rsample(sample_shape)
#     119
#     120     def rsample(self, sample_shape=torch.Size()):
#
# ~/.conda/envs/dev/lib/python3.6/site-packages/torch/distributions/beta.py in rsample(self, sample_shape)
#      56
#      57     def rsample(self, sample_shape=()):
# ---> 58         value = self._dirichlet.rsample(sample_shape).select(-1, 0)
#      59         if isinstance(value, Number):
#      60             value = self._dirichlet.concentration.new_tensor(value)
#
# ~/.conda/envs/dev/lib/python3.6/site-packages/torch/distributions/dirichlet.py in rsample(self, sample_shape)
#      73         concentration = self.concentration.expand(shape)
#      74         if isinstance(concentration, torch.Tensor):
# ---> 75             return _Dirichlet.apply(concentration)
#      76         return _dirichlet_sample_nograd(concentration)
#      77
#
# ~/.conda/envs/dev/lib/python3.6/site-packages/torch/distributions/dirichlet.py in forward(ctx, concentration)
#      25     @staticmethod
#      26     def forward(ctx, concentration):
# ---> 27         x = _dirichlet_sample_nograd(concentration)
#      28         ctx.save_for_backward(x, concentration)
#      29         return x
#
# ~/.conda/envs/dev/lib/python3.6/site-packages/torch/distributions/dirichlet.py in _dirichlet_sample_nograd(concentration)
#      10
#      11 def _dirichlet_sample_nograd(concentration):
# ---> 12     probs = torch._standard_gamma(concentration)
#      13     probs /= probs.sum(-1, True)
#      14     return clamp_probs(probs)
#
# KeyboardInterrupt:

# %%
torch.save(enc.state_dict(), 'VAE/enc-circle')
torch.save(dec.state_dict(), 'VAE/dec-circle')

# %%
P = 2
eubo, elbo, mu, u = oneshot(Xs[P], Mus[P], N, D, NUM_SAMPLES)

# %%
T = 80
fig = plt.figure(figsize=(18,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)   
ax3 = fig.add_subplot(1,3,3)
ax1.scatter(Xs[P,:T, 0].data.numpy(), Xs[P, :T, 1].data.numpy())
ax1.set_xlim([-2,2])
ax1.set_ylim([-2,2])
ax1.set_title('data')

uu = u.mean(0)
ax2.plot(uu[:T, 0].data.numpy(), 'go')
ax2.plot(uu[:T, 1].data.numpy(), 'ro')

ax3.scatter(uu[:T, 0].data.numpy(), uu[:T, 1].data.numpy())
