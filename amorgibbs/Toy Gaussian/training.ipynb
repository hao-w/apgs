# %%
import matplotlib.pyplot as plt
import time
import torch
from torch import logsumexp
from torch.distributions.normal import Normal
import numpy as np
from utils import *
from plots import *
from objectives import *

# %%
## training parameters
STEPS = 10000
NUM_SAMPLES = 5
NUM_SAMPLES_SNR = 100
LEARNING_RATE = 1e-3
## model parameters
p_mu = torch.tensor([0.0])
p_sigma = torch.tensor([1.0])
q_mu = torch.tensor([3.0], requires_grad=True)
q_sigma = torch.tensor([2.0], requires_grad=True) 
## initialize optimizer
optimizer = torch.optim.SGD([q_mu, q_sigma], lr=LEARNING_RATE)
## estimators
ests = ['mc', 'iwae', 'iwae-dreg', 'rws', 'rws-dreg', 'stl']

# %%
dEUBOs = dict()
dELBOs = dict()
dIWELBOs = dict()
dSNRs = dict()
dVARs = dict()
dESSs = dict()

for est in ests:
    ## model parameters
    p_mu = torch.tensor([0.0])
    p_sigma = torch.tensor([1.0])
    q_mu = torch.tensor([4.0], requires_grad=True)
    q_sigma = torch.tensor([2.0], requires_grad=True) 
    ## initialize optimizer
    optimizer = torch.optim.SGD([q_mu, q_sigma], lr=LEARNING_RATE)
    print('======= start training by %s ========\n' % est)
    if est == 'mc':
        EUBOs, ELBOs, IWELBOs, ESSs, SNRs, VARs = train(mc, q_mu, q_sigma, p_mu, p_sigma, STEPS, NUM_SAMPLES, NUM_SAMPLES_SNR, optimizer, filename=est, alpha=None)        
    elif est == 'iwae':
        EUBOs, ELBOs, IWELBOs, ESSs, SNRs, VARs = train(iwae, q_mu, q_sigma, p_mu, p_sigma, STEPS, NUM_SAMPLES, NUM_SAMPLES_SNR, optimizer, filename=est, alpha=None)        
    elif est == 'iwae-dreg':
        EUBOs, ELBOs, IWELBOs, ESSs, SNRs, VARs = train(dreg, q_mu, q_sigma, p_mu, p_sigma, STEPS, NUM_SAMPLES, NUM_SAMPLES_SNR, optimizer, filename=est, alpha=0.0)        
    elif est == 'rws':
        EUBOs, ELBOs, IWELBOs, ESSs, SNRs, VARs = train(rws, q_mu, q_sigma, p_mu, p_sigma, STEPS, NUM_SAMPLES, NUM_SAMPLES_SNR, optimizer, filename=est, alpha=None)      
    elif est == 'rws-dreg':
        EUBOs, ELBOs, IWELBOs, ESSs, SNRs, VARs = train(dreg, q_mu, q_sigma, p_mu, p_sigma, STEPS, NUM_SAMPLES, NUM_SAMPLES_SNR, optimizer, filename=est, alpha=1.0)      
    elif est == 'stl':
        EUBOs, ELBOs, IWELBOs, ESSs, SNRs, VARs = train(dreg, q_mu, q_sigma, p_mu, p_sigma, STEPS, NUM_SAMPLES, NUM_SAMPLES_SNR, optimizer, filename=est, alpha=0.5)      
    
    dEUBOs[est] = EUBOs
    dELBOs[est] = ELBOs
    dIWELBOs[est] = IWELBOs
    dSNRs[est] = SNRs
    dVARs[est] = VARs
    dESSs[est] = ESSs
    print('======= end training by %s ========\n' % est)
# Out:
# ======= start training by mc ========
#
# iteration:0, EUBO:-0.812, ELBO:-11.354, IWELBO:-2.061, ESS:1.259 (0s)
# iteration:100, EUBO:-2.127, ELBO:-7.757, IWELBO:-3.317, ESS:1.260 (9s)
# iteration:200, EUBO:0.244, ELBO:-4.702, IWELBO:-1.204, ESS:1.068 (9s)
# iteration:300, EUBO:1.570, ELBO:-2.582, IWELBO:0.263, ESS:1.170 (9s)
# iteration:400, EUBO:3.042, ELBO:-1.214, IWELBO:1.713, ESS:1.144 (10s)
# iteration:500, EUBO:2.995, ELBO:-4.537, IWELBO:1.582, ESS:1.103 (9s)
# iteration:600, EUBO:1.006, ELBO:0.576, IWELBO:0.804, ESS:3.578 (9s)
# iteration:700, EUBO:0.094, ELBO:-0.756, IWELBO:-0.338, ESS:2.399 (10s)
# iteration:800, EUBO:0.192, ELBO:-0.795, IWELBO:-0.275, ESS:2.364 (9s)
# iteration:900, EUBO:1.732, ELBO:-0.741, IWELBO:0.690, ESS:1.349 (9s)
# iteration:1000, EUBO:1.864, ELBO:0.880, IWELBO:1.482, ESS:2.984 (9s)
# iteration:1100, EUBO:2.182, ELBO:0.801, IWELBO:1.548, ESS:2.002 (10s)
# iteration:1200, EUBO:1.960, ELBO:0.084, IWELBO:1.248, ESS:2.143 (9s)
# iteration:1300, EUBO:0.465, ELBO:0.302, IWELBO:0.386, ESS:4.320 (9s)
# iteration:1400, EUBO:1.524, ELBO:1.073, IWELBO:1.329, ESS:3.678 (10s)
# iteration:1500, EUBO:1.601, ELBO:0.859, IWELBO:1.278, ESS:3.089 (9s)
# iteration:1600, EUBO:0.916, ELBO:0.838, IWELBO:0.878, ESS:4.664 (9s)
# iteration:1700, EUBO:1.279, ELBO:0.980, IWELBO:1.149, ESS:4.066 (9s)
# iteration:1800, EUBO:1.114, ELBO:0.861, IWELBO:0.985, ESS:3.882 (10s)
# iteration:1900, EUBO:0.895, ELBO:0.554, IWELBO:0.761, ESS:4.150 (9s)
# iteration:2000, EUBO:1.283, ELBO:1.171, IWELBO:1.227, ESS:4.495 (9s)
# iteration:2100, EUBO:1.083, ELBO:0.672, IWELBO:0.885, ESS:3.551 (9s)
# iteration:2200, EUBO:0.957, ELBO:0.854, IWELBO:0.906, ESS:4.534 (9s)
# iteration:2300, EUBO:0.761, ELBO:0.373, IWELBO:0.576, ESS:3.657 (10s)
# iteration:2400, EUBO:0.974, ELBO:0.828, IWELBO:0.901, ESS:4.332 (10s)
# iteration:2500, EUBO:1.074, ELBO:1.006, IWELBO:1.041, ESS:4.689 (10s)
# iteration:2600, EUBO:0.958, ELBO:0.873, IWELBO:0.918, ESS:4.651 (9s)
# iteration:2700, EUBO:0.914, ELBO:0.867, IWELBO:0.891, ESS:4.777 (9s)
# iteration:2800, EUBO:0.812, ELBO:0.753, IWELBO:0.783, ESS:4.726 (8s)
# iteration:2900, EUBO:0.800, ELBO:0.725, IWELBO:0.764, ESS:4.684 (10s)
# iteration:3000, EUBO:0.780, ELBO:0.773, IWELBO:0.776, ESS:4.965 (10s)
# iteration:3100, EUBO:1.076, ELBO:1.054, IWELBO:1.064, ESS:4.885 (9s)
# iteration:3200, EUBO:0.804, ELBO:0.790, IWELBO:0.797, ESS:4.927 (9s)
# iteration:3300, EUBO:0.913, ELBO:0.896, IWELBO:0.905, ESS:4.921 (9s)
# iteration:3400, EUBO:0.920, ELBO:0.890, IWELBO:0.905, ESS:4.852 (8s)
# iteration:3500, EUBO:0.937, ELBO:0.918, IWELBO:0.928, ESS:4.902 (9s)
# iteration:3600, EUBO:0.893, ELBO:0.884, IWELBO:0.888, ESS:4.953 (9s)
# iteration:3700, EUBO:0.874, ELBO:0.853, IWELBO:0.863, ESS:4.888 (10s)
# iteration:3800, EUBO:0.943, ELBO:0.941, IWELBO:0.942, ESS:4.991 (9s)
# iteration:3900, EUBO:0.868, ELBO:0.862, IWELBO:0.865, ESS:4.967 (9s)
# iteration:4000, EUBO:0.876, ELBO:0.868, IWELBO:0.872, ESS:4.962 (9s)
# iteration:4100, EUBO:0.913, ELBO:0.911, IWELBO:0.912, ESS:4.988 (9s)
# iteration:4200, EUBO:0.959, ELBO:0.958, IWELBO:0.958, ESS:4.994 (9s)
# iteration:4300, EUBO:0.895, ELBO:0.892, IWELBO:0.894, ESS:4.987 (9s)
# iteration:4400, EUBO:0.930, ELBO:0.929, IWELBO:0.929, ESS:4.996 (10s)
# iteration:4500, EUBO:0.914, ELBO:0.914, IWELBO:0.914, ESS:4.998 (9s)
# iteration:4600, EUBO:0.899, ELBO:0.898, IWELBO:0.898, ESS:4.996 (10s)
# iteration:4700, EUBO:0.924, ELBO:0.924, IWELBO:0.924, ESS:4.999 (8s)
# iteration:4800, EUBO:0.922, ELBO:0.919, IWELBO:0.921, ESS:4.985 (9s)
# iteration:4900, EUBO:0.895, ELBO:0.892, IWELBO:0.894, ESS:4.984 (9s)
# iteration:5000, EUBO:0.943, ELBO:0.943, IWELBO:0.943, ESS:5.000 (9s)
# iteration:5100, EUBO:0.917, ELBO:0.915, IWELBO:0.916, ESS:4.990 (10s)
# iteration:5200, EUBO:0.935, ELBO:0.935, IWELBO:0.935, ESS:4.999 (10s)
# iteration:5300, EUBO:0.895, ELBO:0.893, IWELBO:0.894, ESS:4.992 (9s)
# iteration:5400, EUBO:0.929, ELBO:0.928, IWELBO:0.928, ESS:4.998 (9s)
# iteration:5500, EUBO:0.906, ELBO:0.906, IWELBO:0.906, ESS:4.997 (10s)
# iteration:5600, EUBO:0.915, ELBO:0.914, IWELBO:0.915, ESS:4.997 (9s)
# iteration:5700, EUBO:0.910, ELBO:0.910, IWELBO:0.910, ESS:4.999 (10s)
# iteration:5800, EUBO:0.963, ELBO:0.958, IWELBO:0.961, ESS:4.978 (9s)
# iteration:5900, EUBO:0.923, ELBO:0.921, IWELBO:0.922, ESS:4.995 (10s)
# iteration:6000, EUBO:0.908, ELBO:0.907, IWELBO:0.907, ESS:4.997 (10s)
# iteration:6100, EUBO:0.929, ELBO:0.929, IWELBO:0.929, ESS:5.000 (9s)
# iteration:6200, EUBO:0.913, ELBO:0.913, IWELBO:0.913, ESS:4.998 (9s)
# iteration:6300, EUBO:0.926, ELBO:0.926, IWELBO:0.926, ESS:4.998 (6s)
# iteration:6400, EUBO:0.889, ELBO:0.888, IWELBO:0.889, ESS:4.999 (9s)
# iteration:6500, EUBO:0.905, ELBO:0.904, IWELBO:0.905, ESS:4.999 (9s)
# iteration:6600, EUBO:0.926, ELBO:0.925, IWELBO:0.925, ESS:4.997 (10s)
# iteration:6700, EUBO:0.894, ELBO:0.894, IWELBO:0.894, ESS:5.000 (9s)
# iteration:6800, EUBO:0.919, ELBO:0.919, IWELBO:0.919, ESS:4.999 (9s)
# iteration:6900, EUBO:0.906, ELBO:0.906, IWELBO:0.906, ESS:4.999 (9s)
# iteration:7000, EUBO:0.917, ELBO:0.917, IWELBO:0.917, ESS:4.999 (8s)
# iteration:7100, EUBO:0.924, ELBO:0.923, IWELBO:0.923, ESS:4.995 (8s)
# iteration:7200, EUBO:0.929, ELBO:0.926, IWELBO:0.928, ESS:4.986 (10s)
# iteration:7300, EUBO:0.937, ELBO:0.934, IWELBO:0.935, ESS:4.987 (9s)
# iteration:7400, EUBO:0.922, ELBO:0.922, IWELBO:0.922, ESS:4.997 (9s)
# iteration:7500, EUBO:0.917, ELBO:0.917, IWELBO:0.917, ESS:4.999 (9s)
# iteration:7600, EUBO:0.962, ELBO:0.960, IWELBO:0.961, ESS:4.987 (9s)
# iteration:7700, EUBO:0.927, ELBO:0.927, IWELBO:0.927, ESS:4.996 (9s)
# iteration:7800, EUBO:0.923, ELBO:0.922, IWELBO:0.922, ESS:4.997 (9s)
# iteration:7900, EUBO:0.913, ELBO:0.913, IWELBO:0.913, ESS:4.999 (8s)
# iteration:8000, EUBO:0.928, ELBO:0.928, IWELBO:0.928, ESS:5.000 (8s)
# iteration:8100, EUBO:0.925, ELBO:0.925, IWELBO:0.925, ESS:5.000 (9s)
# iteration:8200, EUBO:0.923, ELBO:0.922, IWELBO:0.923, ESS:4.997 (10s)
# iteration:8300, EUBO:0.928, ELBO:0.927, IWELBO:0.928, ESS:4.998 (9s)
# iteration:8400, EUBO:0.911, ELBO:0.910, IWELBO:0.910, ESS:4.995 (9s)
# iteration:8500, EUBO:0.932, ELBO:0.932, IWELBO:0.932, ESS:5.000 (9s)
# iteration:8600, EUBO:0.908, ELBO:0.906, IWELBO:0.907, ESS:4.994 (10s)
# iteration:8700, EUBO:0.929, ELBO:0.929, IWELBO:0.929, ESS:5.000 (9s)
# iteration:8800, EUBO:0.930, ELBO:0.930, IWELBO:0.930, ESS:5.000 (10s)
# iteration:8900, EUBO:0.918, ELBO:0.917, IWELBO:0.918, ESS:4.998 (9s)
# iteration:9000, EUBO:0.923, ELBO:0.922, IWELBO:0.923, ESS:5.000 (9s)
# iteration:9100, EUBO:0.926, ELBO:0.926, IWELBO:0.926, ESS:5.000 (9s)
# iteration:9200, EUBO:0.916, ELBO:0.916, IWELBO:0.916, ESS:5.000 (9s)
# iteration:9300, EUBO:0.925, ELBO:0.925, IWELBO:0.925, ESS:5.000 (9s)
# iteration:9400, EUBO:0.931, ELBO:0.931, IWELBO:0.931, ESS:5.000 (9s)
# iteration:9500, EUBO:0.911, ELBO:0.910, IWELBO:0.910, ESS:4.997 (9s)
# iteration:9600, EUBO:0.922, ELBO:0.922, IWELBO:0.922, ESS:5.000 (9s)
# iteration:9700, EUBO:0.928, ELBO:0.928, IWELBO:0.928, ESS:4.999 (10s)
# iteration:9800, EUBO:0.927, ELBO:0.927, IWELBO:0.927, ESS:4.999 (9s)
# iteration:9900, EUBO:0.927, ELBO:0.927, IWELBO:0.927, ESS:5.000 (9s)
# ======= end training by mc ========
#
# ======= start training by iwae ========
#
# iteration:0, EUBO:1.708, ELBO:-5.106, IWELBO:0.429, ESS:1.224 (0s)
# iteration:100, EUBO:-2.504, ELBO:-17.087, IWELBO:-3.496, ESS:1.741 (9s)
# iteration:200, EUBO:-0.078, ELBO:-11.172, IWELBO:-1.071, ESS:1.743 (10s)
# iteration:300, EUBO:1.069, ELBO:-0.211, IWELBO:0.634, ESS:2.955 (10s)
# iteration:400, EUBO:2.810, ELBO:-4.481, IWELBO:1.823, ESS:1.692 (10s)
# iteration:500, EUBO:2.664, ELBO:-5.654, IWELBO:1.715, ESS:1.779 (10s)
# iteration:600, EUBO:2.585, ELBO:-5.226, IWELBO:1.375, ESS:1.297 (10s)
# iteration:700, EUBO:1.852, ELBO:-7.429, IWELBO:0.406, ESS:1.077 (9s)
# iteration:800, EUBO:1.993, ELBO:-12.366, IWELBO:0.385, ESS:1.000 (10s)
# iteration:900, EUBO:-2.642, ELBO:-8.495, IWELBO:-3.572, ESS:1.633 (9s)
# iteration:1000, EUBO:2.587, ELBO:-3.395, IWELBO:1.670, ESS:1.967 (10s)
# iteration:1100, EUBO:0.298, ELBO:-10.300, IWELBO:-1.186, ESS:1.056 (10s)
# iteration:1200, EUBO:1.563, ELBO:-4.856, IWELBO:0.237, ESS:1.167 (10s)
# iteration:1300, EUBO:1.883, ELBO:-7.437, IWELBO:0.372, ESS:1.041 (9s)
# iteration:1400, EUBO:1.962, ELBO:-5.195, IWELBO:0.396, ESS:1.013 (9s)
# iteration:1500, EUBO:0.700, ELBO:-12.313, IWELBO:-0.448, ESS:1.403 (10s)
# iteration:1600, EUBO:2.341, ELBO:0.239, IWELBO:1.872, ESS:2.958 (9s)
# iteration:1700, EUBO:-0.344, ELBO:-7.788, IWELBO:-1.806, ESS:1.067 (9s)
# iteration:1800, EUBO:-4.573, ELBO:-7.861, IWELBO:-5.265, ESS:2.204 (10s)
# iteration:1900, EUBO:1.015, ELBO:-7.599, IWELBO:-0.481, ESS:1.041 (10s)
# iteration:2000, EUBO:2.065, ELBO:-4.514, IWELBO:0.670, ESS:1.095 (10s)
# iteration:2100, EUBO:1.312, ELBO:-14.861, IWELBO:-0.285, ESS:1.003 (10s)
# iteration:2200, EUBO:1.733, ELBO:-0.791, IWELBO:0.885, ESS:1.675 (10s)
# iteration:2300, EUBO:2.303, ELBO:-3.200, IWELBO:1.527, ESS:2.163 (10s)
# iteration:2400, EUBO:2.176, ELBO:-2.253, IWELBO:1.664, ESS:2.972 (10s)
# iteration:2500, EUBO:2.234, ELBO:-5.943, IWELBO:1.997, ESS:3.895 (9s)
# iteration:2600, EUBO:2.037, ELBO:-2.727, IWELBO:1.535, ESS:2.902 (10s)
# iteration:2700, EUBO:2.080, ELBO:-5.170, IWELBO:1.260, ESS:2.073 (10s)
# iteration:2800, EUBO:0.877, ELBO:-6.270, IWELBO:-0.396, ESS:1.225 (10s)
# iteration:2900, EUBO:2.288, ELBO:-8.062, IWELBO:0.715, ESS:1.012 (10s)
# iteration:3000, EUBO:1.873, ELBO:-0.801, IWELBO:1.353, ESS:2.655 (10s)
# iteration:3100, EUBO:1.451, ELBO:-2.481, IWELBO:0.690, ESS:1.856 (10s)
# iteration:3200, EUBO:0.898, ELBO:-8.031, IWELBO:-0.242, ESS:1.309 (8s)
# iteration:3300, EUBO:1.874, ELBO:-1.841, IWELBO:0.784, ESS:1.328 (10s)
# iteration:3400, EUBO:1.736, ELBO:-0.416, IWELBO:1.033, ESS:1.924 (10s)
# iteration:3500, EUBO:2.088, ELBO:-7.298, IWELBO:0.603, ESS:1.053 (10s)
# iteration:3600, EUBO:1.764, ELBO:-0.370, IWELBO:1.265, ESS:2.588 (10s)
# iteration:3700, EUBO:1.921, ELBO:-0.538, IWELBO:1.200, ESS:2.183 (10s)
# iteration:3800, EUBO:-6.526, ELBO:-12.055, IWELBO:-7.893, ESS:1.127 (10s)
# iteration:3900, EUBO:0.306, ELBO:-6.347, IWELBO:-1.200, ESS:1.038 (6s)
# iteration:4000, EUBO:1.493, ELBO:-0.565, IWELBO:0.800, ESS:2.044 (6s)
# iteration:4100, EUBO:1.985, ELBO:-2.101, IWELBO:1.058, ESS:1.880 (6s)
# iteration:4200, EUBO:1.977, ELBO:-2.997, IWELBO:1.129, ESS:2.046 (9s)
# iteration:4300, EUBO:1.907, ELBO:-1.906, IWELBO:1.369, ESS:2.833 (10s)
# iteration:4400, EUBO:1.278, ELBO:-1.709, IWELBO:0.494, ESS:1.954 (10s)
# iteration:4500, EUBO:1.834, ELBO:-0.647, IWELBO:1.300, ESS:2.763 (10s)
# iteration:4600, EUBO:1.564, ELBO:-0.847, IWELBO:1.092, ESS:2.686 (10s)
# iteration:4700, EUBO:1.727, ELBO:1.451, IWELBO:1.595, ESS:3.969 (10s)
# iteration:4800, EUBO:-0.872, ELBO:-4.110, IWELBO:-1.960, ESS:1.339 (10s)
# iteration:4900, EUBO:1.905, ELBO:-2.913, IWELBO:1.065, ESS:2.061 (10s)
# iteration:5000, EUBO:1.717, ELBO:1.275, IWELBO:1.525, ESS:3.748 (10s)
# iteration:5100, EUBO:0.603, ELBO:-2.001, IWELBO:-0.274, ESS:1.637 (10s)
# iteration:5200, EUBO:1.678, ELBO:-1.379, IWELBO:1.145, ESS:2.575 (10s)
# iteration:5300, EUBO:1.953, ELBO:-4.736, IWELBO:1.060, ESS:1.990 (9s)
# iteration:5400, EUBO:0.895, ELBO:-3.173, IWELBO:0.216, ESS:2.235 (10s)
# iteration:5500, EUBO:1.041, ELBO:-4.190, IWELBO:0.125, ESS:1.960 (10s)
# iteration:5600, EUBO:1.023, ELBO:-0.414, IWELBO:0.485, ESS:2.279 (10s)
# iteration:5700, EUBO:1.421, ELBO:-2.774, IWELBO:0.799, ESS:2.423 (10s)
# iteration:5800, EUBO:1.992, ELBO:-2.598, IWELBO:1.159, ESS:2.073 (10s)
# iteration:5900, EUBO:1.694, ELBO:0.130, IWELBO:1.434, ESS:3.712 (9s)
# iteration:6000, EUBO:1.716, ELBO:-3.264, IWELBO:0.817, ESS:1.977 (10s)
# iteration:6100, EUBO:1.768, ELBO:-1.831, IWELBO:1.177, ESS:2.442 (10s)
# iteration:6200, EUBO:1.463, ELBO:-11.276, IWELBO:0.322, ESS:1.414 (10s)
# iteration:6300, EUBO:1.430, ELBO:0.879, IWELBO:1.236, ESS:3.873 (10s)
# iteration:6400, EUBO:-0.010, ELBO:-4.229, IWELBO:-1.326, ESS:1.164 (10s)
# iteration:6500, EUBO:1.275, ELBO:-5.834, IWELBO:0.581, ESS:2.180 (9s)
# iteration:6600, EUBO:1.613, ELBO:0.312, IWELBO:1.295, ESS:3.332 (10s)
# iteration:6700, EUBO:1.612, ELBO:-2.375, IWELBO:1.056, ESS:2.761 (9s)
# iteration:6800, EUBO:1.843, ELBO:-0.085, IWELBO:1.494, ESS:3.350 (10s)
# iteration:6900, EUBO:1.687, ELBO:-3.252, IWELBO:0.980, ESS:2.241 (10s)
# iteration:7000, EUBO:1.677, ELBO:-2.356, IWELBO:0.998, ESS:2.343 (10s)
# iteration:7100, EUBO:1.573, ELBO:-0.836, IWELBO:1.309, ESS:3.674 (10s)
# iteration:7200, EUBO:1.647, ELBO:1.406, IWELBO:1.532, ESS:4.090 (10s)
# iteration:7300, EUBO:1.409, ELBO:0.802, IWELBO:1.161, ESS:3.530 (9s)
# iteration:7400, EUBO:1.552, ELBO:0.478, IWELBO:1.270, ESS:3.536 (10s)
# iteration:7500, EUBO:1.313, ELBO:0.753, IWELBO:1.091, ESS:3.640 (10s)
# iteration:7600, EUBO:1.640, ELBO:-3.077, IWELBO:0.351, ESS:1.203 (10s)
# iteration:7700, EUBO:-0.270, ELBO:-9.523, IWELBO:-1.868, ESS:1.003 (10s)
# iteration:7800, EUBO:1.381, ELBO:-0.123, IWELBO:0.910, ESS:2.866 (10s)
# iteration:7900, EUBO:1.636, ELBO:-1.416, IWELBO:0.888, ESS:2.173 (10s)
# iteration:8000, EUBO:1.817, ELBO:-1.628, IWELBO:1.311, ESS:2.995 (10s)
# iteration:8100, EUBO:1.607, ELBO:0.394, IWELBO:1.190, ESS:2.880 (10s)
# iteration:8200, EUBO:1.395, ELBO:-0.127, IWELBO:0.854, ESS:2.372 (10s)
# iteration:8300, EUBO:1.727, ELBO:1.370, IWELBO:1.568, ESS:3.918 (10s)
# iteration:8400, EUBO:1.401, ELBO:-0.535, IWELBO:0.880, ESS:2.767 (10s)
# iteration:8500, EUBO:1.884, ELBO:0.332, IWELBO:1.661, ESS:3.991 (10s)
# iteration:8600, EUBO:0.590, ELBO:-1.210, IWELBO:0.074, ESS:2.514 (9s)
# iteration:8700, EUBO:0.557, ELBO:-2.052, IWELBO:-0.220, ESS:1.916 (10s)
# iteration:8800, EUBO:1.570, ELBO:-1.089, IWELBO:0.980, ESS:2.581 (10s)
# iteration:8900, EUBO:1.247, ELBO:-0.145, IWELBO:0.652, ESS:2.122 (10s)
# iteration:9000, EUBO:1.261, ELBO:-0.383, IWELBO:0.759, ESS:2.651 (10s)
# iteration:9100, EUBO:-1.079, ELBO:-6.048, IWELBO:-1.638, ESS:2.755 (9s)
# iteration:9200, EUBO:1.380, ELBO:-1.341, IWELBO:1.072, ESS:3.439 (10s)
# iteration:9300, EUBO:1.331, ELBO:0.062, IWELBO:0.867, ESS:2.708 (10s)
# iteration:9400, EUBO:-0.553, ELBO:-3.610, IWELBO:-1.528, ESS:1.445 (10s)
# iteration:9500, EUBO:1.372, ELBO:-1.835, IWELBO:0.599, ESS:1.859 (10s)
# iteration:9600, EUBO:1.663, ELBO:-0.531, IWELBO:1.026, ESS:2.355 (10s)
# iteration:9700, EUBO:1.235, ELBO:-1.472, IWELBO:0.378, ESS:1.579 (10s)
# iteration:9800, EUBO:0.631, ELBO:-1.781, IWELBO:-0.054, ESS:2.295 (10s)
# iteration:9900, EUBO:1.526, ELBO:0.676, IWELBO:1.206, ESS:3.300 (10s)
# ======= end training by iwae ========
#
# ======= start training by iwae-dreg ========
#
# iteration:0, EUBO:1.775, ELBO:-8.756, IWELBO:0.400, ESS:1.132 (0s)
# iteration:100, EUBO:1.379, ELBO:-3.291, IWELBO:0.464, ESS:1.974 (6s)
# iteration:200, EUBO:2.986, ELBO:-3.861, IWELBO:1.918, ESS:1.551 (7s)
# iteration:300, EUBO:2.377, ELBO:-4.870, IWELBO:1.352, ESS:1.651 (6s)
# iteration:400, EUBO:2.962, ELBO:-6.089, IWELBO:1.430, ESS:1.027 (6s)
# iteration:500, EUBO:2.035, ELBO:-1.734, IWELBO:0.690, ESS:1.121 (6s)
# iteration:600, EUBO:1.798, ELBO:-10.062, IWELBO:0.192, ESS:1.001 (6s)
# iteration:700, EUBO:2.641, ELBO:-1.265, IWELBO:1.993, ESS:2.407 (7s)
# iteration:800, EUBO:1.678, ELBO:-6.820, IWELBO:0.653, ESS:1.441 (7s)
# iteration:900, EUBO:2.269, ELBO:-2.529, IWELBO:1.685, ESS:2.611 (6s)
# iteration:1000, EUBO:1.961, ELBO:-5.075, IWELBO:0.831, ESS:1.422 (7s)
# iteration:1100, EUBO:0.752, ELBO:-6.430, IWELBO:-0.776, ESS:1.031 (7s)
# iteration:1200, EUBO:2.543, ELBO:-11.406, IWELBO:0.934, ESS:1.000 (6s)
# iteration:1300, EUBO:-0.971, ELBO:-7.664, IWELBO:-1.974, ESS:1.532 (6s)
# iteration:1400, EUBO:1.435, ELBO:-2.669, IWELBO:0.849, ESS:2.617 (6s)
# iteration:1500, EUBO:2.245, ELBO:-7.160, IWELBO:1.333, ESS:1.834 (6s)
# iteration:1600, EUBO:2.303, ELBO:1.424, IWELBO:2.045, ESS:3.646 (6s)
# iteration:1700, EUBO:2.520, ELBO:-7.809, IWELBO:0.914, ESS:1.001 (6s)
# iteration:1800, EUBO:2.424, ELBO:-5.020, IWELBO:1.507, ESS:1.988 (6s)
# iteration:1900, EUBO:2.116, ELBO:-11.147, IWELBO:0.526, ESS:1.006 (6s)
# iteration:2000, EUBO:2.315, ELBO:-7.927, IWELBO:0.830, ESS:1.052 (6s)
# iteration:2100, EUBO:1.179, ELBO:-0.422, IWELBO:0.826, ESS:3.213 (6s)
# iteration:2200, EUBO:1.967, ELBO:-3.268, IWELBO:1.252, ESS:2.068 (6s)
# iteration:2300, EUBO:1.714, ELBO:-6.269, IWELBO:1.206, ESS:2.950 (6s)
# iteration:2400, EUBO:2.200, ELBO:-2.966, IWELBO:1.394, ESS:2.104 (6s)
# iteration:2500, EUBO:2.049, ELBO:-6.656, IWELBO:1.181, ESS:1.878 (6s)
# iteration:2600, EUBO:1.612, ELBO:-0.887, IWELBO:1.093, ESS:2.868 (6s)
# iteration:2700, EUBO:2.021, ELBO:-4.681, IWELBO:1.144, ESS:1.917 (6s)
# iteration:2800, EUBO:1.477, ELBO:0.007, IWELBO:1.121, ESS:3.225 (6s)
# iteration:2900, EUBO:0.823, ELBO:-7.170, IWELBO:-0.105, ESS:1.899 (6s)
# iteration:3000, EUBO:1.329, ELBO:-4.754, IWELBO:0.059, ESS:1.198 (6s)
# iteration:3100, EUBO:1.513, ELBO:-1.483, IWELBO:0.929, ESS:2.593 (6s)
# iteration:3200, EUBO:1.915, ELBO:-2.892, IWELBO:1.181, ESS:2.158 (6s)
# iteration:3300, EUBO:2.108, ELBO:-3.211, IWELBO:1.192, ESS:1.993 (5s)
# iteration:3400, EUBO:-0.749, ELBO:-7.743, IWELBO:-1.995, ESS:1.247 (6s)
# iteration:3500, EUBO:1.913, ELBO:-3.946, IWELBO:0.330, ESS:1.007 (5s)
# iteration:3600, EUBO:1.605, ELBO:-4.128, IWELBO:0.234, ESS:1.130 (6s)
# iteration:3700, EUBO:1.701, ELBO:-0.124, IWELBO:0.867, ESS:1.586 (6s)
# iteration:3800, EUBO:1.988, ELBO:-8.855, IWELBO:1.275, ESS:2.274 (6s)
# iteration:3900, EUBO:1.621, ELBO:-1.970, IWELBO:0.785, ESS:2.068 (6s)
# iteration:4000, EUBO:1.373, ELBO:-2.131, IWELBO:0.844, ESS:2.878 (6s)
# iteration:4100, EUBO:1.872, ELBO:-1.152, IWELBO:0.731, ESS:1.289 (6s)
# iteration:4200, EUBO:2.084, ELBO:-0.793, IWELBO:1.560, ESS:2.896 (6s)
# iteration:4300, EUBO:0.956, ELBO:-0.401, IWELBO:0.416, ESS:2.229 (6s)
# iteration:4400, EUBO:0.823, ELBO:-2.090, IWELBO:0.017, ESS:1.865 (6s)
# iteration:4500, EUBO:1.013, ELBO:-6.508, IWELBO:-0.095, ESS:1.337 (6s)
# iteration:4600, EUBO:1.324, ELBO:-1.842, IWELBO:0.530, ESS:1.968 (6s)
# iteration:4700, EUBO:1.762, ELBO:-3.559, IWELBO:0.866, ESS:1.689 (6s)
# iteration:4800, EUBO:1.856, ELBO:-2.650, IWELBO:0.581, ESS:1.193 (6s)
# iteration:4900, EUBO:1.824, ELBO:-1.616, IWELBO:1.029, ESS:2.026 (6s)
# iteration:5000, EUBO:1.710, ELBO:-6.010, IWELBO:0.809, ESS:1.633 (6s)
# iteration:5100, EUBO:-0.972, ELBO:-5.821, IWELBO:-1.955, ESS:1.708 (6s)
# iteration:5200, EUBO:-0.560, ELBO:-3.191, IWELBO:-1.705, ESS:1.242 (6s)
# iteration:5300, EUBO:0.568, ELBO:-4.578, IWELBO:-0.420, ESS:1.713 (6s)
# iteration:5400, EUBO:1.523, ELBO:0.522, IWELBO:1.127, ESS:2.762 (6s)
# iteration:5500, EUBO:1.574, ELBO:-3.096, IWELBO:0.832, ESS:2.185 (7s)
# iteration:5600, EUBO:1.118, ELBO:-2.833, IWELBO:-0.166, ESS:1.170 (6s)
# iteration:5700, EUBO:0.026, ELBO:-3.448, IWELBO:-1.233, ESS:1.173 (6s)
# iteration:5800, EUBO:1.845, ELBO:1.811, IWELBO:1.829, ESS:4.852 (6s)
# iteration:5900, EUBO:1.936, ELBO:-3.912, IWELBO:1.028, ESS:2.001 (6s)
# iteration:6000, EUBO:1.711, ELBO:1.445, IWELBO:1.592, ESS:4.123 (6s)
# iteration:6100, EUBO:1.120, ELBO:-2.378, IWELBO:0.566, ESS:2.709 (6s)
# iteration:6200, EUBO:1.568, ELBO:0.896, IWELBO:1.300, ESS:3.479 (6s)
# iteration:6300, EUBO:1.949, ELBO:0.079, IWELBO:1.476, ESS:3.027 (6s)
# iteration:6400, EUBO:1.625, ELBO:0.197, IWELBO:1.119, ESS:2.683 (6s)
# iteration:6500, EUBO:1.625, ELBO:1.305, IWELBO:1.474, ESS:3.865 (6s)
# iteration:6600, EUBO:1.547, ELBO:-0.664, IWELBO:0.650, ESS:1.529 (6s)
# iteration:6700, EUBO:1.621, ELBO:-2.254, IWELBO:1.055, ESS:2.694 (6s)
# iteration:6800, EUBO:1.513, ELBO:-0.733, IWELBO:1.015, ESS:2.784 (6s)
# iteration:6900, EUBO:1.727, ELBO:-2.096, IWELBO:0.899, ESS:1.981 (6s)
# iteration:7000, EUBO:1.062, ELBO:-3.769, IWELBO:0.168, ESS:1.699 (6s)
# iteration:7100, EUBO:1.521, ELBO:-3.134, IWELBO:0.938, ESS:2.545 (6s)
# iteration:7200, EUBO:1.599, ELBO:-1.285, IWELBO:0.696, ESS:1.692 (6s)
# iteration:7300, EUBO:0.807, ELBO:-5.592, IWELBO:0.196, ESS:2.385 (6s)
# iteration:7400, EUBO:1.735, ELBO:0.091, IWELBO:1.248, ESS:2.847 (6s)
# iteration:7500, EUBO:1.440, ELBO:0.819, IWELBO:1.213, ESS:3.630 (6s)
# iteration:7600, EUBO:1.339, ELBO:-1.807, IWELBO:0.643, ESS:2.182 (6s)
# iteration:7700, EUBO:1.529, ELBO:0.005, IWELBO:1.038, ESS:2.797 (6s)
# iteration:7800, EUBO:1.349, ELBO:-1.504, IWELBO:0.774, ESS:2.336 (6s)
# iteration:7900, EUBO:1.822, ELBO:0.587, IWELBO:1.596, ESS:3.953 (6s)
# iteration:8000, EUBO:1.727, ELBO:0.795, IWELBO:1.478, ESS:3.730 (6s)
# iteration:8100, EUBO:1.663, ELBO:0.640, IWELBO:1.392, ESS:3.597 (6s)
# iteration:8200, EUBO:1.534, ELBO:-1.395, IWELBO:0.986, ESS:2.535 (6s)
# iteration:8300, EUBO:1.716, ELBO:0.370, IWELBO:1.289, ESS:2.989 (6s)
# iteration:8400, EUBO:1.380, ELBO:-0.966, IWELBO:0.852, ESS:2.735 (6s)
# iteration:8500, EUBO:1.916, ELBO:-3.002, IWELBO:1.408, ESS:3.001 (6s)
# iteration:8600, EUBO:1.595, ELBO:0.069, IWELBO:1.067, ESS:2.575 (6s)
# iteration:8700, EUBO:0.957, ELBO:-1.645, IWELBO:0.340, ESS:2.076 (6s)
# iteration:8800, EUBO:1.633, ELBO:-0.862, IWELBO:1.346, ESS:3.556 (6s)
# iteration:8900, EUBO:1.297, ELBO:-1.106, IWELBO:0.677, ESS:2.221 (6s)
# iteration:9000, EUBO:0.608, ELBO:0.239, IWELBO:0.414, ESS:3.398 (6s)
# iteration:9100, EUBO:0.336, ELBO:-1.344, IWELBO:-0.092, ESS:2.909 (6s)
# iteration:9200, EUBO:1.270, ELBO:-0.711, IWELBO:0.836, ESS:2.851 (6s)
# iteration:9300, EUBO:1.545, ELBO:0.508, IWELBO:1.232, ESS:3.391 (6s)
# iteration:9400, EUBO:1.149, ELBO:0.011, IWELBO:0.655, ESS:2.350 (6s)
# iteration:9500, EUBO:1.429, ELBO:-1.613, IWELBO:0.493, ESS:1.604 (6s)
# iteration:9600, EUBO:1.566, ELBO:0.143, IWELBO:1.110, ESS:2.903 (6s)
# iteration:9700, EUBO:0.936, ELBO:-0.955, IWELBO:0.349, ESS:2.439 (6s)
# iteration:9800, EUBO:1.478, ELBO:1.217, IWELBO:1.358, ESS:4.095 (6s)
# iteration:9900, EUBO:1.497, ELBO:1.341, IWELBO:1.425, ESS:4.420 (6s)
# ======= end training by iwae-dreg ========
#
# ======= start training by rws ========
#
# iteration:0, EUBO:-1.345, ELBO:-6.162, IWELBO:-2.110, ESS:2.019 (0s)
# iteration:100, EUBO:1.616, ELBO:-9.080, IWELBO:0.501, ESS:1.327 (6s)
# iteration:200, EUBO:0.526, ELBO:-7.158, IWELBO:-0.390, ESS:1.997 (6s)
# iteration:300, EUBO:3.632, ELBO:-7.891, IWELBO:2.235, ESS:1.115 (6s)
# iteration:400, EUBO:-3.957, ELBO:-12.094, IWELBO:-4.854, ESS:1.914 (6s)
# iteration:500, EUBO:3.444, ELBO:-3.703, IWELBO:1.991, ESS:1.075 (6s)
# iteration:600, EUBO:2.160, ELBO:-5.083, IWELBO:0.862, ESS:1.166 (6s)
# iteration:700, EUBO:2.184, ELBO:-6.846, IWELBO:1.291, ESS:2.014 (6s)
# iteration:800, EUBO:2.858, ELBO:-3.615, IWELBO:1.747, ESS:1.384 (6s)
# iteration:900, EUBO:1.457, ELBO:-6.731, IWELBO:0.295, ESS:1.281 (6s)
# iteration:1000, EUBO:0.668, ELBO:-4.330, IWELBO:-0.282, ESS:1.852 (7s)
# iteration:1100, EUBO:1.977, ELBO:-1.205, IWELBO:1.113, ESS:1.974 (6s)
# iteration:1200, EUBO:0.974, ELBO:-5.997, IWELBO:-0.556, ESS:1.028 (6s)
# iteration:1300, EUBO:2.637, ELBO:-6.716, IWELBO:1.562, ESS:1.536 (5s)
# iteration:1400, EUBO:2.723, ELBO:-3.698, IWELBO:1.378, ESS:1.133 (6s)
# iteration:1500, EUBO:1.853, ELBO:-7.658, IWELBO:0.947, ESS:1.982 (6s)
# iteration:1600, EUBO:0.822, ELBO:-3.924, IWELBO:-0.068, ESS:1.973 (6s)
# iteration:1700, EUBO:2.448, ELBO:-4.733, IWELBO:1.312, ESS:1.373 (6s)
# iteration:1800, EUBO:1.721, ELBO:-5.113, IWELBO:0.789, ESS:1.930 (6s)
# iteration:1900, EUBO:2.202, ELBO:-3.470, IWELBO:0.923, ESS:1.221 (6s)
# iteration:2000, EUBO:2.567, ELBO:-7.864, IWELBO:0.962, ESS:1.001 (6s)
# iteration:2100, EUBO:-0.786, ELBO:-8.975, IWELBO:-2.266, ESS:1.050 (6s)
# iteration:2200, EUBO:2.449, ELBO:-4.424, IWELBO:1.558, ESS:1.972 (6s)
# iteration:2300, EUBO:2.356, ELBO:-9.839, IWELBO:1.378, ESS:1.780 (6s)
# iteration:2400, EUBO:2.411, ELBO:-13.140, IWELBO:1.484, ESS:1.958 (6s)
# iteration:2500, EUBO:2.386, ELBO:-8.986, IWELBO:0.777, ESS:1.000 (6s)
# iteration:2600, EUBO:-0.181, ELBO:-6.569, IWELBO:-0.750, ESS:2.715 (6s)
# iteration:2700, EUBO:-1.558, ELBO:-8.649, IWELBO:-2.677, ESS:1.407 (6s)
# iteration:2800, EUBO:1.088, ELBO:-8.297, IWELBO:-0.145, ESS:1.212 (6s)
# iteration:2900, EUBO:1.710, ELBO:-7.503, IWELBO:0.142, ESS:1.014 (6s)
# iteration:3000, EUBO:2.091, ELBO:-2.172, IWELBO:1.079, ESS:1.454 (6s)
# iteration:3100, EUBO:2.111, ELBO:0.853, IWELBO:1.814, ESS:3.514 (6s)
# iteration:3200, EUBO:0.631, ELBO:-3.705, IWELBO:-0.777, ESS:1.081 (6s)
# iteration:3300, EUBO:-1.545, ELBO:-12.607, IWELBO:-3.152, ESS:1.001 (6s)
# iteration:3400, EUBO:2.208, ELBO:-3.437, IWELBO:1.421, ESS:2.141 (6s)
# iteration:3500, EUBO:2.342, ELBO:-6.006, IWELBO:0.739, ESS:1.002 (6s)
# iteration:3600, EUBO:1.178, ELBO:-1.602, IWELBO:0.785, ESS:3.037 (6s)
# iteration:3700, EUBO:1.757, ELBO:-1.939, IWELBO:0.622, ESS:1.326 (6s)
# iteration:3800, EUBO:2.365, ELBO:-11.006, IWELBO:0.766, ESS:1.003 (6s)
# iteration:3900, EUBO:2.019, ELBO:-11.483, IWELBO:0.548, ESS:1.059 (6s)
# iteration:4000, EUBO:1.620, ELBO:-2.061, IWELBO:1.126, ESS:2.675 (6s)
# iteration:4100, EUBO:1.815, ELBO:-3.912, IWELBO:0.820, ESS:1.494 (6s)
# iteration:4200, EUBO:1.127, ELBO:-5.730, IWELBO:-0.447, ESS:1.009 (6s)
# iteration:4300, EUBO:1.650, ELBO:-2.265, IWELBO:1.164, ESS:2.966 (6s)
# iteration:4400, EUBO:1.942, ELBO:-7.439, IWELBO:0.442, ESS:1.042 (5s)
# iteration:4500, EUBO:1.148, ELBO:-11.482, IWELBO:-0.430, ESS:1.010 (6s)
# iteration:4600, EUBO:2.036, ELBO:0.426, IWELBO:1.651, ESS:3.192 (6s)
# iteration:4700, EUBO:1.895, ELBO:-2.835, IWELBO:0.925, ESS:1.613 (6s)
# iteration:4800, EUBO:0.303, ELBO:-8.896, IWELBO:-1.267, ESS:1.011 (6s)
# iteration:4900, EUBO:0.984, ELBO:-3.263, IWELBO:-0.062, ESS:1.351 (6s)
# iteration:5000, EUBO:1.657, ELBO:-8.912, IWELBO:0.180, ESS:1.059 (6s)
# iteration:5100, EUBO:-1.157, ELBO:-10.767, IWELBO:-2.756, ESS:1.003 (6s)
# iteration:5200, EUBO:1.515, ELBO:-1.063, IWELBO:0.588, ESS:1.569 (6s)
# iteration:5300, EUBO:1.608, ELBO:-2.468, IWELBO:0.805, ESS:1.922 (6s)
# iteration:5400, EUBO:1.859, ELBO:-1.987, IWELBO:1.243, ESS:2.499 (6s)
# iteration:5500, EUBO:1.286, ELBO:-1.230, IWELBO:0.875, ESS:2.994 (6s)
# iteration:5600, EUBO:1.615, ELBO:-3.191, IWELBO:0.646, ESS:1.542 (6s)
# iteration:5700, EUBO:2.008, ELBO:-3.363, IWELBO:1.294, ESS:2.274 (6s)
# iteration:5800, EUBO:1.978, ELBO:0.667, IWELBO:1.550, ESS:3.058 (6s)
# iteration:5900, EUBO:1.654, ELBO:-0.625, IWELBO:1.087, ESS:2.585 (6s)
# iteration:6000, EUBO:1.153, ELBO:-1.277, IWELBO:0.322, ESS:1.754 (6s)
# iteration:6100, EUBO:1.500, ELBO:-3.106, IWELBO:0.868, ESS:2.471 (6s)
# iteration:6200, EUBO:1.043, ELBO:-12.268, IWELBO:-0.069, ESS:1.466 (6s)
# iteration:6300, EUBO:1.574, ELBO:-0.925, IWELBO:1.239, ESS:3.244 (6s)
# iteration:6400, EUBO:1.445, ELBO:0.548, IWELBO:1.030, ESS:2.690 (6s)
# iteration:6500, EUBO:1.535, ELBO:-0.239, IWELBO:1.132, ESS:2.936 (6s)
# iteration:6600, EUBO:1.687, ELBO:-1.649, IWELBO:0.941, ESS:2.174 (6s)
# iteration:6700, EUBO:0.606, ELBO:-4.651, IWELBO:-0.416, ESS:1.616 (6s)
# iteration:6800, EUBO:1.174, ELBO:-6.066, IWELBO:0.292, ESS:2.023 (6s)
# iteration:6900, EUBO:1.022, ELBO:-2.171, IWELBO:0.054, ESS:1.536 (6s)
# iteration:7000, EUBO:1.514, ELBO:-1.407, IWELBO:0.661, ESS:1.699 (6s)
# iteration:7100, EUBO:1.687, ELBO:1.181, IWELBO:1.499, ESS:3.890 (6s)
# iteration:7200, EUBO:1.730, ELBO:-0.517, IWELBO:1.231, ESS:2.984 (6s)
# iteration:7300, EUBO:1.881, ELBO:-0.029, IWELBO:1.423, ESS:3.066 (6s)
# iteration:7400, EUBO:0.907, ELBO:-0.596, IWELBO:0.324, ESS:2.238 (6s)
# iteration:7500, EUBO:1.122, ELBO:-1.105, IWELBO:0.371, ESS:2.063 (6s)
# iteration:7600, EUBO:0.892, ELBO:-5.282, IWELBO:-0.176, ESS:1.549 (6s)
# iteration:7700, EUBO:1.678, ELBO:0.830, IWELBO:1.447, ESS:3.817 (6s)
# iteration:7800, EUBO:0.864, ELBO:-1.149, IWELBO:0.521, ESS:3.262 (6s)
# iteration:7900, EUBO:1.452, ELBO:-0.070, IWELBO:1.169, ESS:3.557 (6s)
# iteration:8000, EUBO:1.603, ELBO:0.460, IWELBO:1.292, ESS:3.448 (6s)
# iteration:8100, EUBO:1.404, ELBO:1.158, IWELBO:1.288, ESS:4.092 (6s)
# iteration:8200, EUBO:1.060, ELBO:-2.993, IWELBO:0.421, ESS:2.344 (6s)
# iteration:8300, EUBO:1.398, ELBO:-1.825, IWELBO:0.335, ESS:1.370 (6s)
# iteration:8400, EUBO:1.726, ELBO:-2.357, IWELBO:1.215, ESS:2.976 (6s)
# iteration:8500, EUBO:1.016, ELBO:-0.327, IWELBO:0.387, ESS:1.952 (6s)
# iteration:8600, EUBO:1.369, ELBO:0.968, IWELBO:1.191, ESS:3.779 (6s)
# iteration:8700, EUBO:1.388, ELBO:-0.451, IWELBO:0.792, ESS:2.404 (7s)
# iteration:8800, EUBO:1.649, ELBO:-0.679, IWELBO:1.260, ESS:3.232 (6s)
# iteration:8900, EUBO:1.208, ELBO:-1.266, IWELBO:0.735, ESS:2.602 (6s)
# iteration:9000, EUBO:1.504, ELBO:0.196, IWELBO:1.171, ESS:3.361 (6s)
# iteration:9100, EUBO:1.259, ELBO:-0.999, IWELBO:0.278, ESS:1.428 (6s)
# iteration:9200, EUBO:1.422, ELBO:0.983, IWELBO:1.255, ESS:3.983 (6s)
# iteration:9300, EUBO:1.105, ELBO:-0.928, IWELBO:0.429, ESS:1.974 (6s)
# iteration:9400, EUBO:1.415, ELBO:0.259, IWELBO:1.021, ESS:3.133 (6s)
# iteration:9500, EUBO:1.048, ELBO:0.374, IWELBO:0.793, ESS:3.551 (6s)
# iteration:9600, EUBO:1.265, ELBO:0.048, IWELBO:0.952, ESS:3.457 (6s)
# iteration:9700, EUBO:1.326, ELBO:1.210, IWELBO:1.273, ESS:4.577 (6s)
# iteration:9800, EUBO:1.000, ELBO:0.232, IWELBO:0.713, ESS:3.341 (7s)
# iteration:9900, EUBO:1.298, ELBO:-0.591, IWELBO:0.619, ESS:2.244 (6s)
# ======= end training by rws ========
#
# ======= start training by rws-dreg ========
#
# iteration:0, EUBO:-4.250, ELBO:-7.880, IWELBO:-5.568, ESS:1.144 (0s)
# iteration:100, EUBO:1.678, ELBO:-7.441, IWELBO:0.503, ESS:1.359 (6s)
# iteration:200, EUBO:2.423, ELBO:-3.457, IWELBO:1.501, ESS:1.971 (6s)
# iteration:300, EUBO:2.641, ELBO:-10.949, IWELBO:1.043, ESS:1.003 (7s)
# iteration:400, EUBO:-5.149, ELBO:-8.581, IWELBO:-6.332, ESS:1.277 (6s)
# iteration:500, EUBO:-1.360, ELBO:-9.396, IWELBO:-2.139, ESS:2.148 (7s)
# iteration:600, EUBO:1.038, ELBO:-11.634, IWELBO:-0.571, ESS:1.000 (6s)
# iteration:700, EUBO:-0.986, ELBO:-10.189, IWELBO:-2.577, ESS:1.005 (6s)
# iteration:800, EUBO:1.425, ELBO:-4.611, IWELBO:0.903, ESS:2.932 (6s)
# iteration:900, EUBO:-1.374, ELBO:-5.795, IWELBO:-2.634, ESS:1.194 (6s)
# iteration:1000, EUBO:1.097, ELBO:-9.420, IWELBO:-0.339, ESS:1.084 (5s)
# iteration:1100, EUBO:1.100, ELBO:-6.457, IWELBO:-0.505, ESS:1.001 (6s)
# iteration:1200, EUBO:-0.158, ELBO:-13.243, IWELBO:-1.106, ESS:1.882 (6s)
# iteration:1300, EUBO:0.122, ELBO:-4.995, IWELBO:-0.614, ESS:2.069 (7s)
# iteration:1400, EUBO:2.868, ELBO:-1.038, IWELBO:1.990, ESS:2.026 (6s)
# iteration:1500, EUBO:-0.520, ELBO:-3.260, IWELBO:-1.238, ESS:2.070 (7s)
# iteration:1600, EUBO:1.666, ELBO:-1.167, IWELBO:0.469, ESS:1.205 (6s)
# iteration:1700, EUBO:1.036, ELBO:-11.470, IWELBO:0.080, ESS:1.853 (7s)
# iteration:1800, EUBO:1.231, ELBO:-7.749, IWELBO:0.292, ESS:1.910 (6s)
# iteration:1900, EUBO:1.326, ELBO:-7.667, IWELBO:0.472, ESS:1.728 (7s)
# iteration:2000, EUBO:1.650, ELBO:-0.332, IWELBO:0.881, ESS:1.750 (7s)
# iteration:2100, EUBO:0.894, ELBO:-7.181, IWELBO:-0.647, ESS:1.024 (6s)
# iteration:2200, EUBO:2.239, ELBO:-4.198, IWELBO:1.013, ESS:1.218 (6s)
# iteration:2300, EUBO:1.752, ELBO:-2.631, IWELBO:0.656, ESS:1.351 (6s)
# iteration:2400, EUBO:-0.038, ELBO:-12.006, IWELBO:-0.934, ESS:1.998 (6s)
# iteration:2500, EUBO:1.649, ELBO:-5.393, IWELBO:0.708, ESS:1.898 (6s)
# iteration:2600, EUBO:1.770, ELBO:-6.421, IWELBO:0.273, ESS:1.045 (7s)
# iteration:2700, EUBO:1.252, ELBO:-7.839, IWELBO:-0.203, ESS:1.066 (6s)
# iteration:2800, EUBO:0.970, ELBO:-5.955, IWELBO:0.206, ESS:2.085 (6s)
# iteration:2900, EUBO:0.117, ELBO:-10.383, IWELBO:-1.241, ESS:1.146 (6s)
# iteration:3000, EUBO:2.234, ELBO:-2.730, IWELBO:0.815, ESS:1.086 (6s)
# iteration:3100, EUBO:0.845, ELBO:-3.004, IWELBO:0.159, ESS:2.273 (6s)
# iteration:3200, EUBO:2.334, ELBO:-4.910, IWELBO:1.484, ESS:2.049 (6s)
# iteration:3300, EUBO:0.241, ELBO:-6.483, IWELBO:-0.836, ESS:1.482 (6s)
# iteration:3400, EUBO:1.629, ELBO:-5.856, IWELBO:0.693, ESS:1.867 (6s)
# iteration:3500, EUBO:-2.309, ELBO:-6.271, IWELBO:-3.022, ESS:2.272 (6s)
# iteration:3600, EUBO:1.416, ELBO:-5.694, IWELBO:0.778, ESS:2.405 (6s)
# iteration:3700, EUBO:1.609, ELBO:-7.417, IWELBO:0.512, ESS:1.471 (6s)
# iteration:3800, EUBO:0.849, ELBO:-3.904, IWELBO:0.034, ESS:2.098 (6s)
# iteration:3900, EUBO:2.142, ELBO:-1.253, IWELBO:1.572, ESS:2.579 (6s)
# iteration:4000, EUBO:2.206, ELBO:0.676, IWELBO:1.983, ESS:3.995 (6s)
# iteration:4100, EUBO:1.253, ELBO:-5.490, IWELBO:0.236, ESS:1.662 (6s)
# iteration:4200, EUBO:2.018, ELBO:-2.806, IWELBO:0.947, ESS:1.510 (6s)
# iteration:4300, EUBO:2.125, ELBO:1.185, IWELBO:1.855, ESS:3.618 (6s)
# iteration:4400, EUBO:1.925, ELBO:-6.098, IWELBO:0.691, ESS:1.188 (6s)
# iteration:4500, EUBO:1.996, ELBO:-0.438, IWELBO:1.338, ESS:2.321 (6s)
# iteration:4600, EUBO:1.747, ELBO:-2.261, IWELBO:1.246, ESS:2.846 (6s)
# iteration:4700, EUBO:1.835, ELBO:0.552, IWELBO:1.398, ESS:2.939 (7s)
# iteration:4800, EUBO:2.131, ELBO:1.237, IWELBO:1.920, ESS:3.999 (6s)
# iteration:4900, EUBO:1.905, ELBO:-5.008, IWELBO:0.724, ESS:1.274 (6s)
# iteration:5000, EUBO:1.822, ELBO:-3.164, IWELBO:0.606, ESS:1.224 (6s)
# iteration:5100, EUBO:2.129, ELBO:-8.411, IWELBO:1.217, ESS:1.997 (7s)
# iteration:5200, EUBO:1.538, ELBO:-2.935, IWELBO:0.307, ESS:1.246 (6s)
# iteration:5300, EUBO:1.619, ELBO:-2.749, IWELBO:0.971, ESS:2.388 (6s)
# iteration:5400, EUBO:1.223, ELBO:-5.963, IWELBO:0.121, ESS:1.480 (6s)
# iteration:5500, EUBO:1.660, ELBO:0.339, IWELBO:1.204, ESS:2.781 (6s)
# iteration:5600, EUBO:1.696, ELBO:-9.203, IWELBO:0.272, ESS:1.096 (6s)
# iteration:5700, EUBO:1.653, ELBO:-1.869, IWELBO:0.856, ESS:1.853 (6s)
# iteration:5800, EUBO:1.716, ELBO:1.126, IWELBO:1.479, ESS:3.573 (7s)
# iteration:5900, EUBO:0.880, ELBO:-6.901, IWELBO:-0.656, ESS:1.027 (7s)
# iteration:6000, EUBO:1.940, ELBO:-0.178, IWELBO:1.654, ESS:3.611 (6s)
# iteration:6100, EUBO:1.685, ELBO:-3.446, IWELBO:0.695, ESS:1.675 (7s)
# iteration:6200, EUBO:1.690, ELBO:-3.968, IWELBO:1.232, ESS:2.790 (6s)
# iteration:6300, EUBO:1.675, ELBO:0.289, IWELBO:1.120, ESS:2.468 (6s)
# iteration:6400, EUBO:1.844, ELBO:0.626, IWELBO:1.593, ESS:3.776 (6s)
# iteration:6500, EUBO:1.804, ELBO:0.429, IWELBO:1.371, ESS:3.064 (6s)
# iteration:6600, EUBO:1.746, ELBO:-2.423, IWELBO:0.889, ESS:2.028 (6s)
# iteration:6700, EUBO:1.356, ELBO:-0.003, IWELBO:0.760, ESS:2.186 (6s)
# iteration:6800, EUBO:1.528, ELBO:1.340, IWELBO:1.442, ESS:4.337 (6s)
# iteration:6900, EUBO:1.686, ELBO:0.935, IWELBO:1.399, ESS:3.432 (6s)
# iteration:7000, EUBO:1.324, ELBO:-3.766, IWELBO:0.650, ESS:2.188 (6s)
# iteration:7100, EUBO:1.517, ELBO:-1.841, IWELBO:1.152, ESS:3.188 (6s)
# iteration:7200, EUBO:-2.887, ELBO:-8.014, IWELBO:-3.742, ESS:1.635 (6s)
# iteration:7300, EUBO:1.781, ELBO:-5.096, IWELBO:1.118, ESS:2.404 (6s)
# iteration:7400, EUBO:1.323, ELBO:0.555, IWELBO:1.047, ESS:3.471 (6s)
# iteration:7500, EUBO:1.377, ELBO:-0.735, IWELBO:0.903, ESS:2.591 (6s)
# iteration:7600, EUBO:1.632, ELBO:0.994, IWELBO:1.428, ESS:3.886 (6s)
# iteration:7700, EUBO:1.528, ELBO:0.296, IWELBO:1.005, ESS:2.511 (6s)
# iteration:7800, EUBO:1.572, ELBO:-0.194, IWELBO:1.077, ESS:2.670 (6s)
# iteration:7900, EUBO:0.852, ELBO:-1.872, IWELBO:0.072, ESS:2.094 (6s)
# iteration:8000, EUBO:1.662, ELBO:-2.078, IWELBO:0.975, ESS:2.339 (6s)
# iteration:8100, EUBO:1.531, ELBO:-0.318, IWELBO:1.125, ESS:3.132 (6s)
# iteration:8200, EUBO:1.321, ELBO:-0.803, IWELBO:0.961, ESS:3.167 (6s)
# iteration:8300, EUBO:1.286, ELBO:-0.200, IWELBO:0.739, ESS:2.377 (6s)
# iteration:8400, EUBO:1.584, ELBO:-0.060, IWELBO:1.109, ESS:2.879 (6s)
# iteration:8500, EUBO:1.323, ELBO:-1.602, IWELBO:0.280, ESS:1.391 (6s)
# iteration:8600, EUBO:1.247, ELBO:-0.772, IWELBO:0.729, ESS:2.579 (6s)
# iteration:8700, EUBO:1.217, ELBO:-0.985, IWELBO:0.720, ESS:2.571 (7s)
# iteration:8800, EUBO:1.132, ELBO:-0.277, IWELBO:0.553, ESS:2.165 (6s)
# iteration:8900, EUBO:1.395, ELBO:-1.378, IWELBO:0.774, ESS:2.458 (6s)
# iteration:9000, EUBO:1.131, ELBO:0.901, IWELBO:1.019, ESS:4.054 (6s)
# iteration:9100, EUBO:1.272, ELBO:-1.137, IWELBO:0.548, ESS:2.109 (6s)
# iteration:9200, EUBO:1.457, ELBO:0.279, IWELBO:1.202, ESS:3.741 (6s)
# iteration:9300, EUBO:1.430, ELBO:-0.388, IWELBO:0.988, ESS:3.095 (7s)
# iteration:9400, EUBO:1.205, ELBO:0.100, IWELBO:0.927, ESS:3.527 (7s)
# iteration:9500, EUBO:1.385, ELBO:-0.517, IWELBO:1.008, ESS:3.238 (6s)
# iteration:9600, EUBO:1.025, ELBO:0.437, IWELBO:0.758, ESS:3.283 (7s)
# iteration:9700, EUBO:1.185, ELBO:0.631, IWELBO:0.952, ESS:3.596 (6s)
# iteration:9800, EUBO:1.159, ELBO:0.602, IWELBO:0.908, ESS:3.381 (6s)
# iteration:9900, EUBO:0.994, ELBO:-0.058, IWELBO:0.543, ESS:2.668 (7s)
# ======= end training by rws-dreg ========
#
# ======= start training by stl ========
#
# iteration:0, EUBO:3.668, ELBO:-4.172, IWELBO:2.143, ESS:1.030 (0s)
# iteration:100, EUBO:-0.138, ELBO:-5.286, IWELBO:-0.859, ESS:2.199 (7s)
# iteration:200, EUBO:-7.686, ELBO:-16.679, IWELBO:-8.798, ESS:1.464 (6s)
# iteration:300, EUBO:2.700, ELBO:-4.356, IWELBO:1.186, ESS:1.035 (6s)
# iteration:400, EUBO:1.952, ELBO:-10.305, IWELBO:0.911, ESS:1.584 (7s)
# iteration:500, EUBO:-1.590, ELBO:-7.681, IWELBO:-2.767, ESS:1.304 (6s)
# iteration:600, EUBO:3.040, ELBO:-2.982, IWELBO:1.501, ESS:1.024 (6s)
# iteration:700, EUBO:-8.855, ELBO:-14.660, IWELBO:-9.913, ESS:1.539 (7s)

# %%
def plot_results(dEUBOs, dELBOs, dIWELBOs, dESSs, dSNRs, dVARs, num_samples, num_samples,_snr, steps, lr, ests, fs=10):
    fig = plt.figure(figsize=(fs,fs))
    colors = {'mc':'green', 'iwae': 'red', 'iwae-dreg': 'blue', 
              'rws': 'deepskyblue', 'rws-dreg': 'firebrick', 'stl': 'black'}
    fig = plt.figure(figsize=(fs,fs))
    ax = fig.subplots(5, 3, gridspec_kw={'wspace':0.1, 'hspace':0.1})
    
    for i, est in enumerate(ests):
        EUBOs = dEUBOs[est]
        ELBOs = dELBOs[est]
        IWELBOs = dIWELBOs[est]
        ESSs = dESSs[est]
        SNRs = dSNRs[est]
        VARs = dVARs[est]
        if est == 'mc':
            ax[0, 0].plot(EUBOs, c=colors[est], label=est)
            ax[1, 0].plot(ELBOs, c=colors[est], label=est)
            ax[2, 0].plot(IWELBOs, c=colors[est], label=est)
            ax[3, 0].plot(SNRs, c=colors[est], label=est + '-snr')
            ax[3, 0].plot(VARs, marker='o', c=colors[est], label=est + '-var')
            ax[4, 0].plot(ESSs, c=colors[est], label=est)           
        elif est == 'iwae' or est == 'iwae-dreg':
            ax[0, 1].plot(EUBOs, c=colors[est], label=est)
            ax[1, 1].plot(ELBOs, c=colors[est], label=est)
            ax[2, 1].plot(IWELBOs, c=colors[est], label=est)
            ax[3, 1].plot(SNRs, c=colors[est], label=est + '-snr')
            ax[3, 1].plot(VARs, marker='o', c=colors[est], label=est + '-var')
            ax[4, 1].plot(ESSs, c=colors[est], label=est)       
        elif est =='rws' or est == 'rws-dreg':
            ax[0, 2].plot(EUBOs, c=colors[est], label=est)
            ax[1, 2].plot(ELBOs, c=colors[est], label=est)
            ax[2, 2].plot(IWELBOs, c=colors[est], label=est)
            ax[3, 2].plot(SNRs, c=colors[est], label=est + '-snr')
            ax[3, 2].plot(VARs, marker='o', c=colors[est], label=est + '-var')
            ax[4, 2].plot(ESSs, c=colors[est], label=est)  
            
    ax[0, 1].set_title('EUBO')
    ax[1, 1].set_title('ELBO')
    ax[2, 1].set_title('IWELBO')
    ax[3, 1].set_title('SNR and Variance')
    ax[4, 1].set_title('ESS')
    
    for i in range(5):
        for j in range(3):
            ax[i, j].legend(fontsize=14)
            ax[i, j].tick_params(labelsize=14)
            if i == 3:
                ax[i, j].set_yscale('log')
    plt.savefig('results/results-%dsamples-%dSNRsamples-%dsteps-%flr.svg' % (num_samples, num_samples_snr, steps, lr))

# %%
plot_results_multiple(ELBOs, ESSs, SNRs, num_samples, NUM_SAMPLES_SNR, STEPS, LEARNING_RATE, ests)
