# %%
# %matplotlib inline
# %run ../../import_envs.py
# %run ../apg_hyperparams.py

CUDA = torch.cuda.is_available()
DEVICE = torch.device('cuda:0')
# Out:
# probtorch: 0.0+5a2c637 torch: 1.3.0
# inference method:apg, apg sweeps:10, epochs:300, sample size:10, batch size:20, learning rate:0.0001

# %%
# load test data
DATA_DIR = '/home/hao/Research/apg_data/gmm/gmm_test/'
test_sets = ['gmm_20', 'gmm_40', 'gmm_60', 'gmm_80', 'gmm_100']
DATAs = []
for s in test_sets:
    data = torch.from_numpy(np.load(DATA_DIR + s + '/' + 'ob.npy')).float() ## load testing datasets
    DATAs.append(data)
## load the weights
from apg_modeling import init_model
model = init_model(model_params=model_params, 
                    CUDA=CUDA, 
                    DEVICE=DEVICE, 
                    LOAD_VERSION=LOAD_VERSION,
                    LR=None)

# %%
## visualize samples
from apg_testing import sample_data_uniform, test_single
from apg_objective import apg_objective
from viz import viz_samples

APG_SWEEPS_TEST = 12
DATA_PTR = 3
SAVE_NAME = 'samples-%d' % DATA_PTR

datas = sample_data_uniform(DATAs=DATAs, 
                            data_ptr=DATA_PTR)

metrics = test_single(model=model, 
                      apg_objective=apg_objective, 
                      apg_sweeps=APG_SWEEPS_TEST, 
                      datas=datas, 
                      sample_size=1, 
                      CUDA=CUDA, 
                      DEVICE=DEVICE)

viz_samples(datas=datas,
            metrics=metrics,
            apg_sweeps=APG_SWEEPS_TEST,
            K=K, 
            viz_interval=3, 
            figure_size=15, 
            title_fontsize=20, 
            marker_size=5.0, 
            opacity=0.3, 
            bound=15, 
            colors=['#AA3377', '#EE7733', '#009988', '#0077BB', '#BBBBBB', '#EE3377', '#DDCC77'],
            save_name=None)

# %%
## plot the ess and log joint
APG_SWEEP_TEST = 30
SAMPLE_SIZE_TEST = 100
metrics = test_single(model=model, 
                      apg_objective=apg_objective, 
                      apg_sweeps=APG_SWEEP_TEST, 
                      datas=datas, 
                      sample_size=SAMPLE_SIZE_TEST, 
                      CUDA=CUDA, 
                      DEVICE=DEVICE)

# viz_metrics(metrics, figure_size, title_fontsize, save_name=)
