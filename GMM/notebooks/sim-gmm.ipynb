# %%
# %matplotlib inline
# %run ../../import_envs.py
from sim_gmm import Sim_GMM
# Out:
# probtorch: 0.0+5a2c637 torch: 1.3.0

# %%
N = 60
K = 3
D = 2
alpha = 4.0
beta = 4.0
mu = 0.0
nu = 0.3
simulator = Sim_GMM(N, K, D, alpha, beta, mu, nu)
simulator.viz_data()

# %%
PATH = DATA_DIR + 'gmm/train/'
simulator.sim_save_data(num_seqs=20000, PATH=PATH)
