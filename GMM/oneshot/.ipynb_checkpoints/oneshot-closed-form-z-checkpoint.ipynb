# %%
# %matplotlib inline
# %run ../../path_import.py
from plots import *
from training import *
from eubo import *
from model_naive_natparam import *

import probtorch
print('probtorch:', probtorch.__version__, 
      'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# probtorch: 0.0+5a2c637 torch: 1.0.0 cuda: True

# %%
data_path = "../gmm_dataset_c20k"
Data = torch.from_numpy(np.load(data_path + '/obs.npy')).float()
_, N, D = Data.shape
K = 3 ## number of clusters
## Model Parameters
SAMPLE_SIZE = 10
NUM_HIDDEN_LOCAL = 32
## Training Parameters
BATCH_SIZE = 20
NUM_EPOCHS = 200
LEARNING_RATE = 1e-4
CUDA = torch.cuda.is_available()
PATH = 'oneshot-cfz-c20k'

DEVICE = torch.device('cuda:0')

# %%
# initialization
enc_z = Gibbs_z(K, CUDA, DEVICE)
oneshot_eta = Oneshot_eta(K, D, CUDA, DEVICE)
if CUDA:
    oneshot_eta.cuda().to(DEVICE)
optimizer =  torch.optim.Adam(list(oneshot_eta.parameters()),lr=LEARNING_RATE, betas=(0.9, 0.99))

# %%
train(Eubo_os_cfz, oneshot_eta, enc_z, optimizer, Data, K, NUM_EPOCHS, SAMPLE_SIZE, BATCH_SIZE, PATH, CUDA, DEVICE)
# Out:
# epoch=0, EUBO=-435.097, ELBO=-510.501, ESS=1.112 (13s)
# epoch=1, EUBO=-401.335, ELBO=-456.625, ESS=1.166 (13s)
# epoch=2, EUBO=-380.026, ELBO=-423.087, ESS=1.206 (13s)
# epoch=3, EUBO=-365.734, ELBO=-401.885, ESS=1.237 (12s)
# epoch=4, EUBO=-354.732, ELBO=-385.770, ESS=1.261 (13s)
# epoch=5, EUBO=-344.620, ELBO=-371.690, ESS=1.287 (12s)
# epoch=6, EUBO=-333.750, ELBO=-357.040, ESS=1.320 (13s)
# epoch=7, EUBO=-322.202, ELBO=-341.735, ESS=1.346 (13s)
# epoch=8, EUBO=-310.452, ELBO=-326.491, ESS=1.404 (13s)
# epoch=9, EUBO=-299.579, ELBO=-312.346, ESS=1.479 (13s)
# epoch=10, EUBO=-290.728, ELBO=-301.038, ESS=1.554 (14s)
# epoch=11, EUBO=-284.521, ELBO=-293.126, ESS=1.634 (13s)
# epoch=12, EUBO=-280.357, ELBO=-287.867, ESS=1.716 (13s)
# epoch=13, EUBO=-278.332, ELBO=-285.388, ESS=1.775 (12s)
# epoch=14, EUBO=-277.741, ELBO=-284.712, ESS=1.804 (13s)
# epoch=15, EUBO=-277.384, ELBO=-284.422, ESS=1.825 (13s)
# epoch=16, EUBO=-277.143, ELBO=-284.221, ESS=1.830 (12s)
# ...

# %%
torch.save(enc_eta.state_dict(), '../weights/enc-eta-%s' + PATH)
# torch.save(enc_z.state_dict(), '../weights/enc-z-%s' + PATH)

# %%
BATCH_SIZE_TEST = 50
obs, q_eta, q_z = test(Eubo_init_eta, enc_eta, enc_z, Data, K, SAMPLE_SIZE, BATCH_SIZE_TEST, CUDA, DEVICE)

# %%
# %time plot_samples(obs, q_eta, q_z, PATH)

# %%
enc_z.
