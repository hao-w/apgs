# %%
# %matplotlib inline
# %run ../../import_envs.py
print('probtorch:', probtorch.__version__, 
      'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# probtorch: 0.0+f9f5c9b torch: 0.4.1 cuda: True

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:

import sys
import numpy as np
import torch
import probtorch
from training import *

# get_ipython().run_line_magic('matplotlib', 'inline')
# get_ipython().run_line_magic('run', '../../import_envs.py')
# print('probtorch:', probtorch.__version__, 
#       'torch:', torch.__version__, 
#       'cuda:', torch.cuda.is_available())

# %%
## Load dataset
data_path = "../gmm_dataset_c20k"
Data = torch.from_numpy(np.load(data_path + '/obs.npy')).float()

NUM_DATASETS, N, D = Data.shape
K = 3 ## number of clusters
SAMPLE_SIZE = 10
NUM_HIDDEN_LOCAL = 32
NUM_HIDDEN_GLOBAL = 32
NUM_LAYERS = 32

BATCH_SIZE = 20
NUM_EPOCHS = 5
LEARNING_RATE = 5*1e-2
CUDA = torch.cuda.is_available()
PATH = 'baseline-lstm-%dsamples-test' % (SAMPLE_SIZE)
DEVICE = torch.device('cuda:0')

Train_Params = (NUM_EPOCHS, NUM_DATASETS, SAMPLE_SIZE, BATCH_SIZE, CUDA, DEVICE, PATH)
Model_Params = (N, K, D)

# %%
from local_enc import *
from global_lstm_no_ss import *
## if reparameterize continuous variables
Reparameterized = False
# initialization
enc_z = Enc_z(K, D, NUM_HIDDEN_LOCAL, CUDA, DEVICE)
oneshot_eta = LSTM_eta(K, D, BATCH_SIZE, SAMPLE_SIZE, NUM_HIDDEN_GLOBAL, NUM_LAYERS, CUDA, DEVICE, Reparameterized)
if CUDA:
    enc_z.cuda().to(DEVICE)
if CUDA:
    oneshot_eta.cuda().to(DEVICE)
optimizer =  torch.optim.Adam(list(oneshot_eta.parameters())+list(enc_z.parameters()),lr=LEARNING_RATE, betas=(0.9, 0.99))
models = (oneshot_eta, enc_z)

# %%
from os_ep import *
train_baseline(models, EP, optimizer, Data, Model_Params, Train_Params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-8351e0914ddb> in <module>
#       1 from os_ep import *
# ----> 2 train_baseline(models, EP, optimizer, Data, Model_Params, Train_Params)
#
# ~/repos/amortized/GMM/training.py in train_baseline(models, objective, optimizer, data, Model_Params, Train_Params)
#
# ~/repos/amortized/GMM/objectives/os_ep.py in EP(models, obs, SubTrain_Params)
#      14     (device, sample_size, batch_size, N, K, D) = SubTrain_Params
#      15     obs_tau, obs_mu, state, log_w_f_z, q_eta, p_eta, q_z, p_z = Init_step_eta(models, obs, N, K, D, sample_size, batch_size)
# ---> 16     #q_eta, p_eta, q_nu = oneshot_eta(obs, K, D)
#      17     #log_p_eta = p_eta['means'].log_prob.sum(-1) + p_eta['precisions'].log_prob.sum(-1)
#      18     #log_q_eta = q_eta['means'].log_prob.sum(-1) + q_eta['precisions'].log_prob.sum(-1)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/repos/amortized/GMM/models/global_lstm_no_ss.py in forward(self, obs, K, D, batch_first)
#      60         out_seqs = out_seqs.transpose(0, 1).reshape(S, B, T, -1)
#      61         out_last = out_seqs[:, :, T-1, :] #S, B, H
# ---> 62         asd
#      63         # Computing sufficient stats
#      64         q_alpha = torch.exp(self.log_q_alpha(out_last)).reshape(S, B, K, D) # S, B, K*D
#
# NameError: name 'asd' is not defined

# %%
# %debug
# Out:
# > /home/heiko/repos/amortized/GMM/models/global_lstm_no_ss.py(62)forward()
#      60         out_seqs = out_seqs.transpose(0, 1).reshape(S, B, T, -1)
#      61         out_last = out_seqs[:, :, T-1, :] #S, B, H
# ---> 62         asd
#      63         # Computing sufficient stats
#      64         q_alpha = torch.exp(self.log_q_alpha(out_last)).reshape(S, B, K, D) # S, B, K*D
#
# ipdb> out_last
# tensor([[[ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          ...,
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#         [[ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          ...,
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#         [[ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          ...,
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#         ...,
#
#         [[ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          ...,
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#         [[ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          ...,
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#         [[ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          ...,
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#          [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#        device='cuda:0', grad_fn=<SelectBackward>)
# ipdb> out_seq
# *** NameError: name 'out_seq' is not defined
# ipdb> out_seqs
# tensor([[[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         ...,
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]]],
#        device='cuda:0', grad_fn=<AsStridedBackward>)
# --KeyboardInterrupt--
# ipdb> p out_seqs
# tensor([[[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         ...,
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]],
#
#
#         [[[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          ...,
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]],
#
#          [[ 0.0009, -0.0031,  0.0119,  ..., -0.0059, -0.0490,  0.0712],
#           [ 0.0091, -0.0003,  0.0170,  ..., -0.0121, -0.0651,  0.1039],
#           [ 0.0171,  0.0025,  0.0186,  ..., -0.0157, -0.0692,  0.1188],
#           ...,
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249],
#           [ 0.0301,  0.0097,  0.0124,  ..., -0.0166, -0.0657,  0.1249]]]],
#        device='cuda:0', grad_fn=<AsStridedBackward>)

# %%
from datetime import datetime
TIMESTAMP = str(datetime.now())
torch.save(enc_z.state_dict(), '../weights/enc-z-%s' + PATH + TIMESTAMP)
torch.save(oneshot_eta.state_dict(), '../weights/oneshot-eta-%s' + PATH + TIMESTAMP)

# %%
def test(models, objective, Data, Model_Params, Train_Params):
    (NUM_EPOCHS, NUM_DATASETS, S, B, CUDA, device, path) = Train_Params
    SubTrain_Params = (device, S, B) + Model_Params
    ##(N, K, D, mcmc_size) = Model_Params
    indices = torch.randperm(NUM_DATASETS)
    batch_indices = indices[0*B : (0+1)*B]
    obs = Data[batch_indices]
    obs = shuffler(obs).repeat(S, 1, 1, 1)
    if CUDA:
        obs =obs.cuda().to(device)
    loss, metric_step, reused = objective(models, obs, SubTrain_Params)
    return obs, metric_step, reused

# %%
# This must be the same as BATCHSIZE for LSTM
BATCH_SIZE_TEST = BATCH_SIZE
Train_Params_Test = (NUM_EPOCHS, NUM_DATASETS, SAMPLE_SIZE, BATCH_SIZE_TEST, CUDA, DEVICE, PATH)
obs, metric_step, reused = test(models, EP, Data, Model_Params, Train_Params_Test)
(q_eta, _, q_z, _, _, _) = reused
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-a09ab8699480> in <module>
#       2 BATCH_SIZE_TEST = BATCH_SIZE
#       3 Train_Params_Test = (NUM_EPOCHS, NUM_DATASETS, SAMPLE_SIZE, BATCH_SIZE_TEST, CUDA, DEVICE, PATH)
# ----> 4 obs, metric_step, reused = test(models, EP, Data, Model_Params, Train_Params_Test)
#       5 (q_eta, _, q_z, _, _, _) = reused
#
# <ipython-input-90-13c5825ce995> in test(models, objective, Data, Model_Params, Train_Params)
#       9     if CUDA:
#      10         obs =obs.cuda().to(device)
# ---> 11     loss, metric_step, reused = objective(models, obs, SubTrain_Params)
#      12     return obs, metric_step, reused
#
# ~/repos/amortized/GMM/objectives/os_ep.py in EP(models, obs, SubTrain_Params)
#      14     (device, sample_size, batch_size, N, K, D) = SubTrain_Params
#      15     obs_tau, obs_mu, state, log_w_f_z, q_eta, p_eta, q_z, p_z = Init_step_eta(models, obs, N, K, D, sample_size, batch_size)
# ---> 16     #q_eta, p_eta, q_nu = oneshot_eta(obs, K, D)
#      17     #log_p_eta = p_eta['means'].log_prob.sum(-1) + p_eta['precisions'].log_prob.sum(-1)
#      18     #log_q_eta = q_eta['means'].log_prob.sum(-1) + q_eta['precisions'].log_prob.sum(-1)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/repos/amortized/GMM/models/global_lstm_no_ss.py in forward(self, obs, K, D, batch_first)
#      60         out_seqs = out_seqs.transpose(0, 1).reshape(S, B, T, -1)
#      61         out_last = out_seqs[:, :, T-1, :] #S, B, H
# ---> 62         asd
#      63         # Computing sufficient stats
#      64         q_alpha = torch.exp(self.log_q_alpha(out_last)).reshape(S, B, K, D) # S, B, K*D
#
# NameError: name 'asd' is not defined

# %%
# %q_eta['means'].dist.loc[1]
# Out:
# UsageError: Line magic function `%q_eta['means'].dist.loc[1]` not found.

# %%
# %debug

# %%
# %load_ext autoreload
# %autoreload 2
#get_ipython().run_line_magic('time', 'plot_samples(obs, q_eta, q_z, PATH)')
plot_samples(obs, q_eta, q_z, PATH)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
