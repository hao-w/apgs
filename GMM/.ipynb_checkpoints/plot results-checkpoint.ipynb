# %%
# %matplotlib inline
from plots import *
import matplotlib.pyplot as plt
import torch
import numpy as np
import pandas as pd

# %%
PATH = 'ag-cfz-os-prior-c20k'
df = pd.read_csv('results/log-%s.txt' % PATH, sep='\t')
SAMPLE_SIZE = 10

# %%
df
# Out:
#         EUBO     ELBO    ESS  KLs_eta_ex  KLs_eta_in  KLs_z_ex  KLs_z_in
# 0   -470.394 -555.991  4.425     284.156     257.281   125.800   991.140
# 1   -412.830 -477.466  4.563     213.748     270.665   113.626   988.086
# 2   -385.506 -442.884  4.693     190.188     256.949   127.996   892.280
# 3   -375.701 -434.040  4.801     195.958     236.567   155.990   749.664
# 4   -367.303 -430.049  4.883     202.691     215.787   173.953   615.681
# 5   -353.329 -419.182  4.957     201.319     198.693   176.557   523.868
# 6   -341.243 -408.425  5.011     193.320     186.447   171.747   464.964
# 7   -335.277 -404.528  5.045     191.360     177.435   169.297   420.730
# 8   -325.898 -393.001  5.082     180.682     166.126   160.729   385.520
# 9   -315.619 -381.400  5.118     168.112     152.291   151.079   354.747
# 10  -305.989 -368.586  5.140     156.009     138.209   140.370   330.122
# 11  -295.883 -354.525  5.154     142.902     127.722   128.070   307.823
# ...

# %%
plot_results_ag(df, SAMPLE_SIZE, PATH)

# %%
df['ESS'].values
