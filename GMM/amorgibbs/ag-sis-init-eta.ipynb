# %%
# %matplotlib inline
# %run ../../path_import.py
from plots import *
from training_backward import *
from eubo_backward import *
from model_naive_natparam import *

import probtorch
print('probtorch:', probtorch.__version__, 
      'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# probtorch: 0.0+5a2c637 torch: 1.0.0 cuda: True

# %%
data_path = "../gmm_dataset_c2k"
Data = torch.from_numpy(np.load(data_path + '/obs.npy')).float()
_, N, D = Data.shape
K = 3 ## number of clusters
## Model Parameters
MCMC_SIZE = 10
SAMPLE_SIZE = 10
NUM_HIDDEN_LOCAL = 64
## Training Parameters
BATCH_SIZE = 20
NUM_EPOCHS = 3000
LEARNING_RATE = 5 * 1e-4
CUDA = torch.cuda.is_available()
PATH = 'ag-sis-init-eta'

DEVICE = torch.device('cuda:0')

# %%
enc_eta, enc_z, optimizer = initialize(K, D, NUM_HIDDEN_LOCAL, CUDA, DEVICE, LEARNING_RATE)

# %%
train(Eubo_sis_init_eta, enc_eta, enc_z, optimizer, Data, K, NUM_EPOCHS, MCMC_SIZE, SAMPLE_SIZE, BATCH_SIZE, PATH, CUDA, DEVICE)
# Out:
# epoch=0, EUBO=-7053.698, ELBO=-11120.599, ESS=3.120 (14s)
# epoch=1, EUBO=-6436.281, ELBO=-9743.020, ESS=3.375 (13s)
# epoch=2, EUBO=-6014.558, ELBO=-8790.058, ESS=3.615 (13s)
# epoch=3, EUBO=-5687.091, ELBO=-8097.918, ESS=3.829 (14s)
# epoch=4, EUBO=-5443.669, ELBO=-7605.065, ESS=4.007 (13s)
# epoch=5, EUBO=-5260.049, ELBO=-7231.293, ESS=4.153 (14s)
# epoch=6, EUBO=-5087.623, ELBO=-6933.994, ESS=4.253 (13s)
# epoch=7, EUBO=-4961.461, ELBO=-6717.691, ESS=4.341 (13s)
# epoch=8, EUBO=-4859.807, ELBO=-6537.933, ESS=4.404 (13s)
# epoch=9, EUBO=-4773.648, ELBO=-6385.015, ESS=4.463 (13s)
# epoch=10, EUBO=-4695.166, ELBO=-6260.126, ESS=4.498 (12s)
# epoch=11, EUBO=-4642.534, ELBO=-6164.957, ESS=4.530 (12s)
# epoch=12, EUBO=-4597.271, ELBO=-6097.783, ESS=4.560 (12s)
# epoch=13, EUBO=-4550.565, ELBO=-6026.238, ESS=4.588 (14s)
# epoch=14, EUBO=-4517.405, ELBO=-5970.796, ESS=4.607 (14s)
# epoch=15, EUBO=-4500.662, ELBO=-5934.238, ESS=4.624 (13s)
# epoch=16, EUBO=-4458.750, ELBO=-5882.848, ESS=4.643 (15s)
# epoch=17, EUBO=-4455.490, ELBO=-5861.447, ESS=4.661 (14s)
# epoch=18, EUBO=-4432.913, ELBO=-5821.595, ESS=4.682 (14s)
# epoch=19, EUBO=-4420.792, ELBO=-5801.316, ESS=4.697 (14s)
# epoch=20, EUBO=-4411.001, ELBO=-5771.905, ESS=4.716 (14s)
# epoch=21, EUBO=-4387.459, ELBO=-5745.178, ESS=4.732 (14s)
# epoch=22, EUBO=-4380.301, ELBO=-5730.383, ESS=4.749 (14s)
)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6a9941e27765> in <module>()
# ----> 1 train(Eubo_sis_init_eta, enc_eta, enc_z, optimizer, Data, K, NUM_EPOCHS, MCMC_SIZE, SAMPLE_SIZE, BATCH_SIZE, PATH, CUDA, DEVICE)
#
# ~/Research/amortized/GMM/amorgibbs/training_backward.py in train(Eubo, enc_eta, enc_z, optimizer, Data, K, num_epochs, mcmc_size, sample_size, batch_size, PATH, CUDA, device)
#      33             if CUDA:
#      34                 obs =obs.cuda().to(device)
# ---> 35             eubos, elbos, esss, q_eta, p_eta, q_z, p_z, q_nu, pr_nu = Eubo(enc_eta, enc_z, obs, K, mcmc_size, device)
#      36             kl_eta_ex, kl_eta_in, kl_z_ex, kl_z_in = kl_train(q_eta, p_eta, q_z, p_z, q_nu, pr_nu, obs, K)
#      37             ## gradient step
#
# ~/Research/amortized/GMM/amorgibbs/eubo_backward.py in Eubo_sis_init_eta(enc_eta, enc_z, obs, K, mcmc_size, device, RESAMPLE)
#     135             state = q_z['zs'].value
#     136         q_eta, p_eta, q_nu = enc_eta(obs, state, K, D)
# --> 137         eubo_eta_forward, elbo_eta_forward, ess_eta_forward, weights_eta  = Incremental_forward_eta(q_eta, p_eta, obs, state, K, D)
#     138         if RESAMPLE:
#     139             obs_mu, obs_tau = resample_eta(q_eta['means'].value, q_eta['precisions'].value, weights_eta, idw_flag=True)
#
# ~/Research/amortized/GMM/amorgibbs/eubo_backward.py in Incremental_forward_eta(q_eta, p_eta, obs, state, K, D)
#      18     obs_mu = q_eta['means'].value
#      19     obs_tau = q_eta['precisions'].value
# ---> 20     log_obs_k = Log_likelihood(obs, state, obs_mu, 1. / obs_tau.sqrt(), K, D, cluster_flag=True)
#      21     log_weights_eta = log_obs_k + log_p_eta - log_q_eta
#      22     weights_eta = F.softmax(log_weights_eta, 0).detach()
#
# ~/Research/amortized/GMM/utils.py in Log_likelihood(obs, state, obs_mu, obs_sigma, K, D, cluster_flag)
#      47     log_obs = Normal(obs_mu_expand, obs_sigma_expand).log_prob(obs).sum(-1) # S * B * N
#      48     if cluster_flag:
# ---> 49         log_obs = torch.cat([((labels==k).float() * log_obs).sum(-1).unsqueeze(-1) for k in range(K)], -1) # S * B * K
#      50     return log_obs
#
# ~/Research/amortized/GMM/utils.py in <listcomp>(.0)
#      47     log_obs = Normal(obs_mu_expand, obs_sigma_expand).log_prob(obs).sum(-1) # S * B * N
#      48     if cluster_flag:
# ---> 49         log_obs = torch.cat([((labels==k).float() * log_obs).sum(-1).unsqueeze(-1) for k in range(K)], -1) # S * B * K
#      50     return log_obs
#
# KeyboardInterrupt:

# %%
torch.save(enc_eta.state_dict(), '../weights/enc-eta-%s' + PATH)
torch.save(enc_z.state_dict(), '../weights/enc-z-%s' + PATH)

# %%
BATCH_SIZE_TEST = 50
obs, q_eta, q_z = test(Eubo_idw_init_eta, enc_eta, enc_z, Data, K, MCMC_SIZE, SAMPLE_SIZE, BATCH_SIZE_TEST, CUDA, DEVICE)
