# %%
# %matplotlib inline
# %run ../../path_import.py
from plots import *
from training import *
from eubo import *
from model_naive_natparam import *

import probtorch
print('probtorch:', probtorch.__version__, 
      'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# probtorch: 0.0+5a2c637 torch: 1.0.0 cuda: True

# %%
data_path = "../gmm_dataset_nc50k"
Data = torch.from_numpy(np.load(data_path + '/obs.npy')).float()
_, N, D = Data.shape
K = 3 ## number of clusters
## Model Parameters
MCMC_SIZE = 10
SAMPLE_SIZE = 10
NUM_HIDDEN_LOCAL = 64
## Training Parameters
BATCH_SIZE = 20
NUM_EPOCHS = 500
LEARNING_RATE = 1e-4
CUDA = torch.cuda.is_available()
PATH = 'ag-init-z-nc50k'

DEVICE = torch.device('cuda:1')

# %%
enc_eta, enc_z, optimizer = initialize(K, D, NUM_HIDDEN_LOCAL, CUDA, DEVICE, LEARNING_RATE)

# %%
train(Eubo_idw_init_z, enc_eta, enc_z, optimizer, Data, K, NUM_EPOCHS, MCMC_SIZE, SAMPLE_SIZE, BATCH_SIZE, PATH, CUDA, DEVICE)
# Out:
# epoch=0, EUBO=-504.547, ELBO=-667.306, ESS=4.045 (487s)
# epoch=1, EUBO=-350.743, ELBO=-407.666, ESS=5.077 (489s)
# epoch=2, EUBO=-284.296, ELBO=-314.646, ESS=5.432 (489s)
# epoch=3, EUBO=-248.192, ELBO=-266.324, ESS=5.686 (489s)
# epoch=4, EUBO=-240.333, ELBO=-255.321, ESS=5.910 (488s)
# epoch=5, EUBO=-236.302, ELBO=-249.775, ESS=6.022 (487s)
# epoch=6, EUBO=-232.480, ELBO=-244.751, ESS=6.049 (487s)
# epoch=7, EUBO=-228.814, ELBO=-240.159, ESS=6.039 (490s)
# epoch=8, EUBO=-226.007, ELBO=-236.813, ESS=5.993 (487s)
# epoch=9, EUBO=-225.942, ELBO=-236.810, ESS=5.867 (487s)
# epoch=10, EUBO=-225.062, ELBO=-235.644, ESS=5.763 (487s)
# epoch=11, EUBO=-222.102, ELBO=-231.618, ESS=5.855 (489s)
# epoch=12, EUBO=-220.675, ELBO=-229.491, ESS=5.999 (489s)
# epoch=13, EUBO=-219.917, ELBO=-228.296, ESS=6.174 (491s)
# epoch=14, EUBO=-219.668, ELBO=-227.764, ESS=6.354 (488s)
# epoch=15, EUBO=-219.576, ELBO=-227.506, ESS=6.501 (486s)
# epoch=16, EUBO=-219.501, ELBO=-227.339, ESS=6.604 (487s)
# epoch=17, EUBO=-219.487, ELBO=-227.253, ESS=6.664 (486s)
# epoch=18, EUBO=-219.472, ELBO=-227.204, ESS=6.695 (486s)
# epoch=19, EUBO=-219.478, ELBO=-227.214, ESS=6.711 (489s)
# epoch=20, EUBO=-219.467, ELBO=-227.178, ESS=6.717 (487s)
# epoch=21, EUBO=-219.459, ELBO=-227.163, ESS=6.722 (486s)
# epoch=22, EUBO=-219.426, ELBO=-227.150, ESS=6.722 (486s)
# epoch=23, EUBO=-219.424, ELBO=-227.134, ESS=6.727 (489s)
# epoch=24, EUBO=-219.454, ELBO=-227.171, ESS=6.724 (488s)
)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ab45036eb654> in <module>()
# ----> 1 train(Eubo_idw_init_z, enc_eta, enc_z, optimizer, Data, K, NUM_EPOCHS, MCMC_SIZE, SAMPLE_SIZE, BATCH_SIZE, PATH, CUDA, DEVICE)
#
# ~/Research/amortized/GMM/amorgibbs/training.py in train(Eubo, enc_eta, enc_z, optimizer, Data, K, num_epochs, mcmc_size, sample_size, batch_size, PATH, CUDA, device)
#      33             if CUDA:
#      34                 obs =obs.cuda().to(device)
# ---> 35             eubos, elbos, esss, q_eta, p_eta, q_z, p_z, q_nu, pr_nu = Eubo(enc_eta, enc_z, obs, N, K, D, mcmc_size, sample_size, batch_size, device)
#      36             kl_eta_ex, kl_eta_in, kl_z_ex, kl_z_in = kl_train(q_eta, p_eta, q_z, p_z, q_nu, pr_nu, obs, K)
#      37             ## gradient step
#
# ~/Research/amortized/GMM/amorgibbs/eubo.py in Eubo_idw_init_z(enc_eta, enc_z, obs, N, K, D, mcmc_size, sample_size, batch_size, device, idw_flag)
#      21             state = resample_state(state, weights_local, idw_flag=idw_flag)
#      22         ## update tau and mu -- global variables
# ---> 23         q_eta, p_eta, q_nu = enc_eta(obs, state, K, D)
#      24         log_p_eta = p_eta['means'].log_prob.sum(-1) + p_eta['precisions'].log_prob.sum(-1)
#      25         log_q_eta = q_eta['means'].log_prob.sum(-1) + q_eta['precisions'].log_prob.sum(-1)
#
# ~/anaconda3/envs/dev/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/Research/amortized/GMM/amorgibbs/model_naive_natparam.py in forward(self, obs, state, K, D)
#      40                 q_beta,
#      41                 value=precisions,
# ---> 42                 name='precisions')
#      43         p.gamma(self.prior_alpha,
#      44                 self.prior_beta,
#
# <string> in f(self, concentration, rate, validate_args, name, value)
#
# ~/Research/probtorch/probtorch/stochastic.py in variable(self, Dist, *args, **kwargs)
#     290             self.append(node)
#     291         else:
# --> 292             self[name] = node
#     293         return value
#     294
#
# ~/Research/probtorch/probtorch/stochastic.py in __setitem__(self, name, node)
#     183             raise ValueError("Trace already contains a node with "
#     184                              "name: " + name)
# --> 185         if (node.log_prob != node.log_prob).sum() > 0:
#     186             raise ValueError("NaN log prob encountered in node"
#     187                              "with name: " + name)
#
# KeyboardInterrupt:

# %%
torch.save(enc_eta.state_dict(), '../weights/enc-eta-%s' + PATH)
torch.save(enc_z.state_dict(), '../weights/enc-z-%s' + PATH)

# %%
BATCH_SIZE_TEST = 50
obs, q_eta, q_z = test(Eubo_idw_init_z, enc_eta, enc_z, Data, K, 8, SAMPLE_SIZE, BATCH_SIZE_TEST, CUDA, DEVICE)

# %%
# %time plot_samples(obs, q_eta, q_z, PATH)
