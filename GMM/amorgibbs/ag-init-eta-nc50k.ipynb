# %%
# %matplotlib inline
# %run ../../path_import.py
from plots import *
from training import *
from eubo import *
from model_naive_natparam import *

import probtorch
print('probtorch:', probtorch.__version__, 
      'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# probtorch: 0.0+5a2c637 torch: 1.0.0 cuda: True

# %%
data_path = "../gmm_dataset_nc50k"
Data = torch.from_numpy(np.load(data_path + '/obs.npy')).float()
_, N, D = Data.shape
K = 3 ## number of clusters
## Model Parameters
MCMC_SIZE = 10
SAMPLE_SIZE = 10
NUM_HIDDEN_LOCAL = 64
## Training Parameters
BATCH_SIZE = 20
NUM_EPOCHS = 500
LEARNING_RATE = 1e-4
CUDA = torch.cuda.is_available()
PATH = 'ag-init-eta-nc50k'

DEVICE = torch.device('cuda:1')

# %%
enc_eta, enc_z, optimizer = initialize(K, D, NUM_HIDDEN_LOCAL, CUDA, DEVICE, LEARNING_RATE)

# %%
train(Eubo_idw_init_eta, enc_eta, enc_z, optimizer, Data, K, NUM_EPOCHS, MCMC_SIZE, SAMPLE_SIZE, BATCH_SIZE, PATH, CUDA, DEVICE)
# Out:
# epoch=0, EUBO=-881.080, ELBO=-1277.834, ESS=3.311 (426s)
# epoch=1, EUBO=-594.309, ELBO=-753.540, ESS=4.279 (492s)
# epoch=2, EUBO=-517.945, ELBO=-633.082, ESS=4.685 (492s)
# epoch=3, EUBO=-494.618, ELBO=-595.600, ESS=4.883 (490s)
# epoch=4, EUBO=-486.856, ELBO=-581.538, ESS=4.995 (491s)
# epoch=5, EUBO=-479.825, ELBO=-569.550, ESS=5.051 (492s)
# epoch=6, EUBO=-468.842, ELBO=-553.725, ESS=5.083 (492s)
# epoch=7, EUBO=-457.435, ELBO=-538.301, ESS=5.111 (491s)
# epoch=8, EUBO=-445.057, ELBO=-522.149, ESS=5.130 (490s)
# epoch=9, EUBO=-431.020, ELBO=-504.639, ESS=5.141 (489s)
# epoch=10, EUBO=-416.047, ELBO=-486.070, ESS=5.144 (492s)
# epoch=11, EUBO=-401.143, ELBO=-466.855, ESS=5.146 (490s)
# epoch=12, EUBO=-388.200, ELBO=-450.126, ESS=5.150 (490s)
# epoch=13, EUBO=-378.844, ELBO=-437.800, ESS=5.151 (490s)
# epoch=14, EUBO=-372.321, ELBO=-429.325, ESS=5.149 (488s)
# epoch=15, EUBO=-368.792, ELBO=-424.256, ESS=5.149 (489s)
# epoch=16, EUBO=-368.279, ELBO=-422.493, ESS=5.153 (488s)
# epoch=17, EUBO=-370.625, ELBO=-424.963, ESS=5.162 (487s)
# epoch=18, EUBO=-371.725, ELBO=-427.596, ESS=5.167 (492s)
# epoch=19, EUBO=-370.673, ELBO=-427.045, ESS=5.166 (489s)
# epoch=20, EUBO=-367.497, ELBO=-424.391, ESS=5.164 (488s)
# epoch=21, EUBO=-365.174, ELBO=-422.163, ESS=5.162 (490s)
# epoch=22, EUBO=-361.798, ELBO=-418.940, ESS=5.158 (491s)
# epoch=23, EUBO=-358.453, ELBO=-415.748, ESS=5.156 (488s)
# epoch=24, EUBO=-354.687, ELBO=-411.037, ESS=5.152 (488s)
)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e1bb6f6d4414> in <module>()
# ----> 1 train(Eubo_idw_init_eta, enc_eta, enc_z, optimizer, Data, K, NUM_EPOCHS, MCMC_SIZE, SAMPLE_SIZE, BATCH_SIZE, PATH, CUDA, DEVICE)
#
# ~/Research/amortized/GMM/amorgibbs/training.py in train(Eubo, enc_eta, enc_z, optimizer, Data, K, num_epochs, mcmc_size, sample_size, batch_size, PATH, CUDA, device)
#      33             if CUDA:
#      34                 obs =obs.cuda().to(device)
# ---> 35             eubos, elbos, esss, q_eta, p_eta, q_z, p_z, q_nu, pr_nu = Eubo(enc_eta, enc_z, obs, N, K, D, mcmc_size, sample_size, batch_size, device)
#      36             kl_eta_ex, kl_eta_in, kl_z_ex, kl_z_in = kl_train(q_eta, p_eta, q_z, p_z, q_nu, pr_nu, obs, K)
#      37             ## gradient step
#
# ~/Research/amortized/GMM/amorgibbs/eubo.py in Eubo_idw_init_eta(enc_eta, enc_z, obs, N, K, D, mcmc_size, sample_size, batch_size, device, idw_flag)
#      71         state = resample_state(state, weights_local, idw_flag=idw_flag)
#      72         ## update tau and mu -- global variables
# ---> 73         q_eta, p_eta, q_nu = enc_eta(obs, state, K, D)
#      74         log_p_eta = p_eta['means'].log_prob.sum(-1) + p_eta['precisions'].log_prob.sum(-1)
#      75         log_q_eta = q_eta['means'].log_prob.sum(-1) + q_eta['precisions'].log_prob.sum(-1)
#
# ~/anaconda3/envs/dev/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/Research/amortized/GMM/amorgibbs/model_naive_natparam.py in forward(self, obs, state, K, D)
#      40                 q_beta,
#      41                 value=precisions,
# ---> 42                 name='precisions')
#      43         p.gamma(self.prior_alpha,
#      44                 self.prior_beta,
#
# <string> in f(self, concentration, rate, validate_args, name, value)
#
# ~/Research/probtorch/probtorch/stochastic.py in variable(self, Dist, *args, **kwargs)
#     290             self.append(node)
#     291         else:
# --> 292             self[name] = node
#     293         return value
#     294
#
# ~/Research/probtorch/probtorch/stochastic.py in __setitem__(self, name, node)
#     183             raise ValueError("Trace already contains a node with "
#     184                              "name: " + name)
# --> 185         if (node.log_prob != node.log_prob).sum() > 0:
#     186             raise ValueError("NaN log prob encountered in node"
#     187                              "with name: " + name)
#
# KeyboardInterrupt:

# %%
torch.save(enc_eta.state_dict(), '../weights/enc-eta-%s' + PATH)
torch.save(enc_z.state_dict(), '../weights/enc-z-%s' + PATH)

# %%
BATCH_SIZE_TEST = 50
obs, q_eta, q_z = test(Eubo_idw_init_eta, enc_eta, enc_z, Data, K, MCMC_SIZE, SAMPLE_SIZE, BATCH_SIZE_TEST, CUDA, DEVICE)

# %%
# %time plot_samples(obs, q_eta, q_z, PATH)
