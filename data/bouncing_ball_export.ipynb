# %%
import logging

import numpy as np
import probtorch
import torch

import bouncing_ball
import bouncing_ball_data
import combinators
import smc
import utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-aab4bcbcaf56> in <module>()
#       2
#       3 import numpy as np
# ----> 4 import probtorch
#       5 import torch
#       6
#
# ModuleNotFoundError: No module named 'probtorch'

# %%
import matplotlib.gridspec as gridspec
from matplotlib.collections import LineCollection

import matplotlib.pyplot as plt

# %%
logging.basicConfig(format='%(asctime)s %(message)s', datefmt='%m/%d/%Y %H:%M:%S',
                    level=logging.INFO)

# %%
## dataset parameters
T = 200 ## sequence length
num_series = 30
dt = 1 ## \delta t
Boundary = 6 ## unit box is amplified by this value, centered at origin
signal_noise_ratio = 0.2 # the noise is multiplied by this param
D = 2
## Model parameters
K =  4## number of hidden states

# %%
## generate time series
x0, y0, init_v, init_v_rand_dir = bouncing_ball_data.intialization(T, num_series, Boundary)
final_mus = np.zeros((num_series, K, D))
final_covs = np.zeros((num_series, K, D, D))
STATEs = np.zeros((num_series, T+1, 4))
Disps = np.zeros((num_series, T, D))
As_true = np.zeros((num_series, 4, 4))
As_pred = np.zeros((num_series, K, K))
for s in range(num_series):
    init_state = np.array([x0[s], y0[s], init_v_rand_dir[s, 0], init_v_rand_dir[s, 1]])
    STATEs[s], Disps[s], As_true[s] = bouncing_ball_data.generate_data(T, dt, init_state, Boundary, signal_noise_ratio)

# %%
num_particles = 100

# %%
bouncing_ball_step = combinators.Model(bouncing_ball.bouncing_ball_step, {}, {
    'delta_t': torch.ones(1),
})

# %%
smc_runner = smc.SequentialMonteCarlo(bouncing_ball_step, T)

# %%
untrained_params = {
    'position_0': {
        'loc': torch.rand(2) * Boundary,
        'scale': torch.ones(2),
    },
    'alpha_0': {
        'concentration': torch.ones(4),
    },
    'alpha_1': {
        'concentration': torch.Tensor([0.40, 0.20, 0.20, 0.20]),
    },
    'alpha_2': {
        'concentration': torch.Tensor([0.20, 0.40, 0.20, 0.20]),
    },
    'alpha_3': {
        'concentration': torch.Tensor([0.20, 0.20, 0.40, 0.20]),
    },
    'alpha_4': {
        'concentration': torch.Tensor([0.20, 0.20, 0.20, 0.40]),
    },
    'directions': {
        'loc': {
            'loc': torch.Tensor([[1, 1], [1, -1], [-1, -1], [-1, 1]]) * (1/np.sqrt(2)),
            'scale': torch.ones(4, 2) * 0.1,
        },
        'scale': {
            'loc': torch.eye(2).expand(4, 2, 2),
            'scale': torch.ones(4, 2, 2) * 0.1,
        },
    },
}

# %%
def generate_trajectory_trace(s):
    trajectory = torch.Tensor(STATEs[s])
    displacements = torch.Tensor(Disps[s])

    data = {}

    for i, point in enumerate(trajectory):
        data['position_%d' % i] = torch.Tensor(point[:2])
        if i >= 1:
            data['displacement_%d' % i] = displacements[i-1]
    
    return trajectory, displacements, data

# %%
def accumulate_trajectory(inference):
    result = torch.zeros(num_particles, len(trajectory), 2)
    result[:, 0] = inference['position_0'].value
    for t in range(len(trajectory) - 1):
        result[:, t+1] = result[:, t] + inference['displacement_%d' % (t+1)].value
    return result

# %%
def graph_position_trajectory(positions, T, s):
    gs = gridspec.GridSpec(2, 2)
    fig1 = plt.figure(figsize=(5, 5))
    ax1 = fig1.gca()

    ax1.scatter(positions[:, 0], positions[:, 1], c=np.arange(T))
    ax1.set_xlim([-Boundary, Boundary])
    ax1.set_ylim([-Boundary, Boundary])
    #ax1.set_xticks([])
    #ax1.set_yticks([])
    ax1.set_ylabel('y(t)')
    ax1.set_xlabel('x(t)')
    plt.savefig('position_trajectory_%d.pdf' % s)

# %%
def graph_displacement_trajectories(velocity_steps, displacements, T, s):
    fig2, (ax2, ax3) = plt.subplots(2, 1, sharex=True, sharey=True, figsize=(5, 5))

    dx_lc = LineCollection(velocity_steps[:, :, :2].numpy())
    dx_lc.set_array(np.arange(T - 1))
    ax2.add_collection(dx_lc)
    ax2.scatter(np.arange(T), displacements[:, 0], c=np.arange(T), s=10)
    #ax2.set_xlabel('t')
    ax2.set_ylabel('Δx')

    dy_lc = LineCollection(velocity_steps[:, :, 0:3:2].numpy())
    dy_lc.set_array(np.arange(T-1))
    ax3.add_collection(dy_lc)
    ax3.scatter(np.arange(T), displacements[:, 1], c=np.arange(T), s=10)
    ax3.set_xlabel('Time')
    ax3.set_ylabel('Δy')

    plt.savefig('time_vs_displacement_%d.pdf' % s)

# %%
def graph_velocity_frequencies(directions):
    fig = plt.figure(figsize=(6, 6))
    ax = fig.gca()

    ax.scatter(init_v[:, 0], init_v[:, 1], label='z=1')
    ax.scatter(init_v[:, 0], -init_v[:, 1], label='z=2')
    ax.scatter(-init_v[:, 0], -init_v[:, 1], label='z=3')
    ax.scatter(-init_v[:, 0], init_v[:, 1], label='z=4')
    colors = ['b', 'orange', 'g', 'r', 'k']
    for k in range(K):
        ax.scatter(directions[:, k, 0], directions[:, k, 1], c=colors[k], marker='x')

    ax.set_xlabel('X velocity')
    ax.set_ylabel('Y velocity')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4)
    plt.savefig('velocity_frequencies.pdf')

# %%
modal_directions = torch.zeros(num_series, K, 2)

for s in range(num_series):
    trajectory, displacements, data = generate_trajectory_trace(s)
    init_bouncing_ball = combinators.Model(bouncing_ball.init_bouncing_ball,
                                           untrained_params, {})
    inference, trained_params = smc.variational_smc(
        num_particles, init_bouncing_ball, smc_runner, 500, data,
        use_cuda=False, lr=1e-2, inclusive_kl=True,
    )
    inferred_trajectory = accumulate_trajectory(inference)
    
    positions = torch.stack([inferred_trajectory[:, t+1] for t in range(T)], dim=1).mean(dim=0).cpu().detach()
    displacements = torch.stack([inference['displacement_%d' % (t+1)].value for t in range(T)], dim=1).mean(dim=0).cpu().detach()
    step_numbers = torch.stack((torch.arange(T), torch.arange(T) + 1), dim=-1)
    velocity_srcs = torch.cat((torch.arange(T-1).unsqueeze(1).to(displacements), displacements[:-1]), dim=1)
    velocity_dests = torch.cat((torch.arange(T-1).unsqueeze(1).to(displacements) + 1, displacements[1:]), dim=1)
    velocity_steps = torch.stack((velocity_srcs, velocity_dests), dim=1)
    
    graph_position_trajectory(positions, T, s)
    graph_displacement_trajectories(velocity_steps, displacements, T, s)
    
    modal_directions[s] = trained_params['directions']['loc']['loc']
    final_mus[s] = inference['directions__loc'].value.mean(dim=0).detach().cpu().numpy()
    final_covs[s] = inference['directions__scale'].value.mean(dim=0).detach().cpu().numpy()
    for k in range(K):
        As_pred[s][k] = inference['A_%d' % (k+1)].value.mean(dim=0).detach().cpu().numpy()
    
    plt.close('all')

graph_velocity_frequencies(modal_directions.detach().numpy())
# Out:
# 08/01/2018 10:30:53 Variational SMC H_p[log q]=-3.34832535e+01 at epoch 1
# 08/01/2018 10:30:54 Variational SMC H_p[log q]=-3.91264992e+01 at epoch 2
# 08/01/2018 10:30:56 Variational SMC H_p[log q]=-3.69786682e+01 at epoch 3
# 08/01/2018 10:30:58 Variational SMC H_p[log q]=-1.00412254e+01 at epoch 4
# 08/01/2018 10:31:00 Variational SMC H_p[log q]=-1.14205980e+01 at epoch 5
# 08/01/2018 10:31:02 Variational SMC H_p[log q]=-3.22140541e+01 at epoch 6
# 08/01/2018 10:31:03 Variational SMC H_p[log q]=-3.30364418e+01 at epoch 7
# 08/01/2018 10:31:05 Variational SMC H_p[log q]=-2.87692699e+01 at epoch 8
# 08/01/2018 10:31:07 Variational SMC H_p[log q]=-2.29463348e+01 at epoch 9
# 08/01/2018 10:31:09 Variational SMC H_p[log q]=-3.33372955e+01 at epoch 10
# 08/01/2018 10:31:11 Variational SMC H_p[log q]=-8.44804764e+00 at epoch 11
# 08/01/2018 10:31:13 Variational SMC H_p[log q]=1.34431620e+01 at epoch 12
# 08/01/2018 10:31:15 Variational SMC H_p[log q]=-1.10579576e+01 at epoch 13
# 08/01/2018 10:31:17 Variational SMC H_p[log q]=-6.43295479e+00 at epoch 14
# 08/01/2018 10:31:19 Variational SMC H_p[log q]=-5.98336601e+00 at epoch 15
# 08/01/2018 10:31:21 Variational SMC H_p[log q]=-1.81999931e+01 at epoch 16
# 08/01/2018 10:31:23 Variational SMC H_p[log q]=-2.72945442e+01 at epoch 17
# 08/01/2018 10:31:25 Variational SMC H_p[log q]=-1.51265116e+01 at epoch 18
# 08/01/2018 10:31:27 Variational SMC H_p[log q]=-3.39622955e+01 at epoch 19
# 08/01/2018 10:31:29 Variational SMC H_p[log q]=-2.71476154e+01 at epoch 20
# 08/01/2018 10:31:31 Variational SMC H_p[log q]=-2.51164932e+01 at epoch 21
# 08/01/2018 10:31:33 Variational SMC H_p[log q]=-3.40576134e+01 at epoch 22
# 08/01/2018 10:31:35 Variational SMC H_p[log q]=-1.69241219e+01 at epoch 23
# 08/01/2018 10:31:37 Variational SMC H_p[log q]=-3.70440712e+01 at epoch 24
# 08/01/2018 10:31:39 Variational SMC H_p[log q]=-2.28210640e+01 at epoch 25
# 08/01/2018 10:31:41 Variational SMC H_p[log q]=-1.26931858e+00 at epoch 26
# 08/01/2018 10:31:44 Variational SMC H_p[log q]=-3.46603775e+01 at epoch 27
# 08/01/2018 10:31:46 Variational SMC H_p[log q]=-9.12289715e+00 at epoch 28
# 08/01/2018 10:31:48 Variational SMC H_p[log q]=-1.23008251e+01 at epoch 29
# 08/01/2018 10:31:50 Variational SMC H_p[log q]=-2.36830730e+01 at epoch 30
# 08/01/2018 10:31:52 Variational SMC H_p[log q]=-2.15433331e+01 at epoch 31
# 08/01/2018 10:31:53 Variational SMC H_p[log q]=-3.87101326e+01 at epoch 32
# 08/01/2018 10:31:56 Variational SMC H_p[log q]=-3.09819145e+01 at epoch 33
# 08/01/2018 10:31:58 Variational SMC H_p[log q]=-9.94368744e+00 at epoch 34
# 08/01/2018 10:32:00 Variational SMC H_p[log q]=-3.14512520e+01 at epoch 35
# 08/01/2018 10:32:02 Variational SMC H_p[log q]=-3.33115387e+01 at epoch 36
# 08/01/2018 10:32:04 Variational SMC H_p[log q]=-2.52111206e+01 at epoch 37
# 08/01/2018 10:32:06 Variational SMC H_p[log q]=-3.36437340e+01 at epoch 38
# 08/01/2018 10:32:08 Variational SMC H_p[log q]=-4.23815956e+01 at epoch 39
# 08/01/2018 10:32:10 Variational SMC H_p[log q]=-2.01361237e+01 at epoch 40
# 08/01/2018 10:32:12 Variational SMC H_p[log q]=-3.90805893e+01 at epoch 41
# 08/01/2018 10:32:14 Variational SMC H_p[log q]=-9.78321743e+00 at epoch 42
# 08/01/2018 10:32:16 Variational SMC H_p[log q]=-3.11512375e+01 at epoch 43
# 08/01/2018 10:32:18 Variational SMC H_p[log q]=-3.84132118e+01 at epoch 44
# 08/01/2018 10:32:20 Variational SMC H_p[log q]=-4.64283066e+01 at epoch 45
# 08/01/2018 10:32:22 Variational SMC H_p[log q]=-1.42204494e+01 at epoch 46
# 08/01/2018 10:32:24 Variational SMC H_p[log q]=-1.10589004e+00 at epoch 47
# 08/01/2018 10:32:26 Variational SMC H_p[log q]=-2.31602676e-02 at epoch 48
# 08/01/2018 10:32:28 Variational SMC H_p[log q]=-2.16970882e+01 at epoch 49
# 08/01/2018 10:32:30 Variational SMC H_p[log q]=-2.62531281e+01 at epoch 50
# 08/01/2018 10:32:32 Variational SMC H_p[log q]=-6.16594009e+01 at epoch 51
# 08/01/2018 10:32:34 Variational SMC H_p[log q]=-8.57744904e+01 at epoch 52
# 08/01/2018 10:32:36 Variational SMC H_p[log q]=-2.56080608e+01 at epoch 53
# 08/01/2018 10:32:38 Variational SMC H_p[log q]=-1.00553160e+01 at epoch 54
# 08/01/2018 10:32:40 Variational SMC H_p[log q]=-4.02309799e+01 at epoch 55
# 08/01/2018 10:32:42 Variational SMC H_p[log q]=-4.99489594e+01 at epoch 56
# 08/01/2018 10:32:44 Variational SMC H_p[log q]=7.46092272e+00 at epoch 57
# 08/01/2018 10:32:46 Variational SMC H_p[log q]=-9.64837170e+00 at epoch 58
# 08/01/2018 10:32:48 Variational SMC H_p[log q]=-5.04023476e+01 at epoch 59
# 08/01/2018 10:32:50 Variational SMC H_p[log q]=-3.63542328e+01 at epoch 60
# 08/01/2018 10:32:52 Variational SMC H_p[log q]=-4.21896057e+01 at epoch 61
# 08/01/2018 10:32:54 Variational SMC H_p[log q]=-1.01760988e+01 at epoch 62
# 08/01/2018 10:32:56 Variational SMC H_p[log q]=-6.21306725e+01 at epoch 63
# 08/01/2018 10:32:58 Variational SMC H_p[log q]=-2.63727760e+01 at epoch 64
# 08/01/2018 10:33:01 Variational SMC H_p[log q]=-3.49888191e+01 at epoch 65
# 08/01/2018 10:33:02 Variational SMC H_p[log q]=-4.64050102e+01 at epoch 66
# 08/01/2018 10:33:05 Variational SMC H_p[log q]=-2.05112915e+01 at epoch 67
# 08/01/2018 10:33:07 Variational SMC H_p[log q]=-5.93683319e+01 at epoch 68
# 08/01/2018 10:33:09 Variational SMC H_p[log q]=-3.50578766e+01 at epoch 69
# 08/01/2018 10:33:11 Variational SMC H_p[log q]=-3.96387367e+01 at epoch 70
# 08/01/2018 10:33:14 Variational SMC H_p[log q]=-2.48269138e+01 at epoch 71
# 08/01/2018 10:33:16 Variational SMC H_p[log q]=-4.26675682e+01 at epoch 72
# 08/01/2018 10:33:18 Variational SMC H_p[log q]=-8.13324642e+00 at epoch 73
# 08/01/2018 10:33:20 Variational SMC H_p[log q]=-1.51492281e+01 at epoch 74
# 08/01/2018 10:33:22 Variational SMC H_p[log q]=-3.52871857e+01 at epoch 75
# 08/01/2018 10:33:24 Variational SMC H_p[log q]=-3.19835625e+01 at epoch 76
# 08/01/2018 10:33:26 Variational SMC H_p[log q]=-2.43559513e+01 at epoch 77
# 08/01/2018 10:33:28 Variational SMC H_p[log q]=-5.42645302e+01 at epoch 78
# 08/01/2018 10:33:30 Variational SMC H_p[log q]=-6.23717728e+01 at epoch 79
# 08/01/2018 10:33:32 Variational SMC H_p[log q]=-3.42824821e+01 at epoch 80
# 08/01/2018 10:33:34 Variational SMC H_p[log q]=-7.84522820e+00 at epoch 81
# 08/01/2018 10:33:36 Variational SMC H_p[log q]=-4.65316315e+01 at epoch 82
# 08/01/2018 10:33:38 Variational SMC H_p[log q]=-4.28682671e+01 at epoch 83
# 08/01/2018 10:33:40 Variational SMC H_p[log q]=-3.07875347e+01 at epoch 84
# 08/01/2018 10:33:42 Variational SMC H_p[log q]=-3.17525024e+01 at epoch 85
# 08/01/2018 10:33:44 Variational SMC H_p[log q]=-3.58484039e+01 at epoch 86
# 08/01/2018 10:33:46 Variational SMC H_p[log q]=-6.34062691e+01 at epoch 87
# 08/01/2018 10:33:48 Variational SMC H_p[log q]=-4.31495819e+01 at epoch 88
# 08/01/2018 10:33:50 Variational SMC H_p[log q]=-1.47870483e+01 at epoch 89
# 08/01/2018 10:33:52 Variational SMC H_p[log q]=-1.74665680e+01 at epoch 90
# 08/01/2018 10:33:54 Variational SMC H_p[log q]=-1.86409245e+01 at epoch 91
# 08/01/2018 10:33:56 Variational SMC H_p[log q]=-9.45916653e+00 at epoch 92
# 08/01/2018 10:33:58 Variational SMC H_p[log q]=-3.23374863e+01 at epoch 93
# 08/01/2018 10:34:00 Variational SMC H_p[log q]=-3.10600224e+01 at epoch 94
# 08/01/2018 10:34:02 Variational SMC H_p[log q]=-4.32903900e+01 at epoch 95
# 08/01/2018 10:34:04 Variational SMC H_p[log q]=-4.46555061e+01 at epoch 96
# 08/01/2018 10:34:06 Variational SMC H_p[log q]=-2.23838882e+01 at epoch 97
# 08/01/2018 10:34:08 Variational SMC H_p[log q]=-4.91504211e+01 at epoch 98
# 08/01/2018 10:34:10 Variational SMC H_p[log q]=-1.98412914e+01 at epoch 99
# 08/01/2018 10:34:12 Variational SMC H_p[log q]=-1.66019745e+01 at epoch 100
# 08/01/2018 10:34:14 Variational SMC H_p[log q]=-5.23756409e+01 at epoch 101
# 08/01/2018 10:34:16 Variational SMC H_p[log q]=-2.05565414e+01 at epoch 102
# 08/01/2018 10:34:18 Variational SMC H_p[log q]=-5.49716339e+01 at epoch 103
# 08/01/2018 10:34:20 Variational SMC H_p[log q]=-5.97089386e+01 at epoch 104
# 08/01/2018 10:34:22 Variational SMC H_p[log q]=-2.82124310e+01 at epoch 105
# 08/01/2018 10:34:24 Variational SMC H_p[log q]=-4.41810417e+01 at epoch 106
# 08/01/2018 10:34:26 Variational SMC H_p[log q]=-5.08669548e+01 at epoch 107
# 08/01/2018 10:34:28 Variational SMC H_p[log q]=-5.73924408e+01 at epoch 108
# 08/01/2018 10:34:30 Variational SMC H_p[log q]=-4.12892342e+01 at epoch 109
# 08/01/2018 10:34:32 Variational SMC H_p[log q]=-2.38555317e+01 at epoch 110
# 08/01/2018 10:34:34 Variational SMC H_p[log q]=-3.21947975e+01 at epoch 111
# 08/01/2018 10:34:36 Variational SMC H_p[log q]=-5.61877213e+01 at epoch 112
# 08/01/2018 10:34:38 Variational SMC H_p[log q]=-2.45288944e+01 at epoch 113
# 08/01/2018 10:34:41 Variational SMC H_p[log q]=-3.82130737e+01 at epoch 114
# 08/01/2018 10:34:43 Variational SMC H_p[log q]=-4.73341293e+01 at epoch 115
# 08/01/2018 10:34:45 Variational SMC H_p[log q]=-4.71203041e+01 at epoch 116
# 08/01/2018 10:34:47 Variational SMC H_p[log q]=-2.02377052e+01 at epoch 117
# 08/01/2018 10:34:49 Variational SMC H_p[log q]=-1.72519798e+01 at epoch 118
# 08/01/2018 10:34:51 Variational SMC H_p[log q]=-4.31555748e+01 at epoch 119
# 08/01/2018 10:34:53 Variational SMC H_p[log q]=-4.69643250e+01 at epoch 120
# 08/01/2018 10:34:55 Variational SMC H_p[log q]=-5.38970985e+01 at epoch 121
# 08/01/2018 10:34:57 Variational SMC H_p[log q]=-3.32033005e+01 at epoch 122
# 08/01/2018 10:34:59 Variational SMC H_p[log q]=-2.53077469e+01 at epoch 123
# 08/01/2018 10:35:01 Variational SMC H_p[log q]=-5.48876648e+01 at epoch 124
# 08/01/2018 10:35:03 Variational SMC H_p[log q]=-4.14080315e+01 at epoch 125
# 08/01/2018 10:35:05 Variational SMC H_p[log q]=-6.73086929e+01 at epoch 126
# 08/01/2018 10:35:07 Variational SMC H_p[log q]=-5.04221573e+01 at epoch 127
# 08/01/2018 10:35:09 Variational SMC H_p[log q]=-4.87410431e+01 at epoch 128
# 08/01/2018 10:35:11 Variational SMC H_p[log q]=-3.68224373e+01 at epoch 129
# 08/01/2018 10:35:13 Variational SMC H_p[log q]=-3.17198410e+01 at epoch 130
# 08/01/2018 10:35:15 Variational SMC H_p[log q]=-4.22996826e+01 at epoch 131
# 08/01/2018 10:35:17 Variational SMC H_p[log q]=-4.19191513e+01 at epoch 132
# 08/01/2018 10:35:19 Variational SMC H_p[log q]=-5.50205460e+01 at epoch 133
# 08/01/2018 10:35:21 Variational SMC H_p[log q]=-3.76683846e+01 at epoch 134
# 08/01/2018 10:35:24 Variational SMC H_p[log q]=-4.94921837e+01 at epoch 135
# 08/01/2018 10:35:26 Variational SMC H_p[log q]=-5.10031395e+01 at epoch 136
# 08/01/2018 10:35:28 Variational SMC H_p[log q]=-5.61125031e+01 at epoch 137
# 08/01/2018 10:35:30 Variational SMC H_p[log q]=-3.09055672e+01 at epoch 138
# 08/01/2018 10:35:32 Variational SMC H_p[log q]=-8.33021317e+01 at epoch 139
# 08/01/2018 10:35:34 Variational SMC H_p[log q]=-4.37241325e+01 at epoch 140
# 08/01/2018 10:35:36 Variational SMC H_p[log q]=-6.94517365e+01 at epoch 141
# 08/01/2018 10:35:38 Variational SMC H_p[log q]=-2.26187496e+01 at epoch 142
# 08/01/2018 10:35:40 Variational SMC H_p[log q]=-6.67865677e+01 at epoch 143
# 08/01/2018 10:35:42 Variational SMC H_p[log q]=-5.48709908e+01 at epoch 144
# 08/01/2018 10:35:44 Variational SMC H_p[log q]=-6.74503937e+01 at epoch 145
# 08/01/2018 10:35:46 Variational SMC H_p[log q]=-6.01833725e+01 at epoch 146
# 08/01/2018 10:35:48 Variational SMC H_p[log q]=-3.91265984e+01 at epoch 147
# 08/01/2018 10:35:50 Variational SMC H_p[log q]=-6.63101883e+01 at epoch 148
# 08/01/2018 10:35:52 Variational SMC H_p[log q]=-4.48670273e+01 at epoch 149
# 08/01/2018 10:35:54 Variational SMC H_p[log q]=-6.18962593e+01 at epoch 150
# 08/01/2018 10:35:56 Variational SMC H_p[log q]=-4.35446434e+01 at epoch 151
# 08/01/2018 10:35:58 Variational SMC H_p[log q]=-6.40087509e+01 at epoch 152
# 08/01/2018 10:36:00 Variational SMC H_p[log q]=-5.37444000e+01 at epoch 153
# 08/01/2018 10:36:02 Variational SMC H_p[log q]=-6.44512558e+01 at epoch 154
# 08/01/2018 10:36:04 Variational SMC H_p[log q]=-2.61953011e+01 at epoch 155
# 08/01/2018 10:36:06 Variational SMC H_p[log q]=-2.23915501e+01 at epoch 156
# 08/01/2018 10:36:07 Variational SMC H_p[log q]=-7.95898056e+01 at epoch 157
# 08/01/2018 10:36:09 Variational SMC H_p[log q]=-6.91081543e+01 at epoch 158
# 08/01/2018 10:36:11 Variational SMC H_p[log q]=-6.69240265e+01 at epoch 159
# 08/01/2018 10:36:13 Variational SMC H_p[log q]=-3.55186348e+01 at epoch 160
# 08/01/2018 10:36:15 Variational SMC H_p[log q]=-4.33968735e+01 at epoch 161
# 08/01/2018 10:36:17 Variational SMC H_p[log q]=-5.89875145e+01 at epoch 162
# 08/01/2018 10:36:19 Variational SMC H_p[log q]=-3.58328629e+01 at epoch 163
# 08/01/2018 10:36:22 Variational SMC H_p[log q]=-7.85287476e+01 at epoch 164
# 08/01/2018 10:36:24 Variational SMC H_p[log q]=-5.11647949e+01 at epoch 165
# 08/01/2018 10:36:26 Variational SMC H_p[log q]=-8.06248474e+01 at epoch 166
# 08/01/2018 10:36:28 Variational SMC H_p[log q]=-3.54279404e+01 at epoch 167
# 08/01/2018 10:36:30 Variational SMC H_p[log q]=-5.48879280e+01 at epoch 168
# 08/01/2018 10:36:32 Variational SMC H_p[log q]=-8.56630478e+01 at epoch 169
# 08/01/2018 10:36:34 Variational SMC H_p[log q]=-6.04571037e+01 at epoch 170
# 08/01/2018 10:36:37 Variational SMC H_p[log q]=-3.67864609e+01 at epoch 171
# 08/01/2018 10:36:39 Variational SMC H_p[log q]=-8.50972366e+01 at epoch 172
# 08/01/2018 10:36:41 Variational SMC H_p[log q]=-6.94286194e+01 at epoch 173
# 08/01/2018 10:36:44 Variational SMC H_p[log q]=-6.40127869e+01 at epoch 174
# 08/01/2018 10:36:46 Variational SMC H_p[log q]=-4.63633270e+01 at epoch 175
# 08/01/2018 10:36:49 Variational SMC H_p[log q]=-5.63098488e+01 at epoch 176
# 08/01/2018 10:36:52 Variational SMC H_p[log q]=-7.43791809e+01 at epoch 177
# 08/01/2018 10:36:54 Variational SMC H_p[log q]=-7.04047546e+01 at epoch 178
# 08/01/2018 10:36:57 Variational SMC H_p[log q]=-6.68981323e+01 at epoch 179
# 08/01/2018 10:36:59 Variational SMC H_p[log q]=-6.33414955e+01 at epoch 180
# 08/01/2018 10:37:01 Variational SMC H_p[log q]=-1.12354218e+02 at epoch 181
# 08/01/2018 10:37:04 Variational SMC H_p[log q]=-9.14488831e+01 at epoch 182
# 08/01/2018 10:37:06 Variational SMC H_p[log q]=-7.31401672e+01 at epoch 183
# 08/01/2018 10:37:09 Variational SMC H_p[log q]=-4.28871384e+01 at epoch 184
# 08/01/2018 10:37:12 Variational SMC H_p[log q]=-6.45444794e+01 at epoch 185
# 08/01/2018 10:37:15 Variational SMC H_p[log q]=-5.21113319e+01 at epoch 186
# 08/01/2018 10:37:18 Variational SMC H_p[log q]=-7.81992264e+01 at epoch 187
# 08/01/2018 10:37:20 Variational SMC H_p[log q]=-8.22560730e+01 at epoch 188
# 08/01/2018 10:37:22 Variational SMC H_p[log q]=-4.76205597e+01 at epoch 189
# 08/01/2018 10:37:24 Variational SMC H_p[log q]=-4.96712837e+01 at epoch 190
# 08/01/2018 10:37:27 Variational SMC H_p[log q]=-8.61133728e+01 at epoch 191
# 08/01/2018 10:37:29 Variational SMC H_p[log q]=-5.01849213e+01 at epoch 192
# 08/01/2018 10:37:31 Variational SMC H_p[log q]=-8.16040344e+01 at epoch 193
# 08/01/2018 10:37:34 Variational SMC H_p[log q]=-7.06039963e+01 at epoch 194
# 08/01/2018 10:37:36 Variational SMC H_p[log q]=-4.17330437e+01 at epoch 195
# 08/01/2018 10:37:38 Variational SMC H_p[log q]=-7.01016159e+01 at epoch 196
# 08/01/2018 10:37:40 Variational SMC H_p[log q]=-8.62286224e+01 at epoch 197
# 08/01/2018 10:37:42 Variational SMC H_p[log q]=-6.51257629e+01 at epoch 198
# 08/01/2018 10:37:44 Variational SMC H_p[log q]=-6.95314941e+01 at epoch 199
# 08/01/2018 10:37:47 Variational SMC H_p[log q]=-6.04669685e+01 at epoch 200
# 08/01/2018 10:37:49 Variational SMC H_p[log q]=-7.10793228e+01 at epoch 201
# 08/01/2018 10:37:51 Variational SMC H_p[log q]=-6.91445618e+01 at epoch 202
# 08/01/2018 10:37:53 Variational SMC H_p[log q]=-4.46238289e+01 at epoch 203
# 08/01/2018 10:37:55 Variational SMC H_p[log q]=-9.33442154e+01 at epoch 204
# 08/01/2018 10:37:57 Variational SMC H_p[log q]=-7.90284805e+01 at epoch 205
# 08/01/2018 10:37:59 Variational SMC H_p[log q]=-5.94087639e+01 at epoch 206
# 08/01/2018 10:38:01 Variational SMC H_p[log q]=-9.08508530e+01 at epoch 207
# 08/01/2018 10:38:03 Variational SMC H_p[log q]=-7.94931183e+01 at epoch 208
# 08/01/2018 10:38:05 Variational SMC H_p[log q]=-7.05555191e+01 at epoch 209
# 08/01/2018 10:38:07 Variational SMC H_p[log q]=-6.51959152e+01 at epoch 210
# 08/01/2018 10:38:09 Variational SMC H_p[log q]=-6.71324005e+01 at epoch 211
# 08/01/2018 10:38:11 Variational SMC H_p[log q]=-5.66604233e+01 at epoch 212
# 08/01/2018 10:38:14 Variational SMC H_p[log q]=-5.35907288e+01 at epoch 213
# 08/01/2018 10:38:16 Variational SMC H_p[log q]=-1.26056305e+02 at epoch 214
# 08/01/2018 10:38:18 Variational SMC H_p[log q]=-6.41338120e+01 at epoch 215
# 08/01/2018 10:38:20 Variational SMC H_p[log q]=-6.27083282e+01 at epoch 216
# 08/01/2018 10:38:22 Variational SMC H_p[log q]=-1.08033562e+02 at epoch 217
# 08/01/2018 10:38:25 Variational SMC H_p[log q]=-7.73677139e+01 at epoch 218
# 08/01/2018 10:38:27 Variational SMC H_p[log q]=-6.62643967e+01 at epoch 219
# 08/01/2018 10:38:29 Variational SMC H_p[log q]=-8.90229797e+01 at epoch 220
# 08/01/2018 10:38:31 Variational SMC H_p[log q]=-7.49424744e+01 at epoch 221
# 08/01/2018 10:38:33 Variational SMC H_p[log q]=-6.34242973e+01 at epoch 222
# 08/01/2018 10:38:35 Variational SMC H_p[log q]=-7.82454605e+01 at epoch 223
# 08/01/2018 10:38:37 Variational SMC H_p[log q]=-9.16387100e+01 at epoch 224
# 08/01/2018 10:38:39 Variational SMC H_p[log q]=-7.74787140e+01 at epoch 225
# 08/01/2018 10:38:41 Variational SMC H_p[log q]=-6.74095917e+01 at epoch 226
# 08/01/2018 10:38:43 Variational SMC H_p[log q]=-7.50370865e+01 at epoch 227
# 08/01/2018 10:38:44 Variational SMC H_p[log q]=-7.06016769e+01 at epoch 228
# 08/01/2018 10:38:46 Variational SMC H_p[log q]=-5.74971886e+01 at epoch 229
# 08/01/2018 10:38:48 Variational SMC H_p[log q]=-8.54220276e+01 at epoch 230
# 08/01/2018 10:38:50 Variational SMC H_p[log q]=-9.50225067e+01 at epoch 231
# 08/01/2018 10:38:52 Variational SMC H_p[log q]=-6.99385529e+01 at epoch 232
# 08/01/2018 10:38:54 Variational SMC H_p[log q]=-1.17339691e+02 at epoch 233
# 08/01/2018 10:38:56 Variational SMC H_p[log q]=-8.05319214e+01 at epoch 234
# 08/01/2018 10:38:58 Variational SMC H_p[log q]=-1.05885361e+02 at epoch 235
# 08/01/2018 10:38:59 Variational SMC H_p[log q]=-8.54916687e+01 at epoch 236
# 08/01/2018 10:39:01 Variational SMC H_p[log q]=-7.65723038e+01 at epoch 237
# 08/01/2018 10:39:03 Variational SMC H_p[log q]=-9.86739578e+01 at epoch 238
# 08/01/2018 10:39:05 Variational SMC H_p[log q]=-6.01437645e+01 at epoch 239
# 08/01/2018 10:39:07 Variational SMC H_p[log q]=-8.55843735e+01 at epoch 240
# 08/01/2018 10:39:09 Variational SMC H_p[log q]=-6.61073303e+01 at epoch 241
# 08/01/2018 10:39:11 Variational SMC H_p[log q]=-7.15316162e+01 at epoch 242
# 08/01/2018 10:39:13 Variational SMC H_p[log q]=-1.06567024e+02 at epoch 243
# 08/01/2018 10:39:15 Variational SMC H_p[log q]=-9.71609116e+01 at epoch 244
# 08/01/2018 10:39:16 Variational SMC H_p[log q]=-9.93239822e+01 at epoch 245
# 08/01/2018 10:39:18 Variational SMC H_p[log q]=-7.60737000e+01 at epoch 246
# 08/01/2018 10:39:20 Variational SMC H_p[log q]=-1.05862946e+02 at epoch 247
# 08/01/2018 10:39:22 Variational SMC H_p[log q]=-1.16673302e+02 at epoch 248
# 08/01/2018 10:39:24 Variational SMC H_p[log q]=-1.01114952e+02 at epoch 249
# 08/01/2018 10:39:26 Variational SMC H_p[log q]=-9.90315247e+01 at epoch 250
# 08/01/2018 10:39:28 Variational SMC H_p[log q]=-9.90121613e+01 at epoch 251
# 08/01/2018 10:39:30 Variational SMC H_p[log q]=-6.11997528e+01 at epoch 252
# 08/01/2018 10:39:31 Variational SMC H_p[log q]=-1.13520134e+02 at epoch 253
# 08/01/2018 10:39:33 Variational SMC H_p[log q]=-1.27170067e+02 at epoch 254
# 08/01/2018 10:39:35 Variational SMC H_p[log q]=-1.00196632e+02 at epoch 255
# 08/01/2018 10:39:37 Variational SMC H_p[log q]=-1.36127014e+02 at epoch 256
# 08/01/2018 10:39:39 Variational SMC H_p[log q]=-9.17830353e+01 at epoch 257
# 08/01/2018 10:39:41 Variational SMC H_p[log q]=-1.19373093e+02 at epoch 258
# 08/01/2018 10:39:43 Variational SMC H_p[log q]=-8.15945740e+01 at epoch 259
# 08/01/2018 10:39:44 Variational SMC H_p[log q]=-1.15825150e+02 at epoch 260
# 08/01/2018 10:39:46 Variational SMC H_p[log q]=-1.34199387e+02 at epoch 261
# 08/01/2018 10:39:48 Variational SMC H_p[log q]=-9.18661880e+01 at epoch 262
# 08/01/2018 10:39:50 Variational SMC H_p[log q]=-9.16226196e+01 at epoch 263
# 08/01/2018 10:39:52 Variational SMC H_p[log q]=-6.94791870e+01 at epoch 264
# 08/01/2018 10:39:54 Variational SMC H_p[log q]=-1.15030563e+02 at epoch 265
# 08/01/2018 10:39:56 Variational SMC H_p[log q]=-9.00658188e+01 at epoch 266
# 08/01/2018 10:39:58 Variational SMC H_p[log q]=-1.14670021e+02 at epoch 267
# 08/01/2018 10:39:59 Variational SMC H_p[log q]=-9.73021774e+01 at epoch 268
# 08/01/2018 10:40:01 Variational SMC H_p[log q]=-9.27393188e+01 at epoch 269
# 08/01/2018 10:40:03 Variational SMC H_p[log q]=-1.11292488e+02 at epoch 270
# 08/01/2018 10:40:05 Variational SMC H_p[log q]=-7.87210083e+01 at epoch 271
# 08/01/2018 10:40:07 Variational SMC H_p[log q]=-8.37481842e+01 at epoch 272
# 08/01/2018 10:40:09 Variational SMC H_p[log q]=-1.28670120e+02 at epoch 273
# 08/01/2018 10:40:11 Variational SMC H_p[log q]=-7.22911987e+01 at epoch 274
# 08/01/2018 10:40:13 Variational SMC H_p[log q]=-8.31552429e+01 at epoch 275
# 08/01/2018 10:40:15 Variational SMC H_p[log q]=-1.19344353e+02 at epoch 276
# 08/01/2018 10:40:16 Variational SMC H_p[log q]=-7.45430832e+01 at epoch 277
# 08/01/2018 10:40:18 Variational SMC H_p[log q]=-1.14981781e+02 at epoch 278
# 08/01/2018 10:40:20 Variational SMC H_p[log q]=-1.01140915e+02 at epoch 279
# 08/01/2018 10:40:22 Variational SMC H_p[log q]=-8.21053391e+01 at epoch 280
# 08/01/2018 10:40:24 Variational SMC H_p[log q]=-1.07247704e+02 at epoch 281
# 08/01/2018 10:40:26 Variational SMC H_p[log q]=-1.31410980e+02 at epoch 282
# 08/01/2018 10:40:28 Variational SMC H_p[log q]=-1.38693344e+02 at epoch 283
# 08/01/2018 10:40:30 Variational SMC H_p[log q]=-1.29971634e+02 at epoch 284
# 08/01/2018 10:40:32 Variational SMC H_p[log q]=-9.45411224e+01 at epoch 285
# 08/01/2018 10:40:34 Variational SMC H_p[log q]=-1.18791786e+02 at epoch 286
# 08/01/2018 10:40:36 Variational SMC H_p[log q]=-1.11211121e+02 at epoch 287
# 08/01/2018 10:40:37 Variational SMC H_p[log q]=-1.27193054e+02 at epoch 288
# 08/01/2018 10:40:39 Variational SMC H_p[log q]=-1.08725983e+02 at epoch 289
# 08/01/2018 10:40:41 Variational SMC H_p[log q]=-1.14759583e+02 at epoch 290
# 08/01/2018 10:40:43 Variational SMC H_p[log q]=-1.43940063e+02 at epoch 291
# 08/01/2018 10:40:45 Variational SMC H_p[log q]=-1.35084473e+02 at epoch 292
# 08/01/2018 10:40:47 Variational SMC H_p[log q]=-1.47019714e+02 at epoch 293
# 08/01/2018 10:40:49 Variational SMC H_p[log q]=-1.38790344e+02 at epoch 294
# 08/01/2018 10:40:51 Variational SMC H_p[log q]=-1.07414665e+02 at epoch 295
# 08/01/2018 10:40:53 Variational SMC H_p[log q]=-1.22502853e+02 at epoch 296
# 08/01/2018 10:40:55 Variational SMC H_p[log q]=-1.18151466e+02 at epoch 297
# 08/01/2018 10:40:57 Variational SMC H_p[log q]=-1.81242615e+02 at epoch 298
# 08/01/2018 10:40:58 Variational SMC H_p[log q]=-1.23621628e+02 at epoch 299
# 08/01/2018 10:41:00 Variational SMC H_p[log q]=-1.53482437e+02 at epoch 300
# 08/01/2018 10:41:02 Variational SMC H_p[log q]=-1.22635109e+02 at epoch 301
# 08/01/2018 10:41:04 Variational SMC H_p[log q]=-1.31685562e+02 at epoch 302
# 08/01/2018 10:41:06 Variational SMC H_p[log q]=-1.16556778e+02 at epoch 303
# 08/01/2018 10:41:08 Variational SMC H_p[log q]=-1.35752686e+02 at epoch 304
# 08/01/2018 10:41:10 Variational SMC H_p[log q]=-1.50902039e+02 at epoch 305
# 08/01/2018 10:41:12 Variational SMC H_p[log q]=-1.25016937e+02 at epoch 306
# 08/01/2018 10:41:13 Variational SMC H_p[log q]=-1.57902405e+02 at epoch 307
# 08/01/2018 10:41:15 Variational SMC H_p[log q]=-1.46251282e+02 at epoch 308
# 08/01/2018 10:41:17 Variational SMC H_p[log q]=-1.38526093e+02 at epoch 309
# 08/01/2018 10:41:19 Variational SMC H_p[log q]=-1.33202271e+02 at epoch 310
# 08/01/2018 10:41:21 Variational SMC H_p[log q]=-1.33573883e+02 at epoch 311
# 08/01/2018 10:41:23 Variational SMC H_p[log q]=-1.39537521e+02 at epoch 312
# 08/01/2018 10:41:25 Variational SMC H_p[log q]=-1.51454330e+02 at epoch 313
# 08/01/2018 10:41:27 Variational SMC H_p[log q]=-1.06440918e+02 at epoch 314
# 08/01/2018 10:41:29 Variational SMC H_p[log q]=-1.12927429e+02 at epoch 315
# 08/01/2018 10:41:30 Variational SMC H_p[log q]=-1.18423210e+02 at epoch 316
# 08/01/2018 10:41:32 Variational SMC H_p[log q]=-9.94871521e+01 at epoch 317
# 08/01/2018 10:41:34 Variational SMC H_p[log q]=-1.37685852e+02 at epoch 318
# 08/01/2018 10:41:36 Variational SMC H_p[log q]=-1.18857903e+02 at epoch 319
# 08/01/2018 10:41:38 Variational SMC H_p[log q]=-1.43243103e+02 at epoch 320
# 08/01/2018 10:41:40 Variational SMC H_p[log q]=-1.10395042e+02 at epoch 321
# 08/01/2018 10:41:42 Variational SMC H_p[log q]=-1.33964798e+02 at epoch 322
# 08/01/2018 10:41:44 Variational SMC H_p[log q]=-1.03189529e+02 at epoch 323
# 08/01/2018 10:41:46 Variational SMC H_p[log q]=-1.40406189e+02 at epoch 324
# 08/01/2018 10:41:47 Variational SMC H_p[log q]=-1.39858887e+02 at epoch 325
# 08/01/2018 10:41:49 Variational SMC H_p[log q]=-1.51599289e+02 at epoch 326
# 08/01/2018 10:41:51 Variational SMC H_p[log q]=-1.50642288e+02 at epoch 327
# 08/01/2018 10:41:53 Variational SMC H_p[log q]=-1.43615417e+02 at epoch 328
# 08/01/2018 10:41:55 Variational SMC H_p[log q]=-1.69024750e+02 at epoch 329
# 08/01/2018 10:41:57 Variational SMC H_p[log q]=-1.38627197e+02 at epoch 330
# 08/01/2018 10:41:59 Variational SMC H_p[log q]=-1.66430099e+02 at epoch 331
# 08/01/2018 10:42:01 Variational SMC H_p[log q]=-1.33690933e+02 at epoch 332
# 08/01/2018 10:42:02 Variational SMC H_p[log q]=-1.66989746e+02 at epoch 333
# 08/01/2018 10:42:04 Variational SMC H_p[log q]=-1.82927292e+02 at epoch 334
# 08/01/2018 10:42:06 Variational SMC H_p[log q]=-1.08552887e+02 at epoch 335
# 08/01/2018 10:42:08 Variational SMC H_p[log q]=-1.19524101e+02 at epoch 336
# 08/01/2018 10:42:10 Variational SMC H_p[log q]=-2.02834412e+02 at epoch 337
# 08/01/2018 10:42:11 Variational SMC H_p[log q]=-1.36376648e+02 at epoch 338
# 08/01/2018 10:42:13 Variational SMC H_p[log q]=-1.49635269e+02 at epoch 339
# 08/01/2018 10:42:15 Variational SMC H_p[log q]=-1.37085846e+02 at epoch 340
# 08/01/2018 10:42:17 Variational SMC H_p[log q]=-1.22977600e+02 at epoch 341
# 08/01/2018 10:42:19 Variational SMC H_p[log q]=-1.45146255e+02 at epoch 342
# 08/01/2018 10:42:21 Variational SMC H_p[log q]=-1.53827484e+02 at epoch 343
# 08/01/2018 10:42:23 Variational SMC H_p[log q]=-1.30447266e+02 at epoch 344
# 08/01/2018 10:42:25 Variational SMC H_p[log q]=-1.21524971e+02 at epoch 345
# 08/01/2018 10:42:27 Variational SMC H_p[log q]=-1.93696213e+02 at epoch 346
# 08/01/2018 10:42:29 Variational SMC H_p[log q]=-1.22261742e+02 at epoch 347
# 08/01/2018 10:42:31 Variational SMC H_p[log q]=-1.73507462e+02 at epoch 348
# 08/01/2018 10:42:33 Variational SMC H_p[log q]=-1.57765961e+02 at epoch 349
# 08/01/2018 10:42:35 Variational SMC H_p[log q]=-1.71615417e+02 at epoch 350
# 08/01/2018 10:42:37 Variational SMC H_p[log q]=-1.57329147e+02 at epoch 351
# 08/01/2018 10:42:39 Variational SMC H_p[log q]=-1.61100250e+02 at epoch 352
# 08/01/2018 10:42:41 Variational SMC H_p[log q]=-1.62377609e+02 at epoch 353
# 08/01/2018 10:42:43 Variational SMC H_p[log q]=-2.19065369e+02 at epoch 354
# 08/01/2018 10:42:44 Variational SMC H_p[log q]=-1.70866837e+02 at epoch 355
# 08/01/2018 10:42:46 Variational SMC H_p[log q]=-1.29151031e+02 at epoch 356
# 08/01/2018 10:42:48 Variational SMC H_p[log q]=-1.62741486e+02 at epoch 357
# 08/01/2018 10:42:50 Variational SMC H_p[log q]=-1.33442307e+02 at epoch 358
# 08/01/2018 10:42:52 Variational SMC H_p[log q]=-1.42342346e+02 at epoch 359
# 08/01/2018 10:42:54 Variational SMC H_p[log q]=-1.93520157e+02 at epoch 360
# 08/01/2018 10:42:56 Variational SMC H_p[log q]=-1.26589134e+02 at epoch 361
# 08/01/2018 10:42:58 Variational SMC H_p[log q]=-2.20269943e+02 at epoch 362
# 08/01/2018 10:43:00 Variational SMC H_p[log q]=-1.78222992e+02 at epoch 363
# 08/01/2018 10:43:02 Variational SMC H_p[log q]=-1.55930328e+02 at epoch 364
# 08/01/2018 10:43:04 Variational SMC H_p[log q]=-1.73447144e+02 at epoch 365
# 08/01/2018 10:43:06 Variational SMC H_p[log q]=-1.93493576e+02 at epoch 366
# 08/01/2018 10:43:08 Variational SMC H_p[log q]=-1.73379395e+02 at epoch 367
# 08/01/2018 10:43:09 Variational SMC H_p[log q]=-1.51279984e+02 at epoch 368
# 08/01/2018 10:43:11 Variational SMC H_p[log q]=-2.11463379e+02 at epoch 369
# 08/01/2018 10:43:13 Variational SMC H_p[log q]=-1.78209549e+02 at epoch 370
# 08/01/2018 10:43:15 Variational SMC H_p[log q]=-2.02257721e+02 at epoch 371
# 08/01/2018 10:43:17 Variational SMC H_p[log q]=-1.19173752e+02 at epoch 372
# 08/01/2018 10:43:19 Variational SMC H_p[log q]=-1.90315277e+02 at epoch 373
# 08/01/2018 10:43:21 Variational SMC H_p[log q]=-1.72779144e+02 at epoch 374
# 08/01/2018 10:43:23 Variational SMC H_p[log q]=-2.00532089e+02 at epoch 375
# 08/01/2018 10:43:24 Variational SMC H_p[log q]=-1.40926895e+02 at epoch 376
# 08/01/2018 10:43:26 Variational SMC H_p[log q]=-1.54318893e+02 at epoch 377
# 08/01/2018 10:43:28 Variational SMC H_p[log q]=-1.89085800e+02 at epoch 378
# 08/01/2018 10:43:30 Variational SMC H_p[log q]=-1.74248199e+02 at epoch 379
# 08/01/2018 10:43:32 Variational SMC H_p[log q]=-1.64770645e+02 at epoch 380
# 08/01/2018 10:43:34 Variational SMC H_p[log q]=-2.23494553e+02 at epoch 381
# 08/01/2018 10:43:36 Variational SMC H_p[log q]=-2.11168533e+02 at epoch 382
# 08/01/2018 10:43:38 Variational SMC H_p[log q]=-2.05570938e+02 at epoch 383
# 08/01/2018 10:43:40 Variational SMC H_p[log q]=-1.79300842e+02 at epoch 384
# 08/01/2018 10:43:42 Variational SMC H_p[log q]=-1.80264450e+02 at epoch 385
# 08/01/2018 10:43:44 Variational SMC H_p[log q]=-1.60212112e+02 at epoch 386
# 08/01/2018 10:43:46 Variational SMC H_p[log q]=-1.76378754e+02 at epoch 387
# 08/01/2018 10:43:48 Variational SMC H_p[log q]=-1.90069382e+02 at epoch 388
# 08/01/2018 10:43:50 Variational SMC H_p[log q]=-1.71801453e+02 at epoch 389
# 08/01/2018 10:43:51 Variational SMC H_p[log q]=-1.65195862e+02 at epoch 390
# 08/01/2018 10:43:53 Variational SMC H_p[log q]=-1.85494919e+02 at epoch 391
# 08/01/2018 10:43:55 Variational SMC H_p[log q]=-2.02276993e+02 at epoch 392
# 08/01/2018 10:43:57 Variational SMC H_p[log q]=-1.84666931e+02 at epoch 393
# 08/01/2018 10:43:59 Variational SMC H_p[log q]=-1.57561111e+02 at epoch 394
# 08/01/2018 10:44:01 Variational SMC H_p[log q]=-1.92252808e+02 at epoch 395
# 08/01/2018 10:44:03 Variational SMC H_p[log q]=-1.90333420e+02 at epoch 396
# 08/01/2018 10:44:05 Variational SMC H_p[log q]=-1.95115387e+02 at epoch 397
# 08/01/2018 10:44:07 Variational SMC H_p[log q]=-2.12840454e+02 at epoch 398
# 08/01/2018 10:44:09 Variational SMC H_p[log q]=-1.97811798e+02 at epoch 399
# 08/01/2018 10:44:10 Variational SMC H_p[log q]=-1.90018433e+02 at epoch 400
# 08/01/2018 10:44:12 Variational SMC H_p[log q]=-1.66710022e+02 at epoch 401
# 08/01/2018 10:44:14 Variational SMC H_p[log q]=-2.43921738e+02 at epoch 402
# 08/01/2018 10:44:16 Variational SMC H_p[log q]=-1.78867615e+02 at epoch 403
# 08/01/2018 10:44:18 Variational SMC H_p[log q]=-1.50980865e+02 at epoch 404
# 08/01/2018 10:44:20 Variational SMC H_p[log q]=-2.32761841e+02 at epoch 405
# 08/01/2018 10:44:22 Variational SMC H_p[log q]=-2.22321289e+02 at epoch 406
# 08/01/2018 10:44:23 Variational SMC H_p[log q]=-2.14670425e+02 at epoch 407
# 08/01/2018 10:44:25 Variational SMC H_p[log q]=-2.01727127e+02 at epoch 408
# 08/01/2018 10:44:27 Variational SMC H_p[log q]=-1.80783112e+02 at epoch 409
# 08/01/2018 10:44:29 Variational SMC H_p[log q]=-2.29211166e+02 at epoch 410
# 08/01/2018 10:44:31 Variational SMC H_p[log q]=-1.76564957e+02 at epoch 411
# 08/01/2018 10:44:33 Variational SMC H_p[log q]=-2.40212250e+02 at epoch 412
# 08/01/2018 10:44:35 Variational SMC H_p[log q]=-1.54536362e+02 at epoch 413
# 08/01/2018 10:44:36 Variational SMC H_p[log q]=-1.69204712e+02 at epoch 414
# 08/01/2018 10:44:38 Variational SMC H_p[log q]=-1.91776505e+02 at epoch 415
# 08/01/2018 10:44:40 Variational SMC H_p[log q]=-2.07469437e+02 at epoch 416
# 08/01/2018 10:44:42 Variational SMC H_p[log q]=-1.95514633e+02 at epoch 417
# 08/01/2018 10:44:44 Variational SMC H_p[log q]=-1.67187637e+02 at epoch 418
# 08/01/2018 10:44:46 Variational SMC H_p[log q]=-2.09196930e+02 at epoch 419
# 08/01/2018 10:44:48 Variational SMC H_p[log q]=-2.02264725e+02 at epoch 420
# 08/01/2018 10:44:50 Variational SMC H_p[log q]=-1.86074219e+02 at epoch 421
# 08/01/2018 10:44:52 Variational SMC H_p[log q]=-2.36232269e+02 at epoch 422
# 08/01/2018 10:44:54 Variational SMC H_p[log q]=-2.10951111e+02 at epoch 423
# 08/01/2018 10:44:55 Variational SMC H_p[log q]=-1.92631393e+02 at epoch 424
# 08/01/2018 10:44:57 Variational SMC H_p[log q]=-2.12631561e+02 at epoch 425
# 08/01/2018 10:44:59 Variational SMC H_p[log q]=-2.22067169e+02 at epoch 426
# 08/01/2018 10:45:01 Variational SMC H_p[log q]=-2.31269897e+02 at epoch 427
# 08/01/2018 10:45:03 Variational SMC H_p[log q]=-1.77937927e+02 at epoch 428
# 08/01/2018 10:45:05 Variational SMC H_p[log q]=-1.88481293e+02 at epoch 429
# 08/01/2018 10:45:07 Variational SMC H_p[log q]=-1.58090393e+02 at epoch 430
# 08/01/2018 10:45:08 Variational SMC H_p[log q]=-2.07762772e+02 at epoch 431
# 08/01/2018 10:45:10 Variational SMC H_p[log q]=-1.79049362e+02 at epoch 432
# 08/01/2018 10:45:12 Variational SMC H_p[log q]=-1.90253403e+02 at epoch 433
# 08/01/2018 10:45:14 Variational SMC H_p[log q]=-1.96733734e+02 at epoch 434
# 08/01/2018 10:45:16 Variational SMC H_p[log q]=-2.18982681e+02 at epoch 435
# 08/01/2018 10:45:18 Variational SMC H_p[log q]=-1.59267685e+02 at epoch 436
# 08/01/2018 10:45:19 Variational SMC H_p[log q]=-2.08440384e+02 at epoch 437
# 08/01/2018 10:45:21 Variational SMC H_p[log q]=-2.42315903e+02 at epoch 438
# 08/01/2018 10:45:23 Variational SMC H_p[log q]=-2.36978394e+02 at epoch 439
# 08/01/2018 10:45:25 Variational SMC H_p[log q]=-1.80527206e+02 at epoch 440
# 08/01/2018 10:45:27 Variational SMC H_p[log q]=-1.62214691e+02 at epoch 441
# 08/01/2018 10:45:29 Variational SMC H_p[log q]=-1.57522156e+02 at epoch 442
# 08/01/2018 10:45:31 Variational SMC H_p[log q]=-1.73792175e+02 at epoch 443
# 08/01/2018 10:45:32 Variational SMC H_p[log q]=-2.08258652e+02 at epoch 444
# 08/01/2018 10:45:34 Variational SMC H_p[log q]=-1.70910370e+02 at epoch 445
# 08/01/2018 10:45:36 Variational SMC H_p[log q]=-1.56203979e+02 at epoch 446
# 08/01/2018 10:45:38 Variational SMC H_p[log q]=-2.26699722e+02 at epoch 447
# 08/01/2018 10:45:40 Variational SMC H_p[log q]=-1.98914139e+02 at epoch 448
# 08/01/2018 10:45:42 Variational SMC H_p[log q]=-1.78140060e+02 at epoch 449
# 08/01/2018 10:45:44 Variational SMC H_p[log q]=-2.08380661e+02 at epoch 450
# 08/01/2018 10:45:45 Variational SMC H_p[log q]=-2.27879944e+02 at epoch 451
# 08/01/2018 10:45:47 Variational SMC H_p[log q]=-2.39168518e+02 at epoch 452
# 08/01/2018 10:45:49 Variational SMC H_p[log q]=-2.10032425e+02 at epoch 453
# 08/01/2018 10:45:51 Variational SMC H_p[log q]=-1.50445251e+02 at epoch 454
# 08/01/2018 10:45:53 Variational SMC H_p[log q]=-2.02765991e+02 at epoch 455
# 08/01/2018 10:45:55 Variational SMC H_p[log q]=-2.06215668e+02 at epoch 456
# 08/01/2018 10:45:57 Variational SMC H_p[log q]=-1.92528931e+02 at epoch 457
# 08/01/2018 10:45:59 Variational SMC H_p[log q]=-2.10210754e+02 at epoch 458
# 08/01/2018 10:46:00 Variational SMC H_p[log q]=-2.14848083e+02 at epoch 459
# 08/01/2018 10:46:02 Variational SMC H_p[log q]=-2.00019974e+02 at epoch 460
# 08/01/2018 10:46:04 Variational SMC H_p[log q]=-1.98796188e+02 at epoch 461
# 08/01/2018 10:46:06 Variational SMC H_p[log q]=-2.45719116e+02 at epoch 462
# 08/01/2018 10:46:08 Variational SMC H_p[log q]=-2.48207504e+02 at epoch 463
# 08/01/2018 10:46:10 Variational SMC H_p[log q]=-2.02028320e+02 at epoch 464
# 08/01/2018 10:46:12 Variational SMC H_p[log q]=-1.91872696e+02 at epoch 465
# 08/01/2018 10:46:14 Variational SMC H_p[log q]=-2.03706116e+02 at epoch 466
# 08/01/2018 10:46:16 Variational SMC H_p[log q]=-2.13631424e+02 at epoch 467
# 08/01/2018 10:46:17 Variational SMC H_p[log q]=-1.84738953e+02 at epoch 468
# 08/01/2018 10:46:19 Variational SMC H_p[log q]=-1.75576523e+02 at epoch 469
# 08/01/2018 10:46:21 Variational SMC H_p[log q]=-1.95195374e+02 at epoch 470
# 08/01/2018 10:46:23 Variational SMC H_p[log q]=-2.43482468e+02 at epoch 471
# 08/01/2018 10:46:25 Variational SMC H_p[log q]=-2.28627670e+02 at epoch 472
# 08/01/2018 10:46:27 Variational SMC H_p[log q]=-2.28116470e+02 at epoch 473
# 08/01/2018 10:46:29 Variational SMC H_p[log q]=-2.35381577e+02 at epoch 474
# 08/01/2018 10:46:30 Variational SMC H_p[log q]=-1.92160629e+02 at epoch 475
# 08/01/2018 10:46:32 Variational SMC H_p[log q]=-2.30583984e+02 at epoch 476
# 08/01/2018 10:46:34 Variational SMC H_p[log q]=-2.16711426e+02 at epoch 477
# 08/01/2018 10:46:36 Variational SMC H_p[log q]=-2.09857147e+02 at epoch 478
# 08/01/2018 10:46:38 Variational SMC H_p[log q]=-2.31699890e+02 at epoch 479
# 08/01/2018 10:46:40 Variational SMC H_p[log q]=-2.22937195e+02 at epoch 480
# 08/01/2018 10:46:42 Variational SMC H_p[log q]=-2.13372421e+02 at epoch 481
# 08/01/2018 10:46:44 Variational SMC H_p[log q]=-2.12777634e+02 at epoch 482
# 08/01/2018 10:46:46 Variational SMC H_p[log q]=-2.36066345e+02 at epoch 483
# 08/01/2018 10:46:48 Variational SMC H_p[log q]=-2.03102112e+02 at epoch 484
# 08/01/2018 10:46:49 Variational SMC H_p[log q]=-2.32899338e+02 at epoch 485
# 08/01/2018 10:46:51 Variational SMC H_p[log q]=-1.62412781e+02 at epoch 486
# 08/01/2018 10:46:53 Variational SMC H_p[log q]=-2.28689804e+02 at epoch 487
# 08/01/2018 10:46:55 Variational SMC H_p[log q]=-2.11950699e+02 at epoch 488
# 08/01/2018 10:46:57 Variational SMC H_p[log q]=-2.13128052e+02 at epoch 489
# 08/01/2018 10:46:59 Variational SMC H_p[log q]=-2.20918259e+02 at epoch 490
# 08/01/2018 10:47:01 Variational SMC H_p[log q]=-2.31355972e+02 at epoch 491
# 08/01/2018 10:47:03 Variational SMC H_p[log q]=-2.03844360e+02 at epoch 492
# 08/01/2018 10:47:05 Variational SMC H_p[log q]=-2.35780502e+02 at epoch 493
# 08/01/2018 10:47:07 Variational SMC H_p[log q]=-2.02762131e+02 at epoch 494
# 08/01/2018 10:47:09 Variational SMC H_p[log q]=-2.06870392e+02 at epoch 495
# 08/01/2018 10:47:10 Variational SMC H_p[log q]=-2.00697083e+02 at epoch 496
# 08/01/2018 10:47:12 Variational SMC H_p[log q]=-1.94826218e+02 at epoch 497
# 08/01/2018 10:47:14 Variational SMC H_p[log q]=-2.24081680e+02 at epoch 498
# 08/01/2018 10:47:16 Variational SMC H_p[log q]=-2.12854904e+02 at epoch 499
# 08/01/2018 10:47:18 Variational SMC H_p[log q]=-2.37854477e+02 at epoch 500
# 08/01/2018 10:47:20 Variational SMC H_p[log q]=-2.85840435e+01 at epoch 1
# 08/01/2018 10:47:22 Variational SMC H_p[log q]=-3.13765373e+01 at epoch 2
# 08/01/2018 10:47:24 Variational SMC H_p[log q]=-2.01503849e+01 at epoch 3
# 08/01/2018 10:47:26 Variational SMC H_p[log q]=7.30654621e+00 at epoch 4
# 08/01/2018 10:47:27 Variational SMC H_p[log q]=-2.27701035e+01 at epoch 5
# 08/01/2018 10:47:29 Variational SMC H_p[log q]=-2.05494576e+01 at epoch 6
# 08/01/2018 10:47:31 Variational SMC H_p[log q]=-3.90522614e+01 at epoch 7
# 08/01/2018 10:47:32 Variational SMC H_p[log q]=-2.47316036e+01 at epoch 8
# 08/01/2018 10:47:34 Variational SMC H_p[log q]=-2.84125175e+01 at epoch 9
# 08/01/2018 10:47:36 Variational SMC H_p[log q]=-1.09644737e+01 at epoch 10
# 08/01/2018 10:47:37 Variational SMC H_p[log q]=-1.01236534e+01 at epoch 11
# 08/01/2018 10:47:39 Variational SMC H_p[log q]=4.62133980e+00 at epoch 12
# 08/01/2018 10:47:41 Variational SMC H_p[log q]=-1.72128544e+01 at epoch 13
# 08/01/2018 10:47:43 Variational SMC H_p[log q]=-6.11569405e+00 at epoch 14
# 08/01/2018 10:47:44 Variational SMC H_p[log q]=-2.85955982e+01 at epoch 15
# 08/01/2018 10:47:46 Variational SMC H_p[log q]=-2.05065937e+01 at epoch 16
# 08/01/2018 10:47:48 Variational SMC H_p[log q]=-2.39474564e+01 at epoch 17
# 08/01/2018 10:47:50 Variational SMC H_p[log q]=-1.04161196e+01 at epoch 18
# 08/01/2018 10:47:52 Variational SMC H_p[log q]=-1.36186190e+01 at epoch 19
# 08/01/2018 10:47:53 Variational SMC H_p[log q]=-2.54526787e+01 at epoch 20
# 08/01/2018 10:47:55 Variational SMC H_p[log q]=-1.46524801e+01 at epoch 21
# 08/01/2018 10:47:57 Variational SMC H_p[log q]=-1.44605455e+01 at epoch 22
# 08/01/2018 10:47:59 Variational SMC H_p[log q]=-1.15858727e+01 at epoch 23
# 08/01/2018 10:48:01 Variational SMC H_p[log q]=-2.40514889e+01 at epoch 24
# 08/01/2018 10:48:03 Variational SMC H_p[log q]=-1.70650558e+01 at epoch 25
# 08/01/2018 10:48:04 Variational SMC H_p[log q]=-1.21622648e+01 at epoch 26
# 08/01/2018 10:48:06 Variational SMC H_p[log q]=-3.46915131e+01 at epoch 27
# 08/01/2018 10:48:08 Variational SMC H_p[log q]=-4.28127670e+01 at epoch 28
# 08/01/2018 10:48:10 Variational SMC H_p[log q]=-1.63520184e+01 at epoch 29
# 08/01/2018 10:48:12 Variational SMC H_p[log q]=-4.29179230e+01 at epoch 30
# 08/01/2018 10:48:14 Variational SMC H_p[log q]=-2.47346821e+01 at epoch 31
# 08/01/2018 10:48:15 Variational SMC H_p[log q]=-4.45031967e+01 at epoch 32
# 08/01/2018 10:48:17 Variational SMC H_p[log q]=-3.47532501e+01 at epoch 33
# 08/01/2018 10:48:19 Variational SMC H_p[log q]=-1.70220127e+01 at epoch 34
# 08/01/2018 10:48:21 Variational SMC H_p[log q]=-3.93884850e+01 at epoch 35
# 08/01/2018 10:48:23 Variational SMC H_p[log q]=-3.96571388e+01 at epoch 36
# 08/01/2018 10:48:25 Variational SMC H_p[log q]=-3.09269791e+01 at epoch 37
# 08/01/2018 10:48:26 Variational SMC H_p[log q]=-2.18899975e+01 at epoch 38
# 08/01/2018 10:48:28 Variational SMC H_p[log q]=-4.22791367e+01 at epoch 39
# 08/01/2018 10:48:30 Variational SMC H_p[log q]=-5.94278412e+01 at epoch 40
# 08/01/2018 10:48:32 Variational SMC H_p[log q]=-1.99749126e+01 at epoch 41
# 08/01/2018 10:48:34 Variational SMC H_p[log q]=-2.62517147e+01 at epoch 42
# 08/01/2018 10:48:36 Variational SMC H_p[log q]=-2.20291634e+01 at epoch 43
# 08/01/2018 10:48:38 Variational SMC H_p[log q]=-2.05921898e+01 at epoch 44
# 08/01/2018 10:48:39 Variational SMC H_p[log q]=-3.01692772e+00 at epoch 45
# 08/01/2018 10:48:41 Variational SMC H_p[log q]=-4.34183578e+01 at epoch 46
# 08/01/2018 10:48:43 Variational SMC H_p[log q]=-3.54744835e+01 at epoch 47
# 08/01/2018 10:48:45 Variational SMC H_p[log q]=-2.91629009e+01 at epoch 48
# 08/01/2018 10:48:47 Variational SMC H_p[log q]=-4.36737556e+01 at epoch 49
# 08/01/2018 10:48:48 Variational SMC H_p[log q]=-1.21419201e+01 at epoch 50
# 08/01/2018 10:48:50 Variational SMC H_p[log q]=-5.53579140e+00 at epoch 51
# 08/01/2018 10:48:52 Variational SMC H_p[log q]=-2.59793282e+01 at epoch 52
# 08/01/2018 10:48:54 Variational SMC H_p[log q]=-2.26137753e+01 at epoch 53
# 08/01/2018 10:48:56 Variational SMC H_p[log q]=-2.39122639e+01 at epoch 54
# 08/01/2018 10:48:58 Variational SMC H_p[log q]=-1.68887100e+01 at epoch 55
# 08/01/2018 10:48:59 Variational SMC H_p[log q]=-1.40896358e+01 at epoch 56
# 08/01/2018 10:49:01 Variational SMC H_p[log q]=-4.32468452e+01 at epoch 57
# 08/01/2018 10:49:03 Variational SMC H_p[log q]=-3.77507782e+01 at epoch 58
# 08/01/2018 10:49:05 Variational SMC H_p[log q]=-4.88486099e+01 at epoch 59
# 08/01/2018 10:49:07 Variational SMC H_p[log q]=-3.66368256e+01 at epoch 60
# 08/01/2018 10:49:09 Variational SMC H_p[log q]=-2.85275154e+01 at epoch 61
# 08/01/2018 10:49:11 Variational SMC H_p[log q]=-4.82104950e+01 at epoch 62
# 08/01/2018 10:49:13 Variational SMC H_p[log q]=-3.50047340e+01 at epoch 63
# 08/01/2018 10:49:14 Variational SMC H_p[log q]=-3.08671818e+01 at epoch 64
# 08/01/2018 10:49:16 Variational SMC H_p[log q]=-1.62662125e+01 at epoch 65
# 08/01/2018 10:49:18 Variational SMC H_p[log q]=-5.20917969e+01 at epoch 66
# 08/01/2018 10:49:20 Variational SMC H_p[log q]=-1.46127090e+01 at epoch 67
# 08/01/2018 10:49:22 Variational SMC H_p[log q]=-3.34650230e+01 at epoch 68
# 08/01/2018 10:49:24 Variational SMC H_p[log q]=-2.26333427e+01 at epoch 69
# 08/01/2018 10:49:26 Variational SMC H_p[log q]=-3.52566681e+01 at epoch 70
# 08/01/2018 10:49:28 Variational SMC H_p[log q]=-4.61769791e+01 at epoch 71
# 08/01/2018 10:49:29 Variational SMC H_p[log q]=-2.73342381e+01 at epoch 72
# 08/01/2018 10:49:31 Variational SMC H_p[log q]=-3.11989021e+01 at epoch 73
# 08/01/2018 10:49:33 Variational SMC H_p[log q]=-5.36394768e+01 at epoch 74
# 08/01/2018 10:49:35 Variational SMC H_p[log q]=-5.38879051e+01 at epoch 75
# 08/01/2018 10:49:37 Variational SMC H_p[log q]=-3.10463581e+01 at epoch 76
# 08/01/2018 10:49:39 Variational SMC H_p[log q]=-7.59082413e+01 at epoch 77
# 08/01/2018 10:49:41 Variational SMC H_p[log q]=-6.25415897e+00 at epoch 78
# 08/01/2018 10:49:43 Variational SMC H_p[log q]=-1.78939209e+01 at epoch 79
# 08/01/2018 10:49:45 Variational SMC H_p[log q]=-3.18773479e+01 at epoch 80
# 08/01/2018 10:49:46 Variational SMC H_p[log q]=-2.60123100e+01 at epoch 81
# 08/01/2018 10:49:48 Variational SMC H_p[log q]=-4.01795082e+01 at epoch 82
# 08/01/2018 10:49:50 Variational SMC H_p[log q]=-4.33460503e+01 at epoch 83
# 08/01/2018 10:49:52 Variational SMC H_p[log q]=-2.19645710e+01 at epoch 84
# 08/01/2018 10:49:54 Variational SMC H_p[log q]=-1.82425461e+01 at epoch 85
# 08/01/2018 10:49:56 Variational SMC H_p[log q]=-4.40857315e+01 at epoch 86
# 08/01/2018 10:49:58 Variational SMC H_p[log q]=-2.95811272e+01 at epoch 87
# 08/01/2018 10:49:59 Variational SMC H_p[log q]=-3.16745510e+01 at epoch 88
# 08/01/2018 10:50:01 Variational SMC H_p[log q]=-4.13045502e+01 at epoch 89
# 08/01/2018 10:50:03 Variational SMC H_p[log q]=-4.59493446e+01 at epoch 90
# 08/01/2018 10:50:05 Variational SMC H_p[log q]=-5.11655998e+01 at epoch 91
# 08/01/2018 10:50:07 Variational SMC H_p[log q]=-1.67461205e+01 at epoch 92
# 08/01/2018 10:50:09 Variational SMC H_p[log q]=-4.03049011e+01 at epoch 93
# 08/01/2018 10:50:11 Variational SMC H_p[log q]=-6.16093941e+01 at epoch 94
# 08/01/2018 10:50:13 Variational SMC H_p[log q]=-3.45659409e+01 at epoch 95
# 08/01/2018 10:50:15 Variational SMC H_p[log q]=-3.37188072e+01 at epoch 96
# 08/01/2018 10:50:16 Variational SMC H_p[log q]=-2.85012646e+01 at epoch 97
# 08/01/2018 10:50:18 Variational SMC H_p[log q]=-4.03129387e+01 at epoch 98
# 08/01/2018 10:50:20 Variational SMC H_p[log q]=-5.32395554e+01 at epoch 99
# 08/01/2018 10:50:22 Variational SMC H_p[log q]=-2.91967754e+01 at epoch 100
# 08/01/2018 10:50:24 Variational SMC H_p[log q]=-4.91420326e+01 at epoch 101
# 08/01/2018 10:50:26 Variational SMC H_p[log q]=-5.39145699e+01 at epoch 102
# 08/01/2018 10:50:28 Variational SMC H_p[log q]=-4.88454094e+01 at epoch 103
# 08/01/2018 10:50:30 Variational SMC H_p[log q]=-4.63316765e+01 at epoch 104
# 08/01/2018 10:50:32 Variational SMC H_p[log q]=-2.37809944e+01 at epoch 105
# 08/01/2018 10:50:34 Variational SMC H_p[log q]=-2.68445072e+01 at epoch 106
# 08/01/2018 10:50:35 Variational SMC H_p[log q]=-1.72570896e+01 at epoch 107
# 08/01/2018 10:50:37 Variational SMC H_p[log q]=-4.09771194e+01 at epoch 108
# 08/01/2018 10:50:39 Variational SMC H_p[log q]=-3.24119377e+01 at epoch 109
# 08/01/2018 10:50:41 Variational SMC H_p[log q]=-5.57672157e+01 at epoch 110
# 08/01/2018 10:50:43 Variational SMC H_p[log q]=-5.11085739e+01 at epoch 111
# 08/01/2018 10:50:45 Variational SMC H_p[log q]=-3.31072464e+01 at epoch 112
# 08/01/2018 10:50:47 Variational SMC H_p[log q]=-4.52915535e+01 at epoch 113
# 08/01/2018 10:50:49 Variational SMC H_p[log q]=-1.85928040e+01 at epoch 114
# 08/01/2018 10:50:51 Variational SMC H_p[log q]=-4.08450470e+01 at epoch 115
# 08/01/2018 10:50:53 Variational SMC H_p[log q]=-6.41450500e+01 at epoch 116
# 08/01/2018 10:50:55 Variational SMC H_p[log q]=-3.72714767e+01 at epoch 117
# 08/01/2018 10:50:56 Variational SMC H_p[log q]=-4.62089691e+01 at epoch 118
# 08/01/2018 10:50:58 Variational SMC H_p[log q]=-3.51127014e+01 at epoch 119
# 08/01/2018 10:51:00 Variational SMC H_p[log q]=-5.44290085e+01 at epoch 120
# 08/01/2018 10:51:02 Variational SMC H_p[log q]=-7.26293869e+01 at epoch 121
# 08/01/2018 10:51:04 Variational SMC H_p[log q]=-3.90005989e+01 at epoch 122
# 08/01/2018 10:51:06 Variational SMC H_p[log q]=-4.86398277e+01 at epoch 123
# 08/01/2018 10:51:08 Variational SMC H_p[log q]=-7.31036987e+01 at epoch 124
# 08/01/2018 10:51:10 Variational SMC H_p[log q]=-4.49460449e+01 at epoch 125
# 08/01/2018 10:51:11 Variational SMC H_p[log q]=-7.25406418e+01 at epoch 126
# 08/01/2018 10:51:13 Variational SMC H_p[log q]=-4.69116058e+01 at epoch 127
# 08/01/2018 10:51:15 Variational SMC H_p[log q]=-4.35387115e+01 at epoch 128
# 08/01/2018 10:51:17 Variational SMC H_p[log q]=-2.65928078e+01 at epoch 129
# 08/01/2018 10:51:19 Variational SMC H_p[log q]=-4.80314560e+01 at epoch 130
# 08/01/2018 10:51:21 Variational SMC H_p[log q]=-6.23774643e+01 at epoch 131
# 08/01/2018 10:51:23 Variational SMC H_p[log q]=-1.94233818e+01 at epoch 132
# 08/01/2018 10:51:25 Variational SMC H_p[log q]=-3.43385048e+01 at epoch 133
# 08/01/2018 10:51:26 Variational SMC H_p[log q]=-2.54815140e+01 at epoch 134
# ...
# 08/01/2018 18:31:57 Variational SMC H_p[log q]=-7.05545959e+01 at epoch 291
# 08/01/2018 18:31:59 Variational SMC H_p[log q]=-1.34661118e+02 at epoch 292
# 08/01/2018 18:32:01 Variational SMC H_p[log q]=-8.76108627e+01 at epoch 293
# 08/01/2018 18:32:03 Variational SMC H_p[log q]=-1.12418503e+02 at epoch 294
# 08/01/2018 18:32:05 Variational SMC H_p[log q]=-1.31904327e+02 at epoch 295
# 08/01/2018 18:32:07 Variational SMC H_p[log q]=-1.15192978e+02 at epoch 296
# 08/01/2018 18:32:09 Variational SMC H_p[log q]=-8.02178116e+01 at epoch 297
# 08/01/2018 18:32:11 Variational SMC H_p[log q]=-1.49863724e+02 at epoch 298
# 08/01/2018 18:32:13 Variational SMC H_p[log q]=-1.12868401e+02 at epoch 299
# 08/01/2018 18:32:15 Variational SMC H_p[log q]=-1.45851120e+02 at epoch 300
# 08/01/2018 18:32:17 Variational SMC H_p[log q]=-1.33014053e+02 at epoch 301
# 08/01/2018 18:32:19 Variational SMC H_p[log q]=-1.25607712e+02 at epoch 302
# 08/01/2018 18:32:21 Variational SMC H_p[log q]=-1.45106674e+02 at epoch 303
# 08/01/2018 18:32:23 Variational SMC H_p[log q]=-1.33115906e+02 at epoch 304
# 08/01/2018 18:32:25 Variational SMC H_p[log q]=-1.38173279e+02 at epoch 305
# 08/01/2018 18:32:27 Variational SMC H_p[log q]=-1.07195412e+02 at epoch 306
# 08/01/2018 18:32:29 Variational SMC H_p[log q]=-1.00806740e+02 at epoch 307
# 08/01/2018 18:32:31 Variational SMC H_p[log q]=-1.65843948e+02 at epoch 308
# 08/01/2018 18:32:33 Variational SMC H_p[log q]=-1.48779587e+02 at epoch 309
# 08/01/2018 18:32:35 Variational SMC H_p[log q]=-1.51818695e+02 at epoch 310
# 08/01/2018 18:32:37 Variational SMC H_p[log q]=-7.91729660e+01 at epoch 311
# 08/01/2018 18:32:39 Variational SMC H_p[log q]=-1.28719925e+02 at epoch 312
# 08/01/2018 18:32:41 Variational SMC H_p[log q]=-1.59743713e+02 at epoch 313
# 08/01/2018 18:32:43 Variational SMC H_p[log q]=-1.08419701e+02 at epoch 314
# 08/01/2018 18:32:45 Variational SMC H_p[log q]=-1.27995369e+02 at epoch 315
# 08/01/2018 18:32:47 Variational SMC H_p[log q]=-1.18575348e+02 at epoch 316
# 08/01/2018 18:32:49 Variational SMC H_p[log q]=-8.20383682e+01 at epoch 317
# 08/01/2018 18:32:51 Variational SMC H_p[log q]=-1.21702141e+02 at epoch 318
# 08/01/2018 18:32:53 Variational SMC H_p[log q]=-1.36556152e+02 at epoch 319
# 08/01/2018 18:32:55 Variational SMC H_p[log q]=-1.09827126e+02 at epoch 320
# 08/01/2018 18:32:57 Variational SMC H_p[log q]=-1.69725586e+02 at epoch 321
# 08/01/2018 18:32:59 Variational SMC H_p[log q]=-8.98943100e+01 at epoch 322
# 08/01/2018 18:33:01 Variational SMC H_p[log q]=-1.35005173e+02 at epoch 323
# 08/01/2018 18:33:03 Variational SMC H_p[log q]=-1.84425430e+02 at epoch 324
# 08/01/2018 18:33:05 Variational SMC H_p[log q]=-1.60722290e+02 at epoch 325
# 08/01/2018 18:33:07 Variational SMC H_p[log q]=-1.13414406e+02 at epoch 326
# 08/01/2018 18:33:09 Variational SMC H_p[log q]=-1.60053833e+02 at epoch 327
# 08/01/2018 18:33:11 Variational SMC H_p[log q]=-8.29134216e+01 at epoch 328
# 08/01/2018 18:33:13 Variational SMC H_p[log q]=-1.50456375e+02 at epoch 329
# 08/01/2018 18:33:15 Variational SMC H_p[log q]=-1.16904999e+02 at epoch 330
# 08/01/2018 18:33:17 Variational SMC H_p[log q]=-1.57732056e+02 at epoch 331
# 08/01/2018 18:33:19 Variational SMC H_p[log q]=-7.73891525e+01 at epoch 332
# 08/01/2018 18:33:21 Variational SMC H_p[log q]=-1.30452606e+02 at epoch 333
# 08/01/2018 18:33:23 Variational SMC H_p[log q]=-1.23182648e+02 at epoch 334
# 08/01/2018 18:33:25 Variational SMC H_p[log q]=-1.17388939e+02 at epoch 335
# 08/01/2018 18:33:27 Variational SMC H_p[log q]=-1.80830093e+02 at epoch 336
# 08/01/2018 18:33:30 Variational SMC H_p[log q]=-1.58029663e+02 at epoch 337
# 08/01/2018 18:33:32 Variational SMC H_p[log q]=-1.51971527e+02 at epoch 338
# 08/01/2018 18:33:34 Variational SMC H_p[log q]=-1.79282715e+02 at epoch 339
# 08/01/2018 18:33:36 Variational SMC H_p[log q]=-1.15494743e+02 at epoch 340
# 08/01/2018 18:33:37 Variational SMC H_p[log q]=-1.45502838e+02 at epoch 341
# 08/01/2018 18:33:39 Variational SMC H_p[log q]=-1.85715546e+02 at epoch 342
# 08/01/2018 18:33:41 Variational SMC H_p[log q]=-1.76018997e+02 at epoch 343
# 08/01/2018 18:33:43 Variational SMC H_p[log q]=-1.34134964e+02 at epoch 344
# 08/01/2018 18:33:45 Variational SMC H_p[log q]=-1.99207443e+02 at epoch 345
# 08/01/2018 18:33:47 Variational SMC H_p[log q]=-1.68473358e+02 at epoch 346
# 08/01/2018 18:33:49 Variational SMC H_p[log q]=-1.59543152e+02 at epoch 347
# 08/01/2018 18:33:51 Variational SMC H_p[log q]=-1.27333923e+02 at epoch 348
# 08/01/2018 18:33:53 Variational SMC H_p[log q]=-1.40420975e+02 at epoch 349
# 08/01/2018 18:33:55 Variational SMC H_p[log q]=-9.17862015e+01 at epoch 350
# 08/01/2018 18:33:57 Variational SMC H_p[log q]=-1.41092804e+02 at epoch 351
# 08/01/2018 18:33:59 Variational SMC H_p[log q]=-1.76883240e+02 at epoch 352
# 08/01/2018 18:34:01 Variational SMC H_p[log q]=-1.78753113e+02 at epoch 353
# 08/01/2018 18:34:03 Variational SMC H_p[log q]=-1.99097839e+02 at epoch 354
# 08/01/2018 18:34:05 Variational SMC H_p[log q]=-1.36382904e+02 at epoch 355
# 08/01/2018 18:34:07 Variational SMC H_p[log q]=-1.56385315e+02 at epoch 356
# 08/01/2018 18:34:09 Variational SMC H_p[log q]=-1.24251366e+02 at epoch 357
# 08/01/2018 18:34:11 Variational SMC H_p[log q]=-1.92650269e+02 at epoch 358
# 08/01/2018 18:34:14 Variational SMC H_p[log q]=-1.46982666e+02 at epoch 359
# 08/01/2018 18:34:16 Variational SMC H_p[log q]=-1.21548347e+02 at epoch 360
# 08/01/2018 18:34:18 Variational SMC H_p[log q]=-1.22438118e+02 at epoch 361
# 08/01/2018 18:34:20 Variational SMC H_p[log q]=-1.81810959e+02 at epoch 362
# 08/01/2018 18:34:22 Variational SMC H_p[log q]=-1.38917038e+02 at epoch 363
# 08/01/2018 18:34:24 Variational SMC H_p[log q]=-1.44330460e+02 at epoch 364
# 08/01/2018 18:34:26 Variational SMC H_p[log q]=-1.90898376e+02 at epoch 365
# 08/01/2018 18:34:27 Variational SMC H_p[log q]=-1.86167465e+02 at epoch 366
# 08/01/2018 18:34:30 Variational SMC H_p[log q]=-1.69310913e+02 at epoch 367
# 08/01/2018 18:34:32 Variational SMC H_p[log q]=-8.44419556e+01 at epoch 368
# 08/01/2018 18:34:34 Variational SMC H_p[log q]=-1.48830933e+02 at epoch 369
# 08/01/2018 18:34:36 Variational SMC H_p[log q]=-1.49792496e+02 at epoch 370
# 08/01/2018 18:34:38 Variational SMC H_p[log q]=-1.33445663e+02 at epoch 371
# 08/01/2018 18:34:40 Variational SMC H_p[log q]=-2.26224686e+02 at epoch 372
# 08/01/2018 18:34:42 Variational SMC H_p[log q]=-1.52653839e+02 at epoch 373
# 08/01/2018 18:34:44 Variational SMC H_p[log q]=-1.54527054e+02 at epoch 374
# 08/01/2018 18:34:46 Variational SMC H_p[log q]=-1.46614639e+02 at epoch 375
# 08/01/2018 18:34:48 Variational SMC H_p[log q]=-1.85489166e+02 at epoch 376
# 08/01/2018 18:34:50 Variational SMC H_p[log q]=-1.84692078e+02 at epoch 377
# 08/01/2018 18:34:52 Variational SMC H_p[log q]=-1.88318237e+02 at epoch 378
# 08/01/2018 18:34:54 Variational SMC H_p[log q]=-1.87056091e+02 at epoch 379
# 08/01/2018 18:34:56 Variational SMC H_p[log q]=-1.06414413e+02 at epoch 380
# 08/01/2018 18:34:58 Variational SMC H_p[log q]=-1.15381073e+02 at epoch 381
# 08/01/2018 18:35:00 Variational SMC H_p[log q]=-1.63531250e+02 at epoch 382
# 08/01/2018 18:35:02 Variational SMC H_p[log q]=-1.98751617e+02 at epoch 383
# 08/01/2018 18:35:04 Variational SMC H_p[log q]=-1.80827271e+02 at epoch 384
# 08/01/2018 18:35:06 Variational SMC H_p[log q]=-1.59302582e+02 at epoch 385
# 08/01/2018 18:35:08 Variational SMC H_p[log q]=-2.20764252e+02 at epoch 386
# 08/01/2018 18:35:10 Variational SMC H_p[log q]=-1.66118866e+02 at epoch 387
# 08/01/2018 18:35:12 Variational SMC H_p[log q]=-2.05614944e+02 at epoch 388
# 08/01/2018 18:35:14 Variational SMC H_p[log q]=-1.98975037e+02 at epoch 389
# 08/01/2018 18:35:16 Variational SMC H_p[log q]=-1.74969788e+02 at epoch 390
# 08/01/2018 18:35:18 Variational SMC H_p[log q]=-1.36576752e+02 at epoch 391
# 08/01/2018 18:35:20 Variational SMC H_p[log q]=-2.31634262e+02 at epoch 392
# 08/01/2018 18:35:22 Variational SMC H_p[log q]=-1.74320038e+02 at epoch 393
# 08/01/2018 18:35:24 Variational SMC H_p[log q]=-1.61460846e+02 at epoch 394
# 08/01/2018 18:35:26 Variational SMC H_p[log q]=-1.44439880e+02 at epoch 395
# 08/01/2018 18:35:28 Variational SMC H_p[log q]=-1.24685013e+02 at epoch 396
# 08/01/2018 18:35:30 Variational SMC H_p[log q]=-1.48969543e+02 at epoch 397
# 08/01/2018 18:35:32 Variational SMC H_p[log q]=-1.69401871e+02 at epoch 398
# 08/01/2018 18:35:34 Variational SMC H_p[log q]=-2.06849823e+02 at epoch 399
# 08/01/2018 18:35:36 Variational SMC H_p[log q]=-2.03408127e+02 at epoch 400
# 08/01/2018 18:35:38 Variational SMC H_p[log q]=-1.90371765e+02 at epoch 401
# 08/01/2018 18:35:40 Variational SMC H_p[log q]=-1.35187134e+02 at epoch 402
# 08/01/2018 18:35:42 Variational SMC H_p[log q]=-1.75352936e+02 at epoch 403
# 08/01/2018 18:35:44 Variational SMC H_p[log q]=-2.12575119e+02 at epoch 404
# 08/01/2018 18:35:46 Variational SMC H_p[log q]=-1.97885483e+02 at epoch 405
# 08/01/2018 18:35:48 Variational SMC H_p[log q]=-1.66080521e+02 at epoch 406
# 08/01/2018 18:35:50 Variational SMC H_p[log q]=-2.20044983e+02 at epoch 407
# 08/01/2018 18:35:52 Variational SMC H_p[log q]=-1.97723373e+02 at epoch 408
# 08/01/2018 18:35:54 Variational SMC H_p[log q]=-2.42596603e+02 at epoch 409
# 08/01/2018 18:35:56 Variational SMC H_p[log q]=-1.91581619e+02 at epoch 410
# 08/01/2018 18:35:58 Variational SMC H_p[log q]=-1.82589447e+02 at epoch 411
# 08/01/2018 18:36:00 Variational SMC H_p[log q]=-1.20730011e+02 at epoch 412
# 08/01/2018 18:36:02 Variational SMC H_p[log q]=-2.06372208e+02 at epoch 413
# 08/01/2018 18:36:04 Variational SMC H_p[log q]=-2.04929550e+02 at epoch 414
# 08/01/2018 18:36:06 Variational SMC H_p[log q]=-1.99046661e+02 at epoch 415
# 08/01/2018 18:36:08 Variational SMC H_p[log q]=-2.10968597e+02 at epoch 416
# 08/01/2018 18:36:10 Variational SMC H_p[log q]=-1.99059006e+02 at epoch 417
# 08/01/2018 18:36:12 Variational SMC H_p[log q]=-1.80210663e+02 at epoch 418
# 08/01/2018 18:36:14 Variational SMC H_p[log q]=-2.18863358e+02 at epoch 419
# 08/01/2018 18:36:16 Variational SMC H_p[log q]=-1.72519684e+02 at epoch 420
# 08/01/2018 18:36:18 Variational SMC H_p[log q]=-1.85245697e+02 at epoch 421
# 08/01/2018 18:36:20 Variational SMC H_p[log q]=-2.15013260e+02 at epoch 422
# 08/01/2018 18:36:22 Variational SMC H_p[log q]=-1.70565857e+02 at epoch 423
# 08/01/2018 18:36:24 Variational SMC H_p[log q]=-1.97849274e+02 at epoch 424
# 08/01/2018 18:36:26 Variational SMC H_p[log q]=-2.48188171e+02 at epoch 425
# 08/01/2018 18:36:28 Variational SMC H_p[log q]=-1.98366440e+02 at epoch 426
# 08/01/2018 18:36:30 Variational SMC H_p[log q]=-2.37722931e+02 at epoch 427
# 08/01/2018 18:36:32 Variational SMC H_p[log q]=-2.00863434e+02 at epoch 428
# 08/01/2018 18:36:34 Variational SMC H_p[log q]=-2.07418549e+02 at epoch 429
# 08/01/2018 18:36:36 Variational SMC H_p[log q]=-1.84606186e+02 at epoch 430
# 08/01/2018 18:36:38 Variational SMC H_p[log q]=-2.05649811e+02 at epoch 431
# 08/01/2018 18:36:40 Variational SMC H_p[log q]=-2.09905182e+02 at epoch 432
# 08/01/2018 18:36:42 Variational SMC H_p[log q]=-1.90553635e+02 at epoch 433
# 08/01/2018 18:36:44 Variational SMC H_p[log q]=-1.47717880e+02 at epoch 434
# 08/01/2018 18:36:46 Variational SMC H_p[log q]=-1.22692703e+02 at epoch 435
# 08/01/2018 18:36:48 Variational SMC H_p[log q]=-1.75001190e+02 at epoch 436
# 08/01/2018 18:36:50 Variational SMC H_p[log q]=-2.31229782e+02 at epoch 437
# 08/01/2018 18:36:52 Variational SMC H_p[log q]=-1.87301819e+02 at epoch 438
# 08/01/2018 18:36:54 Variational SMC H_p[log q]=-1.97841049e+02 at epoch 439
# 08/01/2018 18:36:56 Variational SMC H_p[log q]=-2.13501877e+02 at epoch 440
# 08/01/2018 18:36:58 Variational SMC H_p[log q]=-2.41982605e+02 at epoch 441
# 08/01/2018 18:37:00 Variational SMC H_p[log q]=-1.94443588e+02 at epoch 442
# 08/01/2018 18:37:02 Variational SMC H_p[log q]=-1.76021637e+02 at epoch 443
# 08/01/2018 18:37:04 Variational SMC H_p[log q]=-2.43099457e+02 at epoch 444
# 08/01/2018 18:37:06 Variational SMC H_p[log q]=-1.88019455e+02 at epoch 445
# 08/01/2018 18:37:08 Variational SMC H_p[log q]=-2.34390152e+02 at epoch 446
# 08/01/2018 18:37:10 Variational SMC H_p[log q]=-1.97210114e+02 at epoch 447
# 08/01/2018 18:37:12 Variational SMC H_p[log q]=-2.21136292e+02 at epoch 448
# 08/01/2018 18:37:14 Variational SMC H_p[log q]=-2.01516449e+02 at epoch 449
# 08/01/2018 18:37:16 Variational SMC H_p[log q]=-2.02316055e+02 at epoch 450
# 08/01/2018 18:37:18 Variational SMC H_p[log q]=-1.88418381e+02 at epoch 451
# 08/01/2018 18:37:20 Variational SMC H_p[log q]=-2.00312225e+02 at epoch 452
# 08/01/2018 18:37:22 Variational SMC H_p[log q]=-1.67682907e+02 at epoch 453
# 08/01/2018 18:37:24 Variational SMC H_p[log q]=-2.02824158e+02 at epoch 454
# 08/01/2018 18:37:26 Variational SMC H_p[log q]=-1.79799545e+02 at epoch 455
# 08/01/2018 18:37:28 Variational SMC H_p[log q]=-1.70496216e+02 at epoch 456
# 08/01/2018 18:37:30 Variational SMC H_p[log q]=-1.87360748e+02 at epoch 457
# 08/01/2018 18:37:32 Variational SMC H_p[log q]=-1.97352615e+02 at epoch 458
# 08/01/2018 18:37:34 Variational SMC H_p[log q]=-2.39010315e+02 at epoch 459
# 08/01/2018 18:37:36 Variational SMC H_p[log q]=-2.20511078e+02 at epoch 460
# 08/01/2018 18:37:38 Variational SMC H_p[log q]=-1.65185013e+02 at epoch 461
# 08/01/2018 18:37:40 Variational SMC H_p[log q]=-2.29467438e+02 at epoch 462
# 08/01/2018 18:37:42 Variational SMC H_p[log q]=-2.10028580e+02 at epoch 463
# 08/01/2018 18:37:44 Variational SMC H_p[log q]=-2.36263031e+02 at epoch 464
# 08/01/2018 18:37:46 Variational SMC H_p[log q]=-2.25498535e+02 at epoch 465
# 08/01/2018 18:37:48 Variational SMC H_p[log q]=-2.04177063e+02 at epoch 466
# 08/01/2018 18:37:50 Variational SMC H_p[log q]=-2.11113724e+02 at epoch 467
# 08/01/2018 18:37:52 Variational SMC H_p[log q]=-2.17049576e+02 at epoch 468
# 08/01/2018 18:37:54 Variational SMC H_p[log q]=-1.97418121e+02 at epoch 469
# 08/01/2018 18:37:56 Variational SMC H_p[log q]=-2.05666321e+02 at epoch 470
# 08/01/2018 18:37:58 Variational SMC H_p[log q]=-2.03380768e+02 at epoch 471
# 08/01/2018 18:38:00 Variational SMC H_p[log q]=-1.93059265e+02 at epoch 472
# 08/01/2018 18:38:02 Variational SMC H_p[log q]=-2.14186600e+02 at epoch 473
# 08/01/2018 18:38:04 Variational SMC H_p[log q]=-2.29917191e+02 at epoch 474
# 08/01/2018 18:38:06 Variational SMC H_p[log q]=-1.99389297e+02 at epoch 475
# 08/01/2018 18:38:08 Variational SMC H_p[log q]=-2.22927383e+02 at epoch 476
# 08/01/2018 18:38:10 Variational SMC H_p[log q]=-2.37265686e+02 at epoch 477
# 08/01/2018 18:38:12 Variational SMC H_p[log q]=-2.37258728e+02 at epoch 478
# 08/01/2018 18:38:14 Variational SMC H_p[log q]=-2.40718597e+02 at epoch 479
# 08/01/2018 18:38:16 Variational SMC H_p[log q]=-2.43492188e+02 at epoch 480
# 08/01/2018 18:38:18 Variational SMC H_p[log q]=-2.44906662e+02 at epoch 481
# 08/01/2018 18:38:20 Variational SMC H_p[log q]=-2.34870941e+02 at epoch 482
# 08/01/2018 18:38:22 Variational SMC H_p[log q]=-1.93830170e+02 at epoch 483
# 08/01/2018 18:38:24 Variational SMC H_p[log q]=-2.21862167e+02 at epoch 484
# 08/01/2018 18:38:26 Variational SMC H_p[log q]=-2.40954941e+02 at epoch 485
# 08/01/2018 18:38:28 Variational SMC H_p[log q]=-2.51497025e+02 at epoch 486
# 08/01/2018 18:38:30 Variational SMC H_p[log q]=-2.33294800e+02 at epoch 487
# 08/01/2018 18:38:33 Variational SMC H_p[log q]=-2.16517303e+02 at epoch 488
# 08/01/2018 18:38:35 Variational SMC H_p[log q]=-2.09427063e+02 at epoch 489
# 08/01/2018 18:38:37 Variational SMC H_p[log q]=-1.98100281e+02 at epoch 490
# 08/01/2018 18:38:39 Variational SMC H_p[log q]=-2.18089935e+02 at epoch 491
# 08/01/2018 18:38:41 Variational SMC H_p[log q]=-2.10178009e+02 at epoch 492
# 08/01/2018 18:38:43 Variational SMC H_p[log q]=-2.07738480e+02 at epoch 493
# 08/01/2018 18:38:45 Variational SMC H_p[log q]=-2.36683380e+02 at epoch 494
# 08/01/2018 18:38:47 Variational SMC H_p[log q]=-2.62789795e+02 at epoch 495
# 08/01/2018 18:38:49 Variational SMC H_p[log q]=-1.81508163e+02 at epoch 496
# 08/01/2018 18:38:51 Variational SMC H_p[log q]=-2.27431442e+02 at epoch 497
# 08/01/2018 18:38:53 Variational SMC H_p[log q]=-2.42711975e+02 at epoch 498
# 08/01/2018 18:38:55 Variational SMC H_p[log q]=-2.12841858e+02 at epoch 499
# 08/01/2018 18:38:57 Variational SMC H_p[log q]=-1.78470016e+02 at epoch 500

# %%
import bouncing_ball_plots

# %%
fs = 3 ## figure size
vmax = 0.3 ## cmap maximum value, to make off-diagonal elements more visible
width_space = 0.05 # space between figures
height_space = 0.05 # space between figures
cov_flag = False # plot the covariances or not
legend_flag = False # plot the legend bar or not
save_flag = True ## save or not

# %%
## plot method 1
bouncing_ball_plots.plot_circle_transition(init_v, modal_directions.detach().numpy(), final_covs,
                                           As_pred, As_true, K, fs, vmax, width_space, height_space, cov_flag, legend_flag, save_flag)

# %%
## plot method 2
bouncing_ball_plots.plot_circle_transition_colorcode(init_v, modal_directions.detach().numpy(), final_covs, As_pred, As_true, K, fs, vmax, width_space, height_space, cov_flag, legend_flag, save_flag)

# %%
def plot_circle_transition_colorcode(init_v, final_mus, final_covs, As_pred, As_true, K, fs, vmax, width_space, height_space, cov_flag, legend_flag, save_flag):

    As_infer = As_pred / As_pred.sum(-1)[:, :, None]
    As_infer = As_infer.mean(0)
    As_true_ave = As_true.mean(0)

    fig = plt.figure(figsize=(fs*1.5 + width_space,fs + height_space))
    gs1 = gridspec.GridSpec(1, 1)
    # , width_ratios=[2,1], height_ratios=[1,1]
    gs1.update(left=0.0, bottom=0.0, right=(2/3), top=1.0, wspace=width_space, hspace=height_space)
    ax1 = fig.add_subplot(gs1[0])

    # ax3 = fig.add_subplot(gs[1, 1])
    ax1.set_xticks([])
    ax1.set_yticks([])

    gs2 = gridspec.GridSpec(4, 1)
    gs2.update(left=2/3 + (1/3)*width_space, bottom=0.5+(1/2)*width_space, right=1.0, top=1.0, wspace=0, hspace=0)
    ax2 = fig.add_subplot(gs2[0, 0])
    ax2.set_xticks([])
    ax2.set_yticks([])
    ax3 = fig.add_subplot(gs2[1, 0])
    ax3.set_xticks([])
    ax3.set_yticks([])
    ax4 = fig.add_subplot(gs2[2, 0])
    ax4.set_xticks([])
    ax4.set_yticks([])
    ax5 = fig.add_subplot(gs2[3, 0])
    ax5.set_xticks([])
    ax5.set_yticks([])

    gs3 = gridspec.GridSpec(4, 1)
    gs3.update(left=2/3 + (1/3)*width_space, bottom=0.0, right=1.0, top=0.5 - (1/2)*width_space, wspace=0, hspace=0)
    ax6 = fig.add_subplot(gs3[0, 0])
    ax6.set_xticks([])
    ax6.set_yticks([])
    ax7 = fig.add_subplot(gs3[1, 0])
    ax7.set_xticks([])
    ax7.set_yticks([])
    ax8 = fig.add_subplot(gs3[2, 0])
    ax8.set_xticks([])
    ax8.set_yticks([])
    ax9 = fig.add_subplot(gs3[3, 0])
    ax9.set_xticks([])
    ax9.set_yticks([])
    markersize = 10.0
    colors = ['b', 'Purple', 'g', 'r']
    ## plot left one
    ax1.scatter(init_v[:,0], init_v[:,1], s=markersize, color=colors[0], label='z=1')
    ax1.scatter(init_v[:,0], -init_v[:,1], s=markersize, color=colors[1], label='z=2')
    ax1.scatter(-init_v[:,0], -init_v[:,1], s=markersize, color=colors[2], label='z=3')
    ax1.scatter(-init_v[:,0], init_v[:,1], s=markersize, color=colors[3], label='z=4')

    for k in range(K):
        ax1.scatter(final_mus[:,k,0], final_mus[:,k,1], c=colors[k], marker='x')
    if cov_flag:
        for k in range(K):
            for s in range(num_series):
                plot_cov_ellipse(cov=final_covs[s, k, :, :], pos=final_mus[s, k, :], nstd=0.3, ax=ax1, alpha=0.3)
    #    ax1.set_xlabel('x velocity')
    #    ax1.set_ylabel('y velocity')
    if legend_flag:
        ax1.legend(loc='upper center', bbox_to_anchor=(0.75, 1.15), ncol=4)

    ax2.imshow(As_infer[None, 0,:], cmap='Blues', vmin=0, vmax=vmax)
    ax3.imshow(As_infer[None, 1,:], cmap='Purples', vmin=0, vmax=vmax)
    ax4.imshow(As_infer[None, 2,:], cmap='Greens', vmin=0, vmax=vmax)
    ax5.imshow(As_infer[None, 3,:], cmap='Reds', vmin=0, vmax=vmax)

    ax6.imshow(As_true_ave[None, 0,:], cmap='Blues', vmin=0, vmax=vmax)
    ax7.imshow(As_true_ave[None, 1,:], cmap='Purples', vmin=0, vmax=vmax)
    ax8.imshow(As_true_ave[None, 2,:], cmap='Greens', vmin=0, vmax=vmax)
    ax9.imshow(As_true_ave[None, 3,:], cmap='Reds', vmin=0, vmax=vmax)

    if save_flag:
        fig.savefig('combinator_results.pdf', dpi=600, bbox_inches='tight')
        fig.savefig('combinator_results.svg', dpi=600, bbox_inches='tight')
        fig.savefig('combinator_results.png', dpi=600, bbox_inches='tight')

# %%
## plot method 2
plot_circle_transition_colorcode(init_v, modal_directions.detach().numpy(), final_covs, As_pred, As_true, K, fs, vmax, width_space, height_space, cov_flag, legend_flag, save_flag)
