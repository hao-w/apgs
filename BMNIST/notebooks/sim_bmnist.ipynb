# %%
# %matplotlib inline
# %run ../../import_envs.py
from sim_bmnist import Sim_BMNIST
# Out:
# probtorch: 0.0+5a2c637 torch: 1.3.0

# %%
timesteps = 15
num_digits = 3
delta_t = 0.3
frame_size = 96
chunk_size = 1000
MNIST_DIR = '/data/hao/apg_data/mnist/'
simulator = Sim_BMNIST(timesteps=timesteps, num_digits=num_digits, frame_size=frame_size, delta_t=delta_t, chunk_size=chunk_size)
simulator.viz_data(MNIST_DIR=MNIST_DIR)
# Out:
# /home/hao/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2751: UserWarning: Default grid_sample and affine_grid behavior will be changed to align_corners=False from 1.4.0. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior will be changed "
# /home/hao/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2693: UserWarning: Default grid_sample and affine_grid behavior will be changed to align_corners=False from 1.4.0. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior will be changed "

# %%
PATH = '/data/hao/apg_data/bmnist/train/'
simulator.sim_save_data(num_seqs=60000, MNIST_DIR=MNIST_DIR, PATH=PATH)
# Out:
# ===(11s) Simulated 1000 sequences, 59000 sequences left.===
# ===(11s) Simulated 1000 sequences, 58000 sequences left.===
# ===(11s) Simulated 1000 sequences, 57000 sequences left.===
# ===(11s) Simulated 1000 sequences, 56000 sequences left.===
# ===(11s) Simulated 1000 sequences, 55000 sequences left.===
# ===(12s) Simulated 1000 sequences, 54000 sequences left.===
# ===(13s) Simulated 1000 sequences, 53000 sequences left.===
# ===(11s) Simulated 1000 sequences, 52000 sequences left.===
# ===(12s) Simulated 1000 sequences, 51000 sequences left.===
# ===(11s) Simulated 1000 sequences, 50000 sequences left.===
# ===(11s) Simulated 1000 sequences, 49000 sequences left.===
# ===(12s) Simulated 1000 sequences, 48000 sequences left.===
# ===(11s) Simulated 1000 sequences, 47000 sequences left.===
# ===(11s) Simulated 1000 sequences, 46000 sequences left.===
# ===(11s) Simulated 1000 sequences, 45000 sequences left.===
# ===(11s) Simulated 1000 sequences, 44000 sequences left.===
# ===(11s) Simulated 1000 sequences, 43000 sequences left.===
# ===(12s) Simulated 1000 sequences, 42000 sequences left.===
# ===(11s) Simulated 1000 sequences, 41000 sequences left.===
# ===(11s) Simulated 1000 sequences, 40000 sequences left.===
# ===(11s) Simulated 1000 sequences, 39000 sequences left.===
# ===(11s) Simulated 1000 sequences, 38000 sequences left.===
# ===(12s) Simulated 1000 sequences, 37000 sequences left.===
# ===(11s) Simulated 1000 sequences, 36000 sequences left.===
# ===(12s) Simulated 1000 sequences, 35000 sequences left.===
# ===(11s) Simulated 1000 sequences, 34000 sequences left.===
# ===(11s) Simulated 1000 sequences, 33000 sequences left.===
# ===(11s) Simulated 1000 sequences, 32000 sequences left.===
# ===(11s) Simulated 1000 sequences, 31000 sequences left.===
# ===(11s) Simulated 1000 sequences, 30000 sequences left.===
# ===(12s) Simulated 1000 sequences, 29000 sequences left.===
