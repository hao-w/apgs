# %%
# %matplotlib inline
from apgs.gmm.sim_gmm import Sim_GMM

# %%
N, K, D = 60, 3, 2
alpha, beta, mu, nu = 2.0, 2.0, 0.0, 0.1
simulator = Sim_GMM(N, K, D, alpha, beta, mu, nu)
simulator.viz_data()
