# %%
# %matplotlib inline
import torch
from univariate import *

# %%
set_seed(1231)
num_hiddens = 8
num_dims = 1
num_samples = 1000
iters = 10000
CUDA = False
device = torch.device('cuda:0')
lr = 1e-3
target_mean = 8.0
# target, proposal = init_densities(num_dims=num_dims, CUDA=CUDA, device=device, optimized=False)

# %% [markdown]
# #### densities that are far

# %%
output = train(iters, loss_rhs, target_mean,lr, num_samples, num_dims, num_hiddens, CUDA, device)     
plot_convergence(output, iters, num_samples)
# Out:
# 10000 gradient steps with 1000 samples in 40s

# %%
output = train(iters, loss_inc, target_mean, lr, num_samples, num_dims, num_hiddens, CUDA, device)     
plot_convergence(output, iters, num_samples)
# Out:
# 10000 gradient steps with 1000 samples in 41s

# %%
output = train(iters, loss_exc, target_mean, lr, num_samples, num_dims, num_hiddens, CUDA, device)     
plot_convergence(output, iters, num_samples)
# Out:
# 10000 gradient steps with 1000 samples in 41s

# %%
output = train(iters, loss_exc_reparam, target_mean, lr, num_samples, num_dims, num_hiddens, CUDA, device, reparameterized=True)     
plot_convergence(output, iters, num_samples)
# Out:
# 10000 gradient steps with 1000 samples in 42s

# %% [markdown]
# #### densities that are close

# %%
target_mean = 4.0
iters = 5000

# %%
output = train(iters, loss_rhs, target_mean,lr, num_samples, num_dims, num_hiddens, CUDA, device)     
plot_convergence(output, iters, num_samples)
# Out:
# 5000 gradient steps with 1000 samples in 19s

# %%
output = train(iters, loss_inc, target_mean, lr, num_samples, num_dims, num_hiddens, CUDA, device)     
plot_convergence(output, iters, num_samples)
# Out:
# 5000 gradient steps with 1000 samples in 19s

# %%
output = train(iters, loss_exc, target_mean, lr, num_samples, num_dims, num_hiddens, CUDA, device)     
plot_convergence(output, iters, num_samples)
# Out:
# 5000 gradient steps with 1000 samples in 19s

# %%
output = train(iters, loss_exc_reparam, target_mean, lr, num_samples, num_dims, num_hiddens, CUDA, device, reparameterized=True)     
plot_convergence(output, iters, num_samples)
# Out:
# 5000 gradient steps with 1000 samples in 19s
