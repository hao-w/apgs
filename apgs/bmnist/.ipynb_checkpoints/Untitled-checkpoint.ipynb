# %%
# %matplotlib inline
from apgs.bmnist.sim_bmnist import Sim_BMNIST

# %%
timesteps, num_digits, frame_size, delta_t, chunk_size = 10, 3, 96, 0.3, 1000
simulator = Sim_BMNIST(timesteps, num_digits, frame_size, delta_t, chunk_size)

# %%
PATH='../../data/bmnist/'
simulator.viz_data(PATH)
