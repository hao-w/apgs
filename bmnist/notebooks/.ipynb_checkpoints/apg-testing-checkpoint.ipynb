# %%
# %matplotlib inline
# %run ../../import_envs.py
# %run ../apg_hyperparams.py

CUDA = torch.cuda.is_available()
DEVICE = torch.device('cuda:0')
# Out:
# probtorch: 0.0+5a2c637 torch: 1.3.0
# inference method:oneshot-as-baseline, resampling:systematic, apg sweeps:0, epochs:1000, sample size:20, batch size:10, learning rate:0.0002

# %%
K = 5
T = 100

# train data path
DATA_PATHS = []
# TEST_DATA_DIR = '/data/hao/nvi_data/bmnist/%ddigits/' % K
# TEST_DATA_DIR = '/data/hao/nvi_data/bmnist/%dT_%dD/' % (T, K)

TEST_DATA_DIR = '/data/hao/apg_data/bmnist/test_%dT_%dD/' % (T, K)

print('===Loading testing data from %s===' % TEST_DATA_DIR)
for file in os.listdir(TEST_DATA_DIR):
    DATA_PATHS.append(os.path.join(TEST_DATA_DIR, file))
print('===%d groups of data files are loaded.===' % len(DATA_PATHS))
# Out:
# ===Loading testing data from /data/hao/apg_data/bmnist/test_100T_5D/===
# ===1 groups of data files are loaded.===

# %%
from apg_modeling import init_model
from affine_transformer import Affine_Transformer

model, optimizer = init_model(frame_pixels=FRAME_PIXELS,
                               digit_pixels=DIGIT_PIXELS, 
                               num_hidden_digit=NUM_HIDDEN_DIGIT, 
                               num_hidden_coor=NUM_HIDDEN_COOR, 
                               z_where_dim=Z_WHERE_DIM, 
                               z_what_dim=Z_WHAT_DIM, 
                               CUDA=CUDA, 
                               DEVICE=DEVICE, 
                               LOAD_VERSION=LOAD_VERSION, 
                               LR=LR)
AT = Affine_Transformer(frame_pixels=FRAME_PIXELS, 
                        digit_pixels=DIGIT_PIXELS, 
                        CUDA=CUDA, 
                        DEVICE=DEVICE)

# %%
# %run ../apg_testing.py

# test_all(model=model, 
#          AT=AT, 
#          apg_sweeps=0, 
#          data_paths=DATA_PATHS, 
#          mnist_mean_path=MNIST_MEAN_PATH, 
#          T=T, 
#          K=K, 
#          D=Z_WHERE_DIM, 
#          z_what_dim=Z_WHAT_DIM, 
#          batch_size=5, 
#          sample_size=10, 
#          MODEL_VERSION='%dT_%dD' % (T, K), 
#          CUDA=CUDA, 
#          DEVICE=DEVICE)

# %%
## visualize samples
# %run ../apg_testing.py
from viz import viz_samples, save_gifs_frames

BATCH_SIZE_TEST = 1
SAMPLE_SIZE_TEST = 1
DATA_PTR = 13


frames = sample_data_uniform(DATA_PATHS, DATA_PTR)

# %%
APG_SWEEPS_TEST = 10
SAVE_NAME = 'samples-%d-%dsweeps' % (DATA_PTR, APG_SWEEPS_TEST)

metrics = test_single(model=model, 
                      AT=AT,
                      apg_sweeps=APG_SWEEPS_TEST, 
                      frames=frames, 
                      mnist_mean_path=MNIST_MEAN_PATH,
                      K=K,
                      sample_size=SAMPLE_SIZE_TEST, 
                      CUDA=CUDA, 
                      DEVICE=DEVICE)

viz_samples(frames=frames,
            metrics=metrics,
            apg_sweeps=APG_SWEEPS_TEST,
            K=K, 
            viz_interval=3, 
            figure_size=20, 
            title_fontsize=20, 
            linewidth=2,
            colors=['#AA3377', '#EE7733', '#009988', '#0077BB', '#BBBBBB', '#EE3377', '#DDCC77'],
            save_name=None)

# %%
# import torch
# import numpy as np
# import os
# import matplotlib.gridspec as gridspec
# import matplotlib.pyplot as plt
# import matplotlib.patches as patches
        

        
# save_gifs_frames(frames=frames, 
#                  metrics=metrics, 
#                  K=K, 
#                  FS=6, 
#                  linewidth=5, 
#                  colors=['#AA3377', '#EE7733', '#009988', '#0077BB', '#BBBBBB', '#EE3377', '#DDCC77'], 
#                  PATH='gifs_apg/')

# %%
# SAVE_NAME_RWS = SAVE_NAME + "rws"
metrics = test_single(model=model, 
                      AT=AT,
                      apg_sweeps=0, 
                      frames=frames, 
                      mnist_mean_path=MNIST_MEAN_PATH,
                      K=K,
                      sample_size=1, 
                      CUDA=CUDA, 
                      DEVICE=DEVICE)

viz_samples(frames=frames,
            metrics=metrics,
            apg_sweeps=0,
            K=K, 
            viz_interval=3, 
            figure_size=20, 
            title_fontsize=20, 
            linewidth=5,
            colors=['#AA3377', '#EE7733', '#009988', '#0077BB', '#BBBBBB', '#EE3377', '#DDCC77'],
            save_name=None)
# Out:
# /home/hao/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2751: UserWarning: Default grid_sample and affine_grid behavior will be changed to align_corners=False from 1.4.0. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior will be changed "
# /home/hao/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2693: UserWarning: Default grid_sample and affine_grid behavior will be changed to align_corners=False from 1.4.0. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior will be changed "

# %%
## from viz import save_gifs_frames
save_gifs_frames(frames=frames, 
                 metrics=metrics, 
                 K=K, 
                 FS=6, 
                 linewidth=5, 
                 colors=['#AA3377', '#EE7733', '#009988', '#0077BB', '#BBBBBB', '#EE3377', '#DDCC77'], 
                 PATH='gifs_rws/')
